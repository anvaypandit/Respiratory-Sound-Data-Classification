# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import pandas as pd
import wave
import sys
import os
import librosa
import librosa.display
import xgboost as xgb
from  sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import sklearn.naive_bayes as nb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier,GradientBoostingClassifier
from sklearn.neighbors import kd_tree
import seaborn as sn
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.kd_tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
# Load per cycle data frame
import pickle
folder = "/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/" 
filename = folder + 'w_c_dataset.pickle'
infile = open(filename,'rb')
[sound,sr,lengths,times,labels] = pickle.load(infile)
infile.close()

# %%
def split_sounds(sounds,times,labels):
    s=[]
    l=[]
    for i,sound in enumerate(sounds):
        for t,label in zip(times[i],labels[i]):
            s.append(sound[int(t[0]):int(t[1])])
            if label==0:
                a=np.array([1,0,0,0])
            if label==1:
                a=np.array([0,1,0,0])
            if label==2:
                a=np.array([0,0,1,0])    
            if label==3:
                a=np.array([0,0,0,1])
            l.append(a)
    return s,l

# %%
[data,label]=split_sounds(sound,times,labels)

# %%
max_pad_len = 697
import librosa
def extract_feature(X,sample_rate):

    mel_spec = librosa.feature.melspectrogram(y=X, sr=sample_rate, n_mels=40)

    ps_db= librosa.power_to_db(mel_spec, ref=np.max)

    # Pad  till end
    pad_width_ps_db = max_pad_len - ps_db.shape[1]

    

    ps_db = np.pad(ps_db, pad_width=((0, 0), (0, pad_width_ps_db)), mode='constant')

    return ps_db

# %%
import sys
dataset = []
for d in data:
    a = extract_feature(d,sr[0])
    dataset.append(a)

# %%
dataset = np.array(dataset)
dataset.shape
# Out:
# (6898, 40, 697)

# %%
# add channel dimension for CNN
dataset = np.reshape(dataset, (*dataset.shape,1))

label=np.asarray(label)
a=np.zeros(label.shape[0])
for i in range(label.shape[0]):
    for j in range(label.shape[1]):
        if label[i][j]==1:
            a[i]=j

            
# Convert to binary for the binary classification problem
bin_label =np.zeros(label.shape[0])
for index,l in enumerate(a):
    if l == 0:
        bin_label[index] = l
    else:
        bin_label[index] = 1

unique, counts = np.unique(bin_label, return_counts=True)

print(np.asarray((unique, counts)).T)


# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(bin_label)
oh_labels = to_categorical(i_labels)
# Out:
# [[0.000e+00 3.642e+03]
#  [1.000e+00 3.256e+03]]

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(dataset, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %%
num_rows = 40
num_columns = 697
num_channels = 1

num_labels = 2
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(32, activation='relu')) 

model.add(Dense(num_labels, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()



# Load the trained model if required
model_file = '/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/LogMel_CNN_Binary_193.h5'
model.load_weights(model_file)

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 696, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 348, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 348, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 347, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 173, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 173, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 172, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 86, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 86, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 85, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 42, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 42, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 47,506
# Trainable params: 47,506
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 0s 9ms/step - loss: 0.4791 - accuracy: 0.7826
# Pre-training accuracy: 78.2609%

# %%
 #train model
num_epochs = 1000
num_batch_size = 128



callbacks = [
    ModelCheckpoint(
        filepath='/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
          validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.3946 - accuracy: 0.8110
# Epoch 00001: val_accuracy improved from -inf to 0.77319, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_01.h5
# 44/44 [==============================] - 3s 79ms/step - loss: 0.3946 - accuracy: 0.8110 - val_loss: 0.4925 - val_accuracy: 0.7732
# Epoch 2/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.8130
# Epoch 00002: val_accuracy improved from 0.77319 to 0.77609, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_02.h5
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3975 - accuracy: 0.8128 - val_loss: 0.4818 - val_accuracy: 0.7761
# Epoch 3/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3832 - accuracy: 0.8227
# Epoch 00003: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3898 - accuracy: 0.8222 - val_loss: 0.5043 - val_accuracy: 0.7688
# Epoch 4/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3842 - accuracy: 0.8218
# Epoch 00004: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 61ms/step - loss: 0.3811 - accuracy: 0.8220 - val_loss: 0.5269 - val_accuracy: 0.7551
# Epoch 5/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3934 - accuracy: 0.8160
# Epoch 00005: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3934 - accuracy: 0.8161 - val_loss: 0.5009 - val_accuracy: 0.7609
# Epoch 6/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3836 - accuracy: 0.8203
# Epoch 00006: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3824 - accuracy: 0.8204 - val_loss: 0.4941 - val_accuracy: 0.7703
# Epoch 7/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3818 - accuracy: 0.8227
# Epoch 00007: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3806 - accuracy: 0.8229 - val_loss: 0.5402 - val_accuracy: 0.7493
# Epoch 8/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3859 - accuracy: 0.8192
# Epoch 00008: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3850 - accuracy: 0.8195 - val_loss: 0.5039 - val_accuracy: 0.7681
# Epoch 9/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3829 - accuracy: 0.8230
# Epoch 00009: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 57ms/step - loss: 0.3785 - accuracy: 0.8233 - val_loss: 0.4888 - val_accuracy: 0.7696
# Epoch 10/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3790 - accuracy: 0.8312
# Epoch 00010: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 61ms/step - loss: 0.3807 - accuracy: 0.8307 - val_loss: 0.5135 - val_accuracy: 0.7536
# Epoch 11/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3885 - accuracy: 0.8210
# Epoch 00011: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3881 - accuracy: 0.8208 - val_loss: 0.4777 - val_accuracy: 0.7732
# Epoch 12/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3792 - accuracy: 0.8250
# Epoch 00012: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 61ms/step - loss: 0.3745 - accuracy: 0.8255 - val_loss: 0.4964 - val_accuracy: 0.7725
# Epoch 13/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3770 - accuracy: 0.8236
# Epoch 00013: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3763 - accuracy: 0.8237 - val_loss: 0.4759 - val_accuracy: 0.7725
# Epoch 14/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3779 - accuracy: 0.8249
# Epoch 00014: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 61ms/step - loss: 0.3785 - accuracy: 0.8248 - val_loss: 0.4775 - val_accuracy: 0.7710
# Epoch 15/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3677 - accuracy: 0.8350
# Epoch 00015: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 57ms/step - loss: 0.3749 - accuracy: 0.8345 - val_loss: 0.4864 - val_accuracy: 0.7645
# Epoch 16/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3784 - accuracy: 0.8259
# Epoch 00016: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3748 - accuracy: 0.8262 - val_loss: 0.5185 - val_accuracy: 0.7645
# Epoch 17/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3810 - accuracy: 0.8261
# Epoch 00017: val_accuracy did not improve from 0.77609
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3785 - accuracy: 0.8262 - val_loss: 0.4980 - val_accuracy: 0.7696
# Epoch 18/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3683 - accuracy: 0.8354
# Epoch 00018: val_accuracy improved from 0.77609 to 0.77899, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_18.h5
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3709 - accuracy: 0.8353 - val_loss: 0.4724 - val_accuracy: 0.7790
# Epoch 19/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3720 - accuracy: 0.8219
# Epoch 00019: val_accuracy did not improve from 0.77899
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3787 - accuracy: 0.8215 - val_loss: 0.4789 - val_accuracy: 0.7739
# Epoch 20/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3834 - accuracy: 0.8185
# Epoch 00020: val_accuracy improved from 0.77899 to 0.78116, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_20.h5
# 44/44 [==============================] - 3s 61ms/step - loss: 0.3814 - accuracy: 0.8186 - val_loss: 0.4810 - val_accuracy: 0.7812
# Epoch 21/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3690 - accuracy: 0.8296
# Epoch 00021: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3695 - accuracy: 0.8293 - val_loss: 0.5142 - val_accuracy: 0.7587
# Epoch 22/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3780 - accuracy: 0.8259
# Epoch 00022: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3730 - accuracy: 0.8264 - val_loss: 0.5086 - val_accuracy: 0.7688
# Epoch 23/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3765 - accuracy: 0.8278
# Epoch 00023: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 61ms/step - loss: 0.3709 - accuracy: 0.8282 - val_loss: 0.5087 - val_accuracy: 0.7659
# Epoch 24/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3620 - accuracy: 0.8316
# Epoch 00024: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3639 - accuracy: 0.8313 - val_loss: 0.5398 - val_accuracy: 0.7239
# Epoch 25/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3902 - accuracy: 0.8141
# Epoch 00025: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3877 - accuracy: 0.8142 - val_loss: 0.4786 - val_accuracy: 0.7717
# Epoch 26/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3752 - accuracy: 0.8205
# Epoch 00026: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3730 - accuracy: 0.8206 - val_loss: 0.4913 - val_accuracy: 0.7804
# Epoch 27/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3594 - accuracy: 0.8374
# Epoch 00027: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3571 - accuracy: 0.8374 - val_loss: 0.4740 - val_accuracy: 0.7732
# Epoch 28/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3710 - accuracy: 0.8274
# Epoch 00028: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3693 - accuracy: 0.8273 - val_loss: 0.4776 - val_accuracy: 0.7790
# Epoch 29/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3561 - accuracy: 0.8418
# Epoch 00029: val_accuracy did not improve from 0.78116
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3569 - accuracy: 0.8414 - val_loss: 0.4816 - val_accuracy: 0.7797
# Epoch 30/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3625 - accuracy: 0.8363
# Epoch 00030: val_accuracy improved from 0.78116 to 0.78261, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_30.h5
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3645 - accuracy: 0.8358 - val_loss: 0.4708 - val_accuracy: 0.7826
# Epoch 31/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3766 - accuracy: 0.8285
# Epoch 00031: val_accuracy did not improve from 0.78261
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3745 - accuracy: 0.8286 - val_loss: 0.5440 - val_accuracy: 0.7399
# Epoch 32/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3638 - accuracy: 0.8343
# Epoch 00032: val_accuracy did not improve from 0.78261
# 44/44 [==============================] - 3s 63ms/step - loss: 0.3626 - accuracy: 0.8344 - val_loss: 0.4896 - val_accuracy: 0.7703
# Epoch 33/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3704 - accuracy: 0.8281
# Epoch 00033: val_accuracy improved from 0.78261 to 0.79203, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_33.h5
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3734 - accuracy: 0.8280 - val_loss: 0.4745 - val_accuracy: 0.7920
# Epoch 34/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3583 - accuracy: 0.8385
# Epoch 00034: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3561 - accuracy: 0.8387 - val_loss: 0.5089 - val_accuracy: 0.7659
# Epoch 35/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3619 - accuracy: 0.8345
# Epoch 00035: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3623 - accuracy: 0.8344 - val_loss: 0.4948 - val_accuracy: 0.7623
# Epoch 36/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3493 - accuracy: 0.8401
# Epoch 00036: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3489 - accuracy: 0.8403 - val_loss: 0.4838 - val_accuracy: 0.7754
# Epoch 37/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3552 - accuracy: 0.8392
# Epoch 00037: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3528 - accuracy: 0.8394 - val_loss: 0.4675 - val_accuracy: 0.7841
# Epoch 38/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3520 - accuracy: 0.8347
# Epoch 00038: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3544 - accuracy: 0.8344 - val_loss: 0.4939 - val_accuracy: 0.7616
# Epoch 39/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3618 - accuracy: 0.8359
# Epoch 00039: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3614 - accuracy: 0.8360 - val_loss: 0.4862 - val_accuracy: 0.7768
# Epoch 40/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3580 - accuracy: 0.8398
# Epoch 00040: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3594 - accuracy: 0.8396 - val_loss: 0.4740 - val_accuracy: 0.7891
# Epoch 41/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3455 - accuracy: 0.8416
# Epoch 00041: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 61ms/step - loss: 0.3432 - accuracy: 0.8418 - val_loss: 0.4755 - val_accuracy: 0.7804
# Epoch 42/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3446 - accuracy: 0.8454
# Epoch 00042: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 62ms/step - loss: 0.3429 - accuracy: 0.8454 - val_loss: 0.5386 - val_accuracy: 0.7420
# Epoch 43/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3501 - accuracy: 0.8438
# Epoch 00043: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3493 - accuracy: 0.8438 - val_loss: 0.4884 - val_accuracy: 0.7848
# Epoch 44/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3351 - accuracy: 0.8463
# Epoch 00044: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3363 - accuracy: 0.8461 - val_loss: 0.5025 - val_accuracy: 0.7775
# Epoch 45/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3510 - accuracy: 0.8408
# Epoch 00045: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3487 - accuracy: 0.8409 - val_loss: 0.4913 - val_accuracy: 0.7804
# Epoch 46/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3335 - accuracy: 0.8490
# Epoch 00046: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3399 - accuracy: 0.8487 - val_loss: 0.4807 - val_accuracy: 0.7754
# Epoch 47/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3440 - accuracy: 0.8438
# Epoch 00047: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3480 - accuracy: 0.8434 - val_loss: 0.4800 - val_accuracy: 0.7812
# Epoch 48/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3569 - accuracy: 0.8392
# Epoch 00048: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3583 - accuracy: 0.8389 - val_loss: 0.4974 - val_accuracy: 0.7717
# Epoch 49/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3514 - accuracy: 0.8416
# Epoch 00049: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3498 - accuracy: 0.8416 - val_loss: 0.4712 - val_accuracy: 0.7819
# Epoch 50/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3520 - accuracy: 0.8410
# Epoch 00050: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3500 - accuracy: 0.8412 - val_loss: 0.4779 - val_accuracy: 0.7790
# Epoch 51/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3600 - accuracy: 0.8363
# Epoch 00051: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3684 - accuracy: 0.8358 - val_loss: 0.5015 - val_accuracy: 0.7710
# Epoch 52/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3650 - accuracy: 0.8321
# Epoch 00052: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3653 - accuracy: 0.8318 - val_loss: 0.4682 - val_accuracy: 0.7884
# Epoch 53/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3400 - accuracy: 0.8476
# Epoch 00053: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3423 - accuracy: 0.8474 - val_loss: 0.5166 - val_accuracy: 0.7609
# Epoch 54/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3478 - accuracy: 0.8405
# Epoch 00054: val_accuracy did not improve from 0.79203
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3472 - accuracy: 0.8405 - val_loss: 0.4759 - val_accuracy: 0.7768
# Epoch 55/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3381 - accuracy: 0.8438
# Epoch 00055: val_accuracy improved from 0.79203 to 0.80072, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_55.h5
# 44/44 [==============================] - 3s 60ms/step - loss: 0.3357 - accuracy: 0.8440 - val_loss: 0.4585 - val_accuracy: 0.8007
# Epoch 56/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3313 - accuracy: 0.8499
# Epoch 00056: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3281 - accuracy: 0.8501 - val_loss: 0.4873 - val_accuracy: 0.7855
# Epoch 57/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3320 - accuracy: 0.8503
# Epoch 00057: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3288 - accuracy: 0.8503 - val_loss: 0.4989 - val_accuracy: 0.7768
# Epoch 58/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3395 - accuracy: 0.8485
# Epoch 00058: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3362 - accuracy: 0.8485 - val_loss: 0.4672 - val_accuracy: 0.7848
# Epoch 59/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3211 - accuracy: 0.8550
# Epoch 00059: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3178 - accuracy: 0.8550 - val_loss: 0.5045 - val_accuracy: 0.7833
# Epoch 60/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3310 - accuracy: 0.8497
# Epoch 00060: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 62ms/step - loss: 0.3289 - accuracy: 0.8499 - val_loss: 0.4732 - val_accuracy: 0.7790
# Epoch 61/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3439 - accuracy: 0.8430
# Epoch 00061: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3469 - accuracy: 0.8429 - val_loss: 0.4896 - val_accuracy: 0.7761
# Epoch 62/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3252 - accuracy: 0.8561
# Epoch 00062: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3239 - accuracy: 0.8563 - val_loss: 0.4760 - val_accuracy: 0.7768
# Epoch 63/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3312 - accuracy: 0.8532
# Epoch 00063: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3286 - accuracy: 0.8534 - val_loss: 0.5038 - val_accuracy: 0.7768
# Epoch 64/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3288 - accuracy: 0.8532
# Epoch 00064: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3296 - accuracy: 0.8530 - val_loss: 0.4686 - val_accuracy: 0.7891
# Epoch 65/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3344 - accuracy: 0.8468
# Epoch 00065: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3326 - accuracy: 0.8469 - val_loss: 0.4973 - val_accuracy: 0.7696
# Epoch 66/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3371 - accuracy: 0.8487
# Epoch 00066: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3407 - accuracy: 0.8485 - val_loss: 0.5094 - val_accuracy: 0.7725
# Epoch 67/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3274 - accuracy: 0.8547
# Epoch 00067: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3274 - accuracy: 0.8547 - val_loss: 0.4828 - val_accuracy: 0.7812
# Epoch 68/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3293 - accuracy: 0.8521
# Epoch 00068: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3278 - accuracy: 0.8521 - val_loss: 0.4757 - val_accuracy: 0.7877
# Epoch 69/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3216 - accuracy: 0.8570
# Epoch 00069: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 63ms/step - loss: 0.3248 - accuracy: 0.8570 - val_loss: 0.4796 - val_accuracy: 0.7775
# Epoch 70/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3344 - accuracy: 0.8499
# Epoch 00070: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3363 - accuracy: 0.8498 - val_loss: 0.5008 - val_accuracy: 0.7717
# Epoch 71/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3242 - accuracy: 0.8521
# Epoch 00071: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3293 - accuracy: 0.8516 - val_loss: 0.4681 - val_accuracy: 0.7899
# Epoch 72/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3317 - accuracy: 0.8525
# Epoch 00072: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3290 - accuracy: 0.8527 - val_loss: 0.4845 - val_accuracy: 0.7855
# Epoch 73/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3236 - accuracy: 0.8514
# Epoch 00073: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3216 - accuracy: 0.8514 - val_loss: 0.4736 - val_accuracy: 0.7826
# Epoch 74/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3263 - accuracy: 0.8510
# Epoch 00074: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3221 - accuracy: 0.8512 - val_loss: 0.5287 - val_accuracy: 0.7464
# Epoch 75/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3448 - accuracy: 0.8450
# Epoch 00075: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3405 - accuracy: 0.8454 - val_loss: 0.4694 - val_accuracy: 0.7920
# Epoch 76/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3261 - accuracy: 0.8490
# Epoch 00076: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3252 - accuracy: 0.8487 - val_loss: 0.4951 - val_accuracy: 0.7848
# Epoch 77/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3209 - accuracy: 0.8605
# Epoch 00077: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3174 - accuracy: 0.8606 - val_loss: 0.4837 - val_accuracy: 0.7775
# Epoch 78/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3370 - accuracy: 0.8487
# Epoch 00078: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 67ms/step - loss: 0.3341 - accuracy: 0.8487 - val_loss: 0.4926 - val_accuracy: 0.7790
# Epoch 79/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3259 - accuracy: 0.8528
# Epoch 00079: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 63ms/step - loss: 0.3338 - accuracy: 0.8523 - val_loss: 0.4977 - val_accuracy: 0.7797
# Epoch 80/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3288 - accuracy: 0.8574
# Epoch 00080: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3304 - accuracy: 0.8574 - val_loss: 0.4882 - val_accuracy: 0.7906
# Epoch 81/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3350 - accuracy: 0.8479
# Epoch 00081: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3331 - accuracy: 0.8480 - val_loss: 0.4993 - val_accuracy: 0.7754
# Epoch 82/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3143 - accuracy: 0.8626
# Epoch 00082: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3135 - accuracy: 0.8628 - val_loss: 0.4839 - val_accuracy: 0.7906
# Epoch 83/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3179 - accuracy: 0.8594
# Epoch 00083: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3172 - accuracy: 0.8594 - val_loss: 0.5083 - val_accuracy: 0.7696
# Epoch 84/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3121 - accuracy: 0.8610
# Epoch 00084: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3163 - accuracy: 0.8610 - val_loss: 0.4615 - val_accuracy: 0.7949
# Epoch 85/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3142 - accuracy: 0.8617
# Epoch 00085: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3122 - accuracy: 0.8617 - val_loss: 0.4666 - val_accuracy: 0.8007
# Epoch 86/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3157 - accuracy: 0.8641
# Epoch 00086: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3146 - accuracy: 0.8641 - val_loss: 0.4810 - val_accuracy: 0.7841
# Epoch 87/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3121 - accuracy: 0.8617
# Epoch 00087: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3193 - accuracy: 0.8614 - val_loss: 0.5128 - val_accuracy: 0.7688
# Epoch 88/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3243 - accuracy: 0.8525
# Epoch 00088: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3244 - accuracy: 0.8525 - val_loss: 0.4718 - val_accuracy: 0.7884
# Epoch 89/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3143 - accuracy: 0.8599
# Epoch 00089: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3142 - accuracy: 0.8599 - val_loss: 0.4877 - val_accuracy: 0.7841
# Epoch 90/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3069 - accuracy: 0.8636
# Epoch 00090: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3051 - accuracy: 0.8637 - val_loss: 0.4685 - val_accuracy: 0.7978
# Epoch 91/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3170 - accuracy: 0.8570
# Epoch 00091: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3232 - accuracy: 0.8567 - val_loss: 0.4756 - val_accuracy: 0.7949
# Epoch 92/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3151 - accuracy: 0.8568
# Epoch 00092: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3123 - accuracy: 0.8570 - val_loss: 0.4799 - val_accuracy: 0.7862
# Epoch 93/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3173 - accuracy: 0.8606
# Epoch 00093: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3140 - accuracy: 0.8608 - val_loss: 0.4945 - val_accuracy: 0.7826
# Epoch 94/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3107 - accuracy: 0.8614
# Epoch 00094: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3110 - accuracy: 0.8614 - val_loss: 0.5238 - val_accuracy: 0.7681
# Epoch 95/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3175 - accuracy: 0.8548
# Epoch 00095: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3130 - accuracy: 0.8550 - val_loss: 0.5494 - val_accuracy: 0.7609
# Epoch 96/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3156 - accuracy: 0.8621
# Epoch 00096: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3126 - accuracy: 0.8623 - val_loss: 0.4855 - val_accuracy: 0.7833
# Epoch 97/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3087 - accuracy: 0.8646
# Epoch 00097: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 66ms/step - loss: 0.3061 - accuracy: 0.8648 - val_loss: 0.4949 - val_accuracy: 0.7812
# Epoch 98/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3001 - accuracy: 0.8725
# Epoch 00098: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3033 - accuracy: 0.8722 - val_loss: 0.4977 - val_accuracy: 0.7855
# Epoch 99/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3102 - accuracy: 0.8625
# Epoch 00099: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3181 - accuracy: 0.8621 - val_loss: 0.5106 - val_accuracy: 0.7587
# Epoch 100/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3293 - accuracy: 0.8510
# Epoch 00100: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3326 - accuracy: 0.8507 - val_loss: 0.4913 - val_accuracy: 0.7862
# Epoch 101/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3051 - accuracy: 0.8679
# Epoch 00101: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3050 - accuracy: 0.8677 - val_loss: 0.4902 - val_accuracy: 0.7848
# Epoch 102/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2986 - accuracy: 0.8692
# Epoch 00102: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2991 - accuracy: 0.8688 - val_loss: 0.4732 - val_accuracy: 0.7855
# Epoch 103/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3019 - accuracy: 0.8648
# Epoch 00103: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3043 - accuracy: 0.8646 - val_loss: 0.4890 - val_accuracy: 0.7797
# Epoch 104/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3067 - accuracy: 0.8628
# Epoch 00104: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3052 - accuracy: 0.8630 - val_loss: 0.5042 - val_accuracy: 0.7891
# Epoch 105/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3156 - accuracy: 0.8612
# Epoch 00105: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3180 - accuracy: 0.8606 - val_loss: 0.4936 - val_accuracy: 0.7899
# Epoch 106/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3266 - accuracy: 0.8505
# Epoch 00106: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 63ms/step - loss: 0.3230 - accuracy: 0.8509 - val_loss: 0.4734 - val_accuracy: 0.7790
# Epoch 107/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3036 - accuracy: 0.8632
# Epoch 00107: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3044 - accuracy: 0.8630 - val_loss: 0.4620 - val_accuracy: 0.7993
# Epoch 108/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3157 - accuracy: 0.8623
# Epoch 00108: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3137 - accuracy: 0.8625 - val_loss: 0.4882 - val_accuracy: 0.7812
# Epoch 109/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3092 - accuracy: 0.8586
# Epoch 00109: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3088 - accuracy: 0.8586 - val_loss: 0.4729 - val_accuracy: 0.7899
# Epoch 110/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3061 - accuracy: 0.8637
# Epoch 00110: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3040 - accuracy: 0.8639 - val_loss: 0.4788 - val_accuracy: 0.7870
# Epoch 111/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2927 - accuracy: 0.8690
# Epoch 00111: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2900 - accuracy: 0.8690 - val_loss: 0.4943 - val_accuracy: 0.7884
# Epoch 112/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2910 - accuracy: 0.8665
# Epoch 00112: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2929 - accuracy: 0.8663 - val_loss: 0.4815 - val_accuracy: 0.7862
# Epoch 113/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2960 - accuracy: 0.8677
# Epoch 00113: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2913 - accuracy: 0.8681 - val_loss: 0.4721 - val_accuracy: 0.7978
# Epoch 114/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3089 - accuracy: 0.8643
# Epoch 00114: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.3054 - accuracy: 0.8646 - val_loss: 0.4671 - val_accuracy: 0.7913
# Epoch 115/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2971 - accuracy: 0.8645
# Epoch 00115: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 64ms/step - loss: 0.2952 - accuracy: 0.8646 - val_loss: 0.4779 - val_accuracy: 0.7812
# Epoch 116/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3001 - accuracy: 0.8648
# Epoch 00116: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 65ms/step - loss: 0.2978 - accuracy: 0.8650 - val_loss: 0.4899 - val_accuracy: 0.7891
# Epoch 117/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2761 - accuracy: 0.8810
# Epoch 00117: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2820 - accuracy: 0.8808 - val_loss: 0.5290 - val_accuracy: 0.7725
# Epoch 118/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3092 - accuracy: 0.8646
# Epoch 00118: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3066 - accuracy: 0.8650 - val_loss: 0.5232 - val_accuracy: 0.7681
# Epoch 119/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2947 - accuracy: 0.8685
# Epoch 00119: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2953 - accuracy: 0.8684 - val_loss: 0.5059 - val_accuracy: 0.7754
# Epoch 120/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2907 - accuracy: 0.8757
# Epoch 00120: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2889 - accuracy: 0.8757 - val_loss: 0.4866 - val_accuracy: 0.7913
# Epoch 121/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2965 - accuracy: 0.8705
# Epoch 00121: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2980 - accuracy: 0.8704 - val_loss: 0.4798 - val_accuracy: 0.7928
# Epoch 122/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2916 - accuracy: 0.8683
# Epoch 00122: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2907 - accuracy: 0.8682 - val_loss: 0.4654 - val_accuracy: 0.7899
# Epoch 123/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2914 - accuracy: 0.8721
# Epoch 00123: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2929 - accuracy: 0.8722 - val_loss: 0.5255 - val_accuracy: 0.7696
# Epoch 124/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2966 - accuracy: 0.8717
# Epoch 00124: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2940 - accuracy: 0.8719 - val_loss: 0.5380 - val_accuracy: 0.7500
# Epoch 125/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2933 - accuracy: 0.8715
# Epoch 00125: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2949 - accuracy: 0.8715 - val_loss: 0.4896 - val_accuracy: 0.7891
# Epoch 126/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2962 - accuracy: 0.8656
# Epoch 00126: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2953 - accuracy: 0.8655 - val_loss: 0.4770 - val_accuracy: 0.7957
# Epoch 127/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2828 - accuracy: 0.8725
# Epoch 00127: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2800 - accuracy: 0.8726 - val_loss: 0.4804 - val_accuracy: 0.7957
# Epoch 128/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2830 - accuracy: 0.8794
# Epoch 00128: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2792 - accuracy: 0.8797 - val_loss: 0.5034 - val_accuracy: 0.7855
# Epoch 129/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2841 - accuracy: 0.8746
# Epoch 00129: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2844 - accuracy: 0.8748 - val_loss: 0.5065 - val_accuracy: 0.7797
# Epoch 130/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.3029 - accuracy: 0.8656
# Epoch 00130: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2983 - accuracy: 0.8659 - val_loss: 0.4913 - val_accuracy: 0.7942
# Epoch 131/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2875 - accuracy: 0.8774
# Epoch 00131: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2883 - accuracy: 0.8771 - val_loss: 0.4955 - val_accuracy: 0.7942
# Epoch 132/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2877 - accuracy: 0.8754
# Epoch 00132: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2897 - accuracy: 0.8753 - val_loss: 0.4932 - val_accuracy: 0.7942
# Epoch 133/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2776 - accuracy: 0.8783
# Epoch 00133: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2757 - accuracy: 0.8786 - val_loss: 0.4941 - val_accuracy: 0.7870
# Epoch 134/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2901 - accuracy: 0.8697
# Epoch 00134: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 66ms/step - loss: 0.2895 - accuracy: 0.8697 - val_loss: 0.4881 - val_accuracy: 0.7935
# Epoch 135/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2868 - accuracy: 0.8761
# Epoch 00135: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 60ms/step - loss: 0.2847 - accuracy: 0.8764 - val_loss: 0.5261 - val_accuracy: 0.7812
# Epoch 136/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2824 - accuracy: 0.8748
# Epoch 00136: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 60ms/step - loss: 0.2807 - accuracy: 0.8750 - val_loss: 0.4962 - val_accuracy: 0.7884
# Epoch 137/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2739 - accuracy: 0.8777
# Epoch 00137: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2737 - accuracy: 0.8777 - val_loss: 0.4867 - val_accuracy: 0.7841
# Epoch 138/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2838 - accuracy: 0.8772
# Epoch 00138: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2872 - accuracy: 0.8769 - val_loss: 0.4860 - val_accuracy: 0.7906
# Epoch 139/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2811 - accuracy: 0.8723
# Epoch 00139: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2773 - accuracy: 0.8726 - val_loss: 0.5242 - val_accuracy: 0.7746
# Epoch 140/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2858 - accuracy: 0.8710
# Epoch 00140: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2837 - accuracy: 0.8711 - val_loss: 0.5167 - val_accuracy: 0.7812
# Epoch 141/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2910 - accuracy: 0.8721
# Epoch 00141: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2899 - accuracy: 0.8721 - val_loss: 0.5121 - val_accuracy: 0.7790
# Epoch 142/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2784 - accuracy: 0.8781
# Epoch 00142: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2793 - accuracy: 0.8780 - val_loss: 0.5273 - val_accuracy: 0.7754
# Epoch 143/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2688 - accuracy: 0.8854
# Epoch 00143: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 67ms/step - loss: 0.2736 - accuracy: 0.8851 - val_loss: 0.4830 - val_accuracy: 0.7884
# Epoch 144/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2893 - accuracy: 0.8757
# Epoch 00144: val_accuracy improved from 0.80072 to 0.80362, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_144.h5
# 44/44 [==============================] - 3s 60ms/step - loss: 0.2918 - accuracy: 0.8757 - val_loss: 0.4665 - val_accuracy: 0.8036
# Epoch 145/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2920 - accuracy: 0.8728
# Epoch 00145: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2939 - accuracy: 0.8726 - val_loss: 0.4921 - val_accuracy: 0.7978
# Epoch 146/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2969 - accuracy: 0.8701
# Epoch 00146: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 58ms/step - loss: 0.3006 - accuracy: 0.8699 - val_loss: 0.5077 - val_accuracy: 0.7833
# Epoch 147/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2780 - accuracy: 0.8741
# Epoch 00147: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2822 - accuracy: 0.8739 - val_loss: 0.4724 - val_accuracy: 0.7993
# Epoch 148/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2722 - accuracy: 0.8832
# Epoch 00148: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2683 - accuracy: 0.8833 - val_loss: 0.4891 - val_accuracy: 0.7877
# Epoch 149/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.8797
# Epoch 00149: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2818 - accuracy: 0.8800 - val_loss: 0.4747 - val_accuracy: 0.7986
# Epoch 150/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2754 - accuracy: 0.8808
# Epoch 00150: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2726 - accuracy: 0.8811 - val_loss: 0.4904 - val_accuracy: 0.8007
# Epoch 151/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2893 - accuracy: 0.8737
# Epoch 00151: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2920 - accuracy: 0.8737 - val_loss: 0.4962 - val_accuracy: 0.7935
# Epoch 152/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2748 - accuracy: 0.8817
# Epoch 00152: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 64ms/step - loss: 0.2715 - accuracy: 0.8820 - val_loss: 0.5175 - val_accuracy: 0.7906
# Epoch 153/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2666 - accuracy: 0.8808
# Epoch 00153: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 65ms/step - loss: 0.2623 - accuracy: 0.8811 - val_loss: 0.4806 - val_accuracy: 0.7986
# Epoch 154/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2743 - accuracy: 0.8824
# Epoch 00154: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2755 - accuracy: 0.8824 - val_loss: 0.4984 - val_accuracy: 0.7971
# Epoch 155/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2759 - accuracy: 0.8801
# Epoch 00155: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2710 - accuracy: 0.8804 - val_loss: 0.5090 - val_accuracy: 0.7862
# Epoch 156/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2709 - accuracy: 0.8826
# Epoch 00156: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2691 - accuracy: 0.8826 - val_loss: 0.5083 - val_accuracy: 0.8000
# Epoch 157/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2678 - accuracy: 0.8839
# Epoch 00157: val_accuracy did not improve from 0.80362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2764 - accuracy: 0.8835 - val_loss: 0.5323 - val_accuracy: 0.7790
# Epoch 158/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2890 - accuracy: 0.8750
# Epoch 00158: val_accuracy improved from 0.80362 to 0.80507, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL_CNN_Binary/Try2/LogMel_CNN_Binary_158.h5
# 44/44 [==============================] - 3s 61ms/step - loss: 0.2941 - accuracy: 0.8750 - val_loss: 0.4604 - val_accuracy: 0.8051
# Epoch 159/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2846 - accuracy: 0.8830
# Epoch 00159: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2857 - accuracy: 0.8827 - val_loss: 0.4929 - val_accuracy: 0.7949
# Epoch 160/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2666 - accuracy: 0.8821
# Epoch 00160: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2643 - accuracy: 0.8822 - val_loss: 0.4899 - val_accuracy: 0.7986
# Epoch 161/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2595 - accuracy: 0.8852
# Epoch 00161: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2639 - accuracy: 0.8851 - val_loss: 0.4664 - val_accuracy: 0.8000
# Epoch 162/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2634 - accuracy: 0.8843
# Epoch 00162: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2668 - accuracy: 0.8840 - val_loss: 0.4787 - val_accuracy: 0.7978
# Epoch 163/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2734 - accuracy: 0.8805
# Epoch 00163: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2692 - accuracy: 0.8808 - val_loss: 0.4745 - val_accuracy: 0.7971
# Epoch 164/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2611 - accuracy: 0.8915
# Epoch 00164: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2715 - accuracy: 0.8913 - val_loss: 0.4868 - val_accuracy: 0.7978
# Epoch 165/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2856 - accuracy: 0.8726
# Epoch 00165: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2845 - accuracy: 0.8726 - val_loss: 0.4868 - val_accuracy: 0.7826
# Epoch 166/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2911 - accuracy: 0.8748
# Epoch 00166: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 60ms/step - loss: 0.2967 - accuracy: 0.8746 - val_loss: 0.5679 - val_accuracy: 0.7638
# Epoch 167/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2770 - accuracy: 0.8777
# Epoch 00167: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2793 - accuracy: 0.8777 - val_loss: 0.4726 - val_accuracy: 0.8000
# Epoch 168/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2659 - accuracy: 0.8826
# Epoch 00168: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2652 - accuracy: 0.8827 - val_loss: 0.4841 - val_accuracy: 0.7964
# Epoch 169/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2686 - accuracy: 0.8806
# Epoch 00169: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2676 - accuracy: 0.8808 - val_loss: 0.5044 - val_accuracy: 0.7906
# Epoch 170/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2542 - accuracy: 0.8850
# Epoch 00170: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2560 - accuracy: 0.8847 - val_loss: 0.4909 - val_accuracy: 0.7942
# Epoch 171/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2623 - accuracy: 0.8852
# Epoch 00171: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 78ms/step - loss: 0.2605 - accuracy: 0.8853 - val_loss: 0.5281 - val_accuracy: 0.7870
# Epoch 172/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2710 - accuracy: 0.8799
# Epoch 00172: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2681 - accuracy: 0.8802 - val_loss: 0.5308 - val_accuracy: 0.7870
# Epoch 173/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2573 - accuracy: 0.8903
# Epoch 00173: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2548 - accuracy: 0.8905 - val_loss: 0.4995 - val_accuracy: 0.7935
# Epoch 174/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2580 - accuracy: 0.8935
# Epoch 00174: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 60ms/step - loss: 0.2620 - accuracy: 0.8934 - val_loss: 0.5247 - val_accuracy: 0.7920
# Epoch 175/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2845 - accuracy: 0.8739
# Epoch 00175: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2839 - accuracy: 0.8739 - val_loss: 0.4964 - val_accuracy: 0.7986
# Epoch 176/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2603 - accuracy: 0.8877
# Epoch 00176: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 58ms/step - loss: 0.2646 - accuracy: 0.8875 - val_loss: 0.5031 - val_accuracy: 0.7920
# Epoch 177/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2473 - accuracy: 0.8928
# Epoch 00177: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 59ms/step - loss: 0.2486 - accuracy: 0.8927 - val_loss: 0.5217 - val_accuracy: 0.7877
# Epoch 178/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2642 - accuracy: 0.8839
# Epoch 00178: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 60ms/step - loss: 0.2722 - accuracy: 0.8835 - val_loss: 0.5426 - val_accuracy: 0.7870
# Epoch 179/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2785 - accuracy: 0.8815
# Epoch 00179: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 61ms/step - loss: 0.2802 - accuracy: 0.8817 - val_loss: 0.5304 - val_accuracy: 0.7884
# Epoch 180/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2594 - accuracy: 0.8864
