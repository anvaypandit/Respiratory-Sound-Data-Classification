# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import pandas as pd
import wave
import sys
import os
import librosa
import librosa.display
import xgboost as xgb
from  sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import sklearn.naive_bayes as nb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier,GradientBoostingClassifier
from sklearn.neighbors import kd_tree
import seaborn as sn
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.kd_tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
# Load per cycle data frame
import pickle
folder = "/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/" 
filename = folder + 'w_c_dataset.pickle'
infile = open(filename,'rb')
[sound,sr,lengths,times,labels] = pickle.load(infile)
infile.close()

# %%
def split_sounds(sounds,times,labels):
    s=[]
    l=[]
    for i,sound in enumerate(sounds):
        for t,label in zip(times[i],labels[i]):
            s.append(sound[int(t[0]):int(t[1])])
            if label==0:
                a=np.array([1,0,0,0])
            if label==1:
                a=np.array([0,1,0,0])
            if label==2:
                a=np.array([0,0,1,0])    
            if label==3:
                a=np.array([0,0,0,1])
            l.append(a)
    return s,l

# %%
max_pad_len = 697
import librosa
def extract_feature(X,sample_rate):
    n_fft=int(sample_rate*0.025)
    hop_length=int(sample_rate*0.01)

    mel_spec = librosa.feature.melspectrogram(y=X, sr=sample_rate, n_mels=40)
    ps_db= librosa.power_to_db(mel_spec, ref=np.max)
    mfccs = librosa.feature.mfcc(y=X, sr=sample_rate,n_mfcc=40)
    # Pad  mfcc till the end
    pad_width_mfcc = max_pad_len - mfccs.shape[1]
    pad_width_ps_db = max_pad_len - ps_db.shape[1]
    
    mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width_mfcc)), mode='constant')
    ps_db = np.pad(ps_db, pad_width=((0, 0), (0, pad_width_ps_db)), mode='constant')
    
    return np.vstack((mfccs,ps_db))

# %%
import sys
[data,label]=split_sounds(sound,times,labels)
dataset = []
for d in data:
    a = extract_feature(d,sr[0])
    dataset.append(a)

# %%
dataset = np.array(dataset)
dataset.shape
# Out:
# (6898, 80, 697)

# %%
# add channel dimension for CNN
dataset = np.reshape(dataset, (*dataset.shape,1))

label=np.asarray(label)
a=np.zeros(label.shape[0])
for i in range(label.shape[0]):
    for j in range(label.shape[1]):
        if label[i][j]==1:
            a[i]=j

# COnvert to binary for the binary classification problem
bin_label =np.zeros(label.shape[0])
for index,l in enumerate(a):
    if l == 0:
        bin_label[index] = l
    else:
        bin_label[index] = 1

unique, counts = np.unique(bin_label, return_counts=True)

print(np.asarray((unique, counts)).T)


# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(bin_label)
oh_labels = to_categorical(i_labels)
# Out:
# [[0.000e+00 3.642e+03]
#  [1.000e+00 3.256e+03]]

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(dataset, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %%
num_rows = 80
num_columns = 697
num_channels = 1

num_labels = 2
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(32, activation='relu')) 

model.add(Dense(num_labels, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()



# Load the trained model if required
#model_file = '/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/MFC_CNN_Binary_197.h5'
#model.load_weights(model_file)

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 79, 696, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 39, 348, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 39, 348, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 38, 347, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 173, 32)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 173, 32)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 172, 64)       8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 86, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 86, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 85, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 42, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 42, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 47,506
# Trainable params: 47,506
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 0s 8ms/step - loss: 0.7130 - accuracy: 0.5283
# Pre-training accuracy: 52.8261%

# %%
# train model
num_epochs = 500
num_batch_size = 128



callbacks = [
    ModelCheckpoint(
        filepath='/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
          validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/500
# 44/44 [==============================] - ETA: 0s - loss: 0.7022 - accuracy: 0.5227
# Epoch 00001: val_accuracy improved from -inf to 0.53261, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_01.h5
# 44/44 [==============================] - 5s 125ms/step - loss: 0.7022 - accuracy: 0.5227 - val_loss: 0.6918 - val_accuracy: 0.5326
# Epoch 2/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6875 - accuracy: 0.5540
# Epoch 00002: val_accuracy improved from 0.53261 to 0.54855, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_02.h5
# 44/44 [==============================] - 5s 113ms/step - loss: 0.6873 - accuracy: 0.5542 - val_loss: 0.6858 - val_accuracy: 0.5486
# Epoch 3/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6759 - accuracy: 0.5963
# Epoch 00003: val_accuracy improved from 0.54855 to 0.60145, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_03.h5
# 44/44 [==============================] - 4s 93ms/step - loss: 0.6762 - accuracy: 0.5960 - val_loss: 0.6780 - val_accuracy: 0.6014
# Epoch 4/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6658 - accuracy: 0.6059
# Epoch 00004: val_accuracy did not improve from 0.60145
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6683 - accuracy: 0.6055 - val_loss: 0.6885 - val_accuracy: 0.5442
# Epoch 5/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6699 - accuracy: 0.5899
# Epoch 00005: val_accuracy improved from 0.60145 to 0.60797, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_05.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6700 - accuracy: 0.5903 - val_loss: 0.6681 - val_accuracy: 0.6080
# Epoch 6/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6597 - accuracy: 0.6007
# Epoch 00006: val_accuracy did not improve from 0.60797
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6602 - accuracy: 0.6006 - val_loss: 0.6680 - val_accuracy: 0.6080
# Epoch 7/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6535 - accuracy: 0.6259
# Epoch 00007: val_accuracy improved from 0.60797 to 0.60870, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_07.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6539 - accuracy: 0.6261 - val_loss: 0.6665 - val_accuracy: 0.6087
# Epoch 8/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6522 - accuracy: 0.6266
# Epoch 00008: val_accuracy did not improve from 0.60870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6555 - accuracy: 0.6258 - val_loss: 0.6705 - val_accuracy: 0.5891
# Epoch 9/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6447 - accuracy: 0.6344
# Epoch 00009: val_accuracy improved from 0.60870 to 0.62391, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_09.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6445 - accuracy: 0.6341 - val_loss: 0.6577 - val_accuracy: 0.6239
# Epoch 10/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6420 - accuracy: 0.6388
# Epoch 00010: val_accuracy did not improve from 0.62391
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6429 - accuracy: 0.6385 - val_loss: 0.6558 - val_accuracy: 0.6232
# Epoch 11/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6428 - accuracy: 0.6335
# Epoch 00011: val_accuracy did not improve from 0.62391
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6431 - accuracy: 0.6339 - val_loss: 0.6592 - val_accuracy: 0.6087
# Epoch 12/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6415 - accuracy: 0.6444
# Epoch 00012: val_accuracy did not improve from 0.62391
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6439 - accuracy: 0.6443 - val_loss: 0.6528 - val_accuracy: 0.6239
# Epoch 13/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6345 - accuracy: 0.6490
# Epoch 00013: val_accuracy did not improve from 0.62391
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6351 - accuracy: 0.6488 - val_loss: 0.6596 - val_accuracy: 0.6094
# Epoch 14/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6384 - accuracy: 0.6374
# Epoch 00014: val_accuracy improved from 0.62391 to 0.63696, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_14.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6387 - accuracy: 0.6370 - val_loss: 0.6507 - val_accuracy: 0.6370
# Epoch 15/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6364 - accuracy: 0.6428
# Epoch 00015: val_accuracy did not improve from 0.63696
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6345 - accuracy: 0.6432 - val_loss: 0.6590 - val_accuracy: 0.6109
# Epoch 16/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6292 - accuracy: 0.6510
# Epoch 00016: val_accuracy did not improve from 0.63696
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6318 - accuracy: 0.6506 - val_loss: 0.6504 - val_accuracy: 0.6239
# Epoch 17/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6293 - accuracy: 0.6450
# Epoch 00017: val_accuracy did not improve from 0.63696
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6271 - accuracy: 0.6453 - val_loss: 0.6442 - val_accuracy: 0.6275
# Epoch 18/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6280 - accuracy: 0.6535
# Epoch 00018: val_accuracy did not improve from 0.63696
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6288 - accuracy: 0.6535 - val_loss: 0.6442 - val_accuracy: 0.6348
# Epoch 19/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6211 - accuracy: 0.6564
# Epoch 00019: val_accuracy did not improve from 0.63696
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6230 - accuracy: 0.6562 - val_loss: 0.6498 - val_accuracy: 0.6217
# Epoch 20/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6278 - accuracy: 0.6528
# Epoch 00020: val_accuracy did not improve from 0.63696
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6297 - accuracy: 0.6528 - val_loss: 0.6425 - val_accuracy: 0.6355
# Epoch 21/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6229 - accuracy: 0.6592
# Epoch 00021: val_accuracy improved from 0.63696 to 0.64565, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_21.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6262 - accuracy: 0.6591 - val_loss: 0.6356 - val_accuracy: 0.6457
# Epoch 22/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6221 - accuracy: 0.6555
# Epoch 00022: val_accuracy did not improve from 0.64565
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6214 - accuracy: 0.6557 - val_loss: 0.6428 - val_accuracy: 0.6217
# Epoch 23/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6176 - accuracy: 0.6593
# Epoch 00023: val_accuracy did not improve from 0.64565
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6179 - accuracy: 0.6593 - val_loss: 0.6298 - val_accuracy: 0.6413
# Epoch 24/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6174 - accuracy: 0.6602
# Epoch 00024: val_accuracy did not improve from 0.64565
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6157 - accuracy: 0.6606 - val_loss: 0.6325 - val_accuracy: 0.6413
# Epoch 25/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6117 - accuracy: 0.6641
# Epoch 00025: val_accuracy did not improve from 0.64565
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6104 - accuracy: 0.6640 - val_loss: 0.6292 - val_accuracy: 0.6457
# Epoch 26/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6102 - accuracy: 0.6704
# Epoch 00026: val_accuracy did not improve from 0.64565
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6137 - accuracy: 0.6700 - val_loss: 0.6291 - val_accuracy: 0.6457
# Epoch 27/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6098 - accuracy: 0.6681
# Epoch 00027: val_accuracy improved from 0.64565 to 0.64855, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_27.h5
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6108 - accuracy: 0.6678 - val_loss: 0.6239 - val_accuracy: 0.6486
# Epoch 28/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6093 - accuracy: 0.6666
# Epoch 00028: val_accuracy did not improve from 0.64855
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6097 - accuracy: 0.6667 - val_loss: 0.6283 - val_accuracy: 0.6457
# Epoch 29/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6052 - accuracy: 0.6731
# Epoch 00029: val_accuracy did not improve from 0.64855
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6013 - accuracy: 0.6736 - val_loss: 0.6191 - val_accuracy: 0.6471
# Epoch 30/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6044 - accuracy: 0.6781
# Epoch 00030: val_accuracy did not improve from 0.64855
# 44/44 [==============================] - 3s 69ms/step - loss: 0.6019 - accuracy: 0.6783 - val_loss: 0.6196 - val_accuracy: 0.6442
# Epoch 31/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5992 - accuracy: 0.6771
# Epoch 00031: val_accuracy improved from 0.64855 to 0.65507, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_31.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5979 - accuracy: 0.6774 - val_loss: 0.6207 - val_accuracy: 0.6551
# Epoch 32/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5993 - accuracy: 0.6831
# Epoch 00032: val_accuracy improved from 0.65507 to 0.65652, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_32.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5980 - accuracy: 0.6829 - val_loss: 0.6206 - val_accuracy: 0.6565
# Epoch 33/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6022 - accuracy: 0.6757
# Epoch 00033: val_accuracy did not improve from 0.65652
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6030 - accuracy: 0.6754 - val_loss: 0.6204 - val_accuracy: 0.6536
# Epoch 34/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6045 - accuracy: 0.6768
# Epoch 00034: val_accuracy improved from 0.65652 to 0.66739, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_34.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6060 - accuracy: 0.6767 - val_loss: 0.6135 - val_accuracy: 0.6674
# Epoch 35/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5941 - accuracy: 0.6886
# Epoch 00035: val_accuracy did not improve from 0.66739
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5939 - accuracy: 0.6890 - val_loss: 0.6114 - val_accuracy: 0.6609
# Epoch 36/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5938 - accuracy: 0.6831
# Epoch 00036: val_accuracy did not improve from 0.66739
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5951 - accuracy: 0.6829 - val_loss: 0.6128 - val_accuracy: 0.6623
# Epoch 37/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5881 - accuracy: 0.6913
# Epoch 00037: val_accuracy improved from 0.66739 to 0.67609, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_37.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5914 - accuracy: 0.6908 - val_loss: 0.6027 - val_accuracy: 0.6761
# Epoch 38/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5838 - accuracy: 0.6953
# Epoch 00038: val_accuracy improved from 0.67609 to 0.67681, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_38.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5830 - accuracy: 0.6955 - val_loss: 0.5987 - val_accuracy: 0.6768
# Epoch 39/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5866 - accuracy: 0.6926
# Epoch 00039: val_accuracy improved from 0.67681 to 0.67754, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_39.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5873 - accuracy: 0.6923 - val_loss: 0.6038 - val_accuracy: 0.6775
# Epoch 40/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5871 - accuracy: 0.6933
# Epoch 00040: val_accuracy did not improve from 0.67754
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5858 - accuracy: 0.6934 - val_loss: 0.6032 - val_accuracy: 0.6725
# Epoch 41/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5791 - accuracy: 0.7002
# Epoch 00041: val_accuracy did not improve from 0.67754
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5800 - accuracy: 0.7003 - val_loss: 0.6053 - val_accuracy: 0.6710
# Epoch 42/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5813 - accuracy: 0.6999
# Epoch 00042: val_accuracy improved from 0.67754 to 0.68841, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_42.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5797 - accuracy: 0.7001 - val_loss: 0.5945 - val_accuracy: 0.6884
# Epoch 43/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5807 - accuracy: 0.6939
# Epoch 00043: val_accuracy did not improve from 0.68841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5854 - accuracy: 0.6932 - val_loss: 0.5894 - val_accuracy: 0.6855
# Epoch 44/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5795 - accuracy: 0.6949
# Epoch 00044: val_accuracy did not improve from 0.68841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5781 - accuracy: 0.6952 - val_loss: 0.5923 - val_accuracy: 0.6790
# Epoch 45/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5769 - accuracy: 0.6982
# Epoch 00045: val_accuracy did not improve from 0.68841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5813 - accuracy: 0.6977 - val_loss: 0.5947 - val_accuracy: 0.6732
# Epoch 46/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5751 - accuracy: 0.6968
# Epoch 00046: val_accuracy did not improve from 0.68841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5776 - accuracy: 0.6966 - val_loss: 0.5918 - val_accuracy: 0.6754
# Epoch 47/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5690 - accuracy: 0.7077
# Epoch 00047: val_accuracy improved from 0.68841 to 0.69275, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_47.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5686 - accuracy: 0.7079 - val_loss: 0.5851 - val_accuracy: 0.6928
# Epoch 48/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5691 - accuracy: 0.7068
# Epoch 00048: val_accuracy did not improve from 0.69275
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5704 - accuracy: 0.7066 - val_loss: 0.6078 - val_accuracy: 0.6565
# Epoch 49/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5670 - accuracy: 0.7097
# Epoch 00049: val_accuracy did not improve from 0.69275
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5688 - accuracy: 0.7099 - val_loss: 0.5845 - val_accuracy: 0.6899
# Epoch 50/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5677 - accuracy: 0.7077
# Epoch 00050: val_accuracy did not improve from 0.69275
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5690 - accuracy: 0.7075 - val_loss: 0.5870 - val_accuracy: 0.6913
# Epoch 51/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5573 - accuracy: 0.7189
# Epoch 00051: val_accuracy did not improve from 0.69275
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5559 - accuracy: 0.7191 - val_loss: 0.6161 - val_accuracy: 0.6667
# Epoch 52/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5631 - accuracy: 0.7133
# Epoch 00052: val_accuracy improved from 0.69275 to 0.69493, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_52.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5622 - accuracy: 0.7135 - val_loss: 0.5775 - val_accuracy: 0.6949
# Epoch 53/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5555 - accuracy: 0.7146
# Epoch 00053: val_accuracy improved from 0.69493 to 0.71014, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_53.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5604 - accuracy: 0.7140 - val_loss: 0.5731 - val_accuracy: 0.7101
# Epoch 54/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5550 - accuracy: 0.7200
# Epoch 00054: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5542 - accuracy: 0.7196 - val_loss: 0.5729 - val_accuracy: 0.7036
# Epoch 55/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5549 - accuracy: 0.7262
# Epoch 00055: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5531 - accuracy: 0.7264 - val_loss: 0.5749 - val_accuracy: 0.6949
# Epoch 56/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5540 - accuracy: 0.7198
# Epoch 00056: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5540 - accuracy: 0.7198 - val_loss: 0.5971 - val_accuracy: 0.6746
# Epoch 57/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5530 - accuracy: 0.7178
# Epoch 00057: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5578 - accuracy: 0.7173 - val_loss: 0.5702 - val_accuracy: 0.7007
# Epoch 58/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5552 - accuracy: 0.7198
# Epoch 00058: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5539 - accuracy: 0.7198 - val_loss: 0.5714 - val_accuracy: 0.6957
# Epoch 59/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5469 - accuracy: 0.7209
# Epoch 00059: val_accuracy improved from 0.71014 to 0.71087, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_59.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5493 - accuracy: 0.7209 - val_loss: 0.5633 - val_accuracy: 0.7109
# Epoch 60/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5540 - accuracy: 0.7220
# Epoch 00060: val_accuracy did not improve from 0.71087
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5511 - accuracy: 0.7224 - val_loss: 0.5847 - val_accuracy: 0.6848
# Epoch 61/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5432 - accuracy: 0.7275
# Epoch 00061: val_accuracy did not improve from 0.71087
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5399 - accuracy: 0.7278 - val_loss: 0.5869 - val_accuracy: 0.6819
# Epoch 62/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5457 - accuracy: 0.7302
# Epoch 00062: val_accuracy did not improve from 0.71087
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5430 - accuracy: 0.7303 - val_loss: 0.5632 - val_accuracy: 0.7080
# Epoch 63/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5371 - accuracy: 0.7289
# Epoch 00063: val_accuracy did not improve from 0.71087
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5396 - accuracy: 0.7289 - val_loss: 0.5674 - val_accuracy: 0.6942
# Epoch 64/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5343 - accuracy: 0.7384
# Epoch 00064: val_accuracy did not improve from 0.71087
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5341 - accuracy: 0.7385 - val_loss: 0.5636 - val_accuracy: 0.7022
# Epoch 65/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5392 - accuracy: 0.7258
# Epoch 00065: val_accuracy did not improve from 0.71087
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5362 - accuracy: 0.7262 - val_loss: 0.5567 - val_accuracy: 0.7072
# Epoch 66/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5326 - accuracy: 0.7356
# Epoch 00066: val_accuracy improved from 0.71087 to 0.71377, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_66.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5300 - accuracy: 0.7358 - val_loss: 0.5570 - val_accuracy: 0.7138
# Epoch 67/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5305 - accuracy: 0.7378
# Epoch 00067: val_accuracy did not improve from 0.71377
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5328 - accuracy: 0.7378 - val_loss: 0.5602 - val_accuracy: 0.7022
# Epoch 68/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5399 - accuracy: 0.7309
# Epoch 00068: val_accuracy improved from 0.71377 to 0.71594, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_68.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5401 - accuracy: 0.7309 - val_loss: 0.5523 - val_accuracy: 0.7159
# Epoch 69/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5202 - accuracy: 0.7453
# Epoch 00069: val_accuracy did not improve from 0.71594
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5187 - accuracy: 0.7454 - val_loss: 0.5432 - val_accuracy: 0.7159
# Epoch 70/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5311 - accuracy: 0.7346
# Epoch 00070: val_accuracy did not improve from 0.71594
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5269 - accuracy: 0.7350 - val_loss: 0.5503 - val_accuracy: 0.7116
# Epoch 71/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5240 - accuracy: 0.7476
# Epoch 00071: val_accuracy improved from 0.71594 to 0.72029, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_71.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5194 - accuracy: 0.7481 - val_loss: 0.5440 - val_accuracy: 0.7203
# Epoch 72/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5268 - accuracy: 0.7355
# Epoch 00072: val_accuracy did not improve from 0.72029
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5302 - accuracy: 0.7349 - val_loss: 0.5582 - val_accuracy: 0.7014
# Epoch 73/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5211 - accuracy: 0.7444
# Epoch 00073: val_accuracy did not improve from 0.72029
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5192 - accuracy: 0.7447 - val_loss: 0.5398 - val_accuracy: 0.7174
# Epoch 74/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5094 - accuracy: 0.7529
# Epoch 00074: val_accuracy did not improve from 0.72029
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5116 - accuracy: 0.7526 - val_loss: 0.5368 - val_accuracy: 0.7196
# Epoch 75/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5149 - accuracy: 0.7513
# Epoch 00075: val_accuracy improved from 0.72029 to 0.72101, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_75.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5153 - accuracy: 0.7512 - val_loss: 0.5428 - val_accuracy: 0.7210
# Epoch 76/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5110 - accuracy: 0.7518
# Epoch 00076: val_accuracy improved from 0.72101 to 0.72174, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_76.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5108 - accuracy: 0.7517 - val_loss: 0.5377 - val_accuracy: 0.7217
# Epoch 77/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5241 - accuracy: 0.7335
# Epoch 00077: val_accuracy did not improve from 0.72174
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5191 - accuracy: 0.7340 - val_loss: 0.5457 - val_accuracy: 0.7181
# Epoch 78/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5087 - accuracy: 0.7535
# Epoch 00078: val_accuracy did not improve from 0.72174
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5076 - accuracy: 0.7537 - val_loss: 0.5354 - val_accuracy: 0.7196
# Epoch 79/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5180 - accuracy: 0.7456
# Epoch 00079: val_accuracy did not improve from 0.72174
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5160 - accuracy: 0.7459 - val_loss: 0.5526 - val_accuracy: 0.7080
# Epoch 80/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5127 - accuracy: 0.7544
# Epoch 00080: val_accuracy did not improve from 0.72174
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5105 - accuracy: 0.7546 - val_loss: 0.5404 - val_accuracy: 0.7138
# Epoch 81/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5090 - accuracy: 0.7578
# Epoch 00081: val_accuracy improved from 0.72174 to 0.73188, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_81.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5066 - accuracy: 0.7582 - val_loss: 0.5317 - val_accuracy: 0.7319
# Epoch 82/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5078 - accuracy: 0.7518
# Epoch 00082: val_accuracy improved from 0.73188 to 0.73333, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_82.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5066 - accuracy: 0.7519 - val_loss: 0.5299 - val_accuracy: 0.7333
# Epoch 83/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4989 - accuracy: 0.7662
# Epoch 00083: val_accuracy did not improve from 0.73333
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4967 - accuracy: 0.7664 - val_loss: 0.5331 - val_accuracy: 0.7217
# Epoch 84/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5008 - accuracy: 0.7591
# Epoch 00084: val_accuracy improved from 0.73333 to 0.73841, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_84.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5033 - accuracy: 0.7590 - val_loss: 0.5264 - val_accuracy: 0.7384
# Epoch 85/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4982 - accuracy: 0.7584
# Epoch 00085: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4969 - accuracy: 0.7584 - val_loss: 0.5293 - val_accuracy: 0.7261
# Epoch 86/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4966 - accuracy: 0.7624
# Epoch 00086: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4918 - accuracy: 0.7628 - val_loss: 0.5239 - val_accuracy: 0.7290
# Epoch 87/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4924 - accuracy: 0.7696
# Epoch 00087: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4876 - accuracy: 0.7700 - val_loss: 0.5263 - val_accuracy: 0.7290
# Epoch 88/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4889 - accuracy: 0.7644
# Epoch 00088: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4889 - accuracy: 0.7640 - val_loss: 0.5213 - val_accuracy: 0.7283
# Epoch 89/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4785 - accuracy: 0.7664
# Epoch 00089: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4821 - accuracy: 0.7660 - val_loss: 0.5206 - val_accuracy: 0.7377
# Epoch 90/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4910 - accuracy: 0.7616
# Epoch 00090: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4997 - accuracy: 0.7608 - val_loss: 0.5384 - val_accuracy: 0.7261
# Epoch 91/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5085 - accuracy: 0.7480
# Epoch 00091: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.5110 - accuracy: 0.7479 - val_loss: 0.5286 - val_accuracy: 0.7261
# Epoch 92/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4883 - accuracy: 0.7585
# Epoch 00092: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4843 - accuracy: 0.7590 - val_loss: 0.5211 - val_accuracy: 0.7355
# Epoch 93/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4835 - accuracy: 0.7729
# Epoch 00093: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4806 - accuracy: 0.7733 - val_loss: 0.5279 - val_accuracy: 0.7304
# Epoch 94/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4773 - accuracy: 0.7749
# Epoch 00094: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 74ms/step - loss: 0.4748 - accuracy: 0.7751 - val_loss: 0.5413 - val_accuracy: 0.7232
# Epoch 95/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4906 - accuracy: 0.7638
# Epoch 00095: val_accuracy did not improve from 0.73841
# 44/44 [==============================] - 3s 75ms/step - loss: 0.4892 - accuracy: 0.7639 - val_loss: 0.5227 - val_accuracy: 0.7268
# Epoch 96/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4737 - accuracy: 0.7765
# Epoch 00096: val_accuracy improved from 0.73841 to 0.73913, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_96.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4791 - accuracy: 0.7764 - val_loss: 0.5146 - val_accuracy: 0.7391
# Epoch 97/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4775 - accuracy: 0.7733
# Epoch 00097: val_accuracy improved from 0.73913 to 0.74420, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_97.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4814 - accuracy: 0.7727 - val_loss: 0.5169 - val_accuracy: 0.7442
# Epoch 98/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4823 - accuracy: 0.7711
# Epoch 00098: val_accuracy did not improve from 0.74420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4801 - accuracy: 0.7711 - val_loss: 0.5149 - val_accuracy: 0.7399
# Epoch 99/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4847 - accuracy: 0.7629
# Epoch 00099: val_accuracy did not improve from 0.74420
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4817 - accuracy: 0.7630 - val_loss: 0.5173 - val_accuracy: 0.7370
# Epoch 100/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4704 - accuracy: 0.7751
# Epoch 00100: val_accuracy improved from 0.74420 to 0.75000, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_100.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4717 - accuracy: 0.7751 - val_loss: 0.5118 - val_accuracy: 0.7500
# Epoch 101/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4711 - accuracy: 0.7811
# Epoch 00101: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4688 - accuracy: 0.7813 - val_loss: 0.5331 - val_accuracy: 0.7217
# Epoch 102/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4658 - accuracy: 0.7807
# Epoch 00102: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4611 - accuracy: 0.7811 - val_loss: 0.5145 - val_accuracy: 0.7464
# Epoch 103/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4630 - accuracy: 0.7793
# Epoch 00103: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4579 - accuracy: 0.7794 - val_loss: 0.5298 - val_accuracy: 0.7239
# Epoch 104/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4594 - accuracy: 0.7785
# Epoch 00104: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4533 - accuracy: 0.7791 - val_loss: 0.5118 - val_accuracy: 0.7464
# Epoch 105/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4559 - accuracy: 0.7889
# Epoch 00105: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4573 - accuracy: 0.7891 - val_loss: 0.5101 - val_accuracy: 0.7464
# Epoch 106/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4564 - accuracy: 0.7843
# Epoch 00106: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4557 - accuracy: 0.7845 - val_loss: 0.5119 - val_accuracy: 0.7399
# Epoch 107/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4611 - accuracy: 0.7834
# Epoch 00107: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4583 - accuracy: 0.7836 - val_loss: 0.5372 - val_accuracy: 0.7232
# Epoch 108/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4520 - accuracy: 0.7876
# Epoch 00108: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4498 - accuracy: 0.7880 - val_loss: 0.5130 - val_accuracy: 0.7413
# Epoch 109/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4468 - accuracy: 0.7961
# Epoch 00109: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4507 - accuracy: 0.7958 - val_loss: 0.5237 - val_accuracy: 0.7326
# Epoch 110/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4555 - accuracy: 0.7960
# Epoch 00110: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4628 - accuracy: 0.7956 - val_loss: 0.5156 - val_accuracy: 0.7449
# Epoch 111/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4557 - accuracy: 0.7911
# Epoch 00111: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4510 - accuracy: 0.7914 - val_loss: 0.5150 - val_accuracy: 0.7399
# Epoch 112/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4430 - accuracy: 0.7905
# Epoch 00112: val_accuracy did not improve from 0.75000
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4423 - accuracy: 0.7907 - val_loss: 0.5253 - val_accuracy: 0.7370
# Epoch 113/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4500 - accuracy: 0.7854
# Epoch 00113: val_accuracy improved from 0.75000 to 0.75580, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_113.h5
# 44/44 [==============================] - 3s 76ms/step - loss: 0.4498 - accuracy: 0.7852 - val_loss: 0.5085 - val_accuracy: 0.7558
# Epoch 114/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4465 - accuracy: 0.7894
# Epoch 00114: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4443 - accuracy: 0.7896 - val_loss: 0.5120 - val_accuracy: 0.7377
# Epoch 115/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4439 - accuracy: 0.7898
# Epoch 00115: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4410 - accuracy: 0.7900 - val_loss: 0.5188 - val_accuracy: 0.7399
# Epoch 116/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4435 - accuracy: 0.7934
# Epoch 00116: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4428 - accuracy: 0.7934 - val_loss: 0.5366 - val_accuracy: 0.7254
# Epoch 117/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4528 - accuracy: 0.7867
# Epoch 00117: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4581 - accuracy: 0.7862 - val_loss: 0.5061 - val_accuracy: 0.7493
# Epoch 118/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4420 - accuracy: 0.7951
# Epoch 00118: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4454 - accuracy: 0.7947 - val_loss: 0.4982 - val_accuracy: 0.7551
# Epoch 119/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4328 - accuracy: 0.8000
# Epoch 00119: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4408 - accuracy: 0.7997 - val_loss: 0.4995 - val_accuracy: 0.7500
# Epoch 120/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4351 - accuracy: 0.7941
# Epoch 00120: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4360 - accuracy: 0.7939 - val_loss: 0.5407 - val_accuracy: 0.7283
# Epoch 121/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4332 - accuracy: 0.8025
# Epoch 00121: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4347 - accuracy: 0.8026 - val_loss: 0.5188 - val_accuracy: 0.7348
# Epoch 122/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4324 - accuracy: 0.7952
# Epoch 00122: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 74ms/step - loss: 0.4336 - accuracy: 0.7952 - val_loss: 0.5090 - val_accuracy: 0.7514
# Epoch 123/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4277 - accuracy: 0.8029
# Epoch 00123: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4320 - accuracy: 0.8023 - val_loss: 0.4940 - val_accuracy: 0.7529
# Epoch 124/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4301 - accuracy: 0.8005
# Epoch 00124: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4341 - accuracy: 0.8005 - val_loss: 0.5588 - val_accuracy: 0.7232
# Epoch 125/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4342 - accuracy: 0.7976
# Epoch 00125: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4318 - accuracy: 0.7978 - val_loss: 0.5072 - val_accuracy: 0.7435
# Epoch 126/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4287 - accuracy: 0.8060
# Epoch 00126: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4289 - accuracy: 0.8057 - val_loss: 0.5139 - val_accuracy: 0.7471
# Epoch 127/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4249 - accuracy: 0.8069
# Epoch 00127: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4273 - accuracy: 0.8068 - val_loss: 0.5384 - val_accuracy: 0.7348
# Epoch 128/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4388 - accuracy: 0.8005
# Epoch 00128: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4380 - accuracy: 0.8007 - val_loss: 0.5009 - val_accuracy: 0.7471
# Epoch 129/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4140 - accuracy: 0.8130
# Epoch 00129: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4164 - accuracy: 0.8128 - val_loss: 0.4933 - val_accuracy: 0.7449
# Epoch 130/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4156 - accuracy: 0.8101
# Epoch 00130: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4181 - accuracy: 0.8101 - val_loss: 0.4899 - val_accuracy: 0.7522
# Epoch 131/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4282 - accuracy: 0.8000
# Epoch 00131: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 77ms/step - loss: 0.4223 - accuracy: 0.8005 - val_loss: 0.5101 - val_accuracy: 0.7478
# Epoch 132/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4164 - accuracy: 0.8107
# Epoch 00132: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4157 - accuracy: 0.8106 - val_loss: 0.5056 - val_accuracy: 0.7391
# Epoch 133/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4067 - accuracy: 0.8136
# Epoch 00133: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4047 - accuracy: 0.8137 - val_loss: 0.5391 - val_accuracy: 0.7341
# Epoch 134/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4195 - accuracy: 0.8072
# Epoch 00134: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4175 - accuracy: 0.8074 - val_loss: 0.5081 - val_accuracy: 0.7420
# Epoch 135/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4196 - accuracy: 0.8061
# Epoch 00135: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4249 - accuracy: 0.8059 - val_loss: 0.5030 - val_accuracy: 0.7507
# Epoch 136/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4080 - accuracy: 0.8083
# Epoch 00136: val_accuracy did not improve from 0.75580
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4076 - accuracy: 0.8086 - val_loss: 0.5101 - val_accuracy: 0.7486
# Epoch 137/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4045 - accuracy: 0.8190
# Epoch 00137: val_accuracy improved from 0.75580 to 0.76159, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_137.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4021 - accuracy: 0.8193 - val_loss: 0.4889 - val_accuracy: 0.7616
# Epoch 138/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3998 - accuracy: 0.8169
# Epoch 00138: val_accuracy did not improve from 0.76159
# 44/44 [==============================] - 3s 69ms/step - loss: 0.3979 - accuracy: 0.8171 - val_loss: 0.5087 - val_accuracy: 0.7478
# Epoch 139/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4104 - accuracy: 0.8121
# Epoch 00139: val_accuracy did not improve from 0.76159
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4129 - accuracy: 0.8119 - val_loss: 0.5101 - val_accuracy: 0.7457
# Epoch 140/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4024 - accuracy: 0.8143
# Epoch 00140: val_accuracy did not improve from 0.76159
# 44/44 [==============================] - 3s 75ms/step - loss: 0.4047 - accuracy: 0.8141 - val_loss: 0.5003 - val_accuracy: 0.7529
# Epoch 141/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3997 - accuracy: 0.8169
# Epoch 00141: val_accuracy improved from 0.76159 to 0.76449, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/LogMEL+MFCC_CNN/MFCC_LogMEL_CNN_Binary_141.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.3981 - accuracy: 0.8168 - val_loss: 0.4892 - val_accuracy: 0.7645
# Epoch 142/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3913 - accuracy: 0.8229
# Epoch 00142: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.3932 - accuracy: 0.8224 - val_loss: 0.5079 - val_accuracy: 0.7565
# Epoch 143/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4081 - accuracy: 0.8121
# Epoch 00143: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4088 - accuracy: 0.8123 - val_loss: 0.5123 - val_accuracy: 0.7428
# Epoch 144/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4045 - accuracy: 0.8138
# Epoch 00144: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4070 - accuracy: 0.8137 - val_loss: 0.4969 - val_accuracy: 0.7457
# Epoch 145/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3868 - accuracy: 0.8241
# Epoch 00145: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.3921 - accuracy: 0.8238 - val_loss: 0.5021 - val_accuracy: 0.7529
# Epoch 146/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4005 - accuracy: 0.8154
# Epoch 00146: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4016 - accuracy: 0.8153 - val_loss: 0.5039 - val_accuracy: 0.7551
# Epoch 147/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3939 - accuracy: 0.8194
# Epoch 00147: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.3932 - accuracy: 0.8197 - val_loss: 0.5098 - val_accuracy: 0.7543
# Epoch 148/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3964 - accuracy: 0.8225
# Epoch 00148: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.3962 - accuracy: 0.8226 - val_loss: 0.4918 - val_accuracy: 0.7522
# Epoch 149/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3851 - accuracy: 0.8238
# Epoch 00149: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 74ms/step - loss: 0.3887 - accuracy: 0.8233 - val_loss: 0.5090 - val_accuracy: 0.7478
# Epoch 150/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3956 - accuracy: 0.8181
# Epoch 00150: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 4s 80ms/step - loss: 0.3927 - accuracy: 0.8184 - val_loss: 0.5032 - val_accuracy: 0.7507
# Epoch 151/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3916 - accuracy: 0.8243
# Epoch 00151: val_accuracy did not improve from 0.76449
# 44/44 [==============================] - 3s 69ms/step - loss: 0.3967 - accuracy: 0.8240 - val_loss: 0.4982 - val_accuracy: 0.7500
# Epoch 152/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3938 - accuracy: 0.8229
# Epoch 00152: val_accuracy did not improve from 0.76449
# ...
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1849 - accuracy: 0.9241 - val_loss: 0.6267 - val_accuracy: 0.7862
# Epoch 445/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1789 - accuracy: 0.9230
# Epoch 00445: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1756 - accuracy: 0.9232 - val_loss: 0.5756 - val_accuracy: 0.7964
# Epoch 446/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1879 - accuracy: 0.9246
# Epoch 00446: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1852 - accuracy: 0.9248 - val_loss: 0.5960 - val_accuracy: 0.7942
# Epoch 447/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1802 - accuracy: 0.9262
# Epoch 00447: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1859 - accuracy: 0.9261 - val_loss: 0.5851 - val_accuracy: 0.7891
# Epoch 448/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1799 - accuracy: 0.9268
# Epoch 00448: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1785 - accuracy: 0.9270 - val_loss: 0.6225 - val_accuracy: 0.7986
# Epoch 449/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.9230
# Epoch 00449: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1805 - accuracy: 0.9232 - val_loss: 0.5939 - val_accuracy: 0.7906
# Epoch 450/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1834 - accuracy: 0.9250
# Epoch 00450: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1813 - accuracy: 0.9250 - val_loss: 0.6482 - val_accuracy: 0.7790
# Epoch 451/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1986 - accuracy: 0.9184
# Epoch 00451: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1959 - accuracy: 0.9184 - val_loss: 0.6002 - val_accuracy: 0.7855
# Epoch 452/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1825 - accuracy: 0.9237
# Epoch 00452: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1806 - accuracy: 0.9237 - val_loss: 0.6321 - val_accuracy: 0.7855
# Epoch 453/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1879 - accuracy: 0.9266
# Epoch 00453: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1925 - accuracy: 0.9261 - val_loss: 0.6350 - val_accuracy: 0.7913
# Epoch 454/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2236 - accuracy: 0.9102
# Epoch 00454: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.2283 - accuracy: 0.9103 - val_loss: 0.5731 - val_accuracy: 0.7920
# Epoch 455/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1844 - accuracy: 0.9246
# Epoch 00455: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1828 - accuracy: 0.9248 - val_loss: 0.6153 - val_accuracy: 0.7819
# Epoch 456/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9239
# Epoch 00456: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1952 - accuracy: 0.9239 - val_loss: 0.5889 - val_accuracy: 0.8022
# Epoch 457/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1817 - accuracy: 0.9259
# Epoch 00457: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1782 - accuracy: 0.9261 - val_loss: 0.6175 - val_accuracy: 0.7935
# Epoch 458/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1823 - accuracy: 0.9261
# Epoch 00458: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1931 - accuracy: 0.9257 - val_loss: 0.5974 - val_accuracy: 0.8014
# Epoch 459/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1904 - accuracy: 0.9213
# Epoch 00459: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1905 - accuracy: 0.9213 - val_loss: 0.5852 - val_accuracy: 0.8036
# Epoch 460/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1950 - accuracy: 0.9201
# Epoch 00460: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1967 - accuracy: 0.9197 - val_loss: 0.5766 - val_accuracy: 0.7928
# Epoch 461/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1901 - accuracy: 0.9193
# Epoch 00461: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1927 - accuracy: 0.9194 - val_loss: 0.5958 - val_accuracy: 0.7855
# Epoch 462/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1861 - accuracy: 0.9242
# Epoch 00462: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1828 - accuracy: 0.9244 - val_loss: 0.5585 - val_accuracy: 0.7891
# Epoch 463/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1816 - accuracy: 0.9271
# Epoch 00463: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1799 - accuracy: 0.9273 - val_loss: 0.5811 - val_accuracy: 0.7993
# Epoch 464/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1772 - accuracy: 0.9315
# Epoch 00464: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1750 - accuracy: 0.9317 - val_loss: 0.5959 - val_accuracy: 0.7884
# Epoch 465/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1903 - accuracy: 0.9250
# Epoch 00465: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1885 - accuracy: 0.9252 - val_loss: 0.5842 - val_accuracy: 0.7855
# Epoch 466/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1827 - accuracy: 0.9255
# Epoch 00466: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1810 - accuracy: 0.9257 - val_loss: 0.6195 - val_accuracy: 0.7826
# Epoch 467/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1769 - accuracy: 0.9264
# Epoch 00467: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1764 - accuracy: 0.9264 - val_loss: 0.5853 - val_accuracy: 0.7957
# Epoch 468/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1783 - accuracy: 0.9273
# Epoch 00468: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1755 - accuracy: 0.9275 - val_loss: 0.5972 - val_accuracy: 0.7971
# Epoch 469/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1833 - accuracy: 0.9259
# Epoch 00469: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1861 - accuracy: 0.9259 - val_loss: 0.5782 - val_accuracy: 0.8000
# Epoch 470/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1861 - accuracy: 0.9228
# Epoch 00470: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1859 - accuracy: 0.9226 - val_loss: 0.5928 - val_accuracy: 0.7812
# Epoch 471/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1872 - accuracy: 0.9257
# Epoch 00471: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1854 - accuracy: 0.9257 - val_loss: 0.6023 - val_accuracy: 0.7833
# Epoch 472/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1827 - accuracy: 0.9244
# Epoch 00472: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1800 - accuracy: 0.9246 - val_loss: 0.5995 - val_accuracy: 0.7928
# Epoch 473/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1746 - accuracy: 0.9295
# Epoch 00473: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1756 - accuracy: 0.9291 - val_loss: 0.5851 - val_accuracy: 0.7833
# Epoch 474/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1775 - accuracy: 0.9255
# Epoch 00474: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1788 - accuracy: 0.9253 - val_loss: 0.5838 - val_accuracy: 0.7884
# Epoch 475/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1800 - accuracy: 0.9299
# Epoch 00475: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1802 - accuracy: 0.9299 - val_loss: 0.5645 - val_accuracy: 0.7884
# Epoch 476/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1839 - accuracy: 0.9255
# Epoch 00476: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1850 - accuracy: 0.9255 - val_loss: 0.5795 - val_accuracy: 0.7913
# Epoch 477/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1771 - accuracy: 0.9259
# Epoch 00477: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1738 - accuracy: 0.9261 - val_loss: 0.5848 - val_accuracy: 0.7870
# Epoch 478/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9257
# Epoch 00478: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1722 - accuracy: 0.9259 - val_loss: 0.6306 - val_accuracy: 0.7899
# Epoch 479/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1792 - accuracy: 0.9284
# Epoch 00479: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1821 - accuracy: 0.9282 - val_loss: 0.6071 - val_accuracy: 0.7848
# Epoch 480/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1815 - accuracy: 0.9295
# Epoch 00480: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1801 - accuracy: 0.9297 - val_loss: 0.6022 - val_accuracy: 0.7899
# Epoch 481/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1672 - accuracy: 0.9342
# Epoch 00481: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1689 - accuracy: 0.9340 - val_loss: 0.6091 - val_accuracy: 0.7899
# Epoch 482/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1808 - accuracy: 0.9288
# Epoch 00482: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1800 - accuracy: 0.9288 - val_loss: 0.6125 - val_accuracy: 0.7906
# Epoch 483/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1764 - accuracy: 0.9310
# Epoch 00483: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1750 - accuracy: 0.9311 - val_loss: 0.6215 - val_accuracy: 0.7920
# Epoch 484/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1756 - accuracy: 0.9297
# Epoch 00484: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1766 - accuracy: 0.9297 - val_loss: 0.6122 - val_accuracy: 0.7848
# Epoch 485/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1724 - accuracy: 0.9330
# Epoch 00485: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1727 - accuracy: 0.9329 - val_loss: 0.5884 - val_accuracy: 0.7986
# Epoch 486/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1842 - accuracy: 0.9279
# Epoch 00486: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1825 - accuracy: 0.9279 - val_loss: 0.5960 - val_accuracy: 0.7935
# Epoch 487/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1821 - accuracy: 0.9241
# Epoch 00487: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1843 - accuracy: 0.9239 - val_loss: 0.5626 - val_accuracy: 0.8022
# Epoch 488/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1809 - accuracy: 0.9311
# Epoch 00488: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1804 - accuracy: 0.9313 - val_loss: 0.6111 - val_accuracy: 0.7833
# Epoch 489/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1752 - accuracy: 0.9273
# Epoch 00489: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1727 - accuracy: 0.9275 - val_loss: 0.6197 - val_accuracy: 0.7848
# Epoch 490/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1686 - accuracy: 0.9308
# Epoch 00490: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1665 - accuracy: 0.9310 - val_loss: 0.6299 - val_accuracy: 0.7949
# Epoch 491/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1710 - accuracy: 0.9275
# Epoch 00491: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1733 - accuracy: 0.9273 - val_loss: 0.6096 - val_accuracy: 0.7884
# Epoch 492/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1790 - accuracy: 0.9286
# Epoch 00492: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1763 - accuracy: 0.9288 - val_loss: 0.6082 - val_accuracy: 0.7855
# Epoch 493/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1688 - accuracy: 0.9301
# Epoch 00493: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1665 - accuracy: 0.9302 - val_loss: 0.6288 - val_accuracy: 0.7884
# Epoch 494/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1780 - accuracy: 0.9271
# Epoch 00494: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1765 - accuracy: 0.9271 - val_loss: 0.6122 - val_accuracy: 0.7790
# Epoch 495/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1781 - accuracy: 0.9268
# Epoch 00495: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1789 - accuracy: 0.9268 - val_loss: 0.6257 - val_accuracy: 0.7768
# Epoch 496/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1791 - accuracy: 0.9246
# Epoch 00496: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1767 - accuracy: 0.9248 - val_loss: 0.6193 - val_accuracy: 0.7732
# Epoch 497/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1817 - accuracy: 0.9239
# Epoch 00497: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1783 - accuracy: 0.9241 - val_loss: 0.5898 - val_accuracy: 0.7870
# Epoch 498/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1767 - accuracy: 0.9248
# Epoch 00498: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1758 - accuracy: 0.9250 - val_loss: 0.6018 - val_accuracy: 0.7906
# Epoch 499/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.9302
# Epoch 00499: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1673 - accuracy: 0.9304 - val_loss: 0.6292 - val_accuracy: 0.7920
# Epoch 500/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1738 - accuracy: 0.9308
# Epoch 00500: val_accuracy did not improve from 0.80507
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1711 - accuracy: 0.9310 - val_loss: 0.6249 - val_accuracy: 0.7855
# Training completed in time:  0:26:17.120198
