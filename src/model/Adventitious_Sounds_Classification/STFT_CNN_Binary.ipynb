# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import pandas as pd
import wave
import sys
import os
import librosa
import librosa.display
import xgboost as xgb
from  sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import sklearn.naive_bayes as nb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier,GradientBoostingClassifier
from sklearn.neighbors import kd_tree
import seaborn as sn
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.kd_tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
# Load per cycle data frame
import pickle
folder = "/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/" 
filename = folder + 'w_c_dataset.pickle'
infile = open(filename,'rb')
[sound,sr,lengths,times,labels] = pickle.load(infile)
infile.close()

# %%
def split_sounds(sounds,times,labels):
    s=[]
    l=[]
    for i,sound in enumerate(sounds):
        for t,label in zip(times[i],labels[i]):
            s.append(sound[int(t[0]):int(t[1])])
            if label==0:
                a=np.array([1,0,0,0])
            if label==1:
                a=np.array([0,1,0,0])
            if label==2:
                a=np.array([0,0,1,0])    
            if label==3:
                a=np.array([0,0,0,1])
            l.append(a)
    return s,l

# %%
[data,label]=split_sounds(sound,times,labels)

# %%
#max_pad_len = 697
import librosa
from skimage.transform import resize

def extract_feature(X,sample_rate):
    n_fft=int(sample_rate*0.025)
    hop_length=int(sample_rate*0.01)
    stfts = librosa.core.stft(y=X,n_fft=n_fft)
    stfts = np.abs(stfts)
    stfts = resize(stfts, (40,670), mode = 'constant')
    return stfts

# %%
import sys
dataset = []
max_pad_len = float('-inf')
for d in data:
    a = extract_feature(d,sr[0])
    dataset.append(a)

# %%
dataset = np.array(dataset)
dataset.shape
# Out:
# (6898, 40, 670)

# %%
# add channel dimension for CNN
dataset = np.reshape(dataset, (*dataset.shape,1))

label=np.asarray(label)
a=np.zeros(label.shape[0])
for i in range(label.shape[0]):
    for j in range(label.shape[1]):
        if label[i][j]==1:
            a[i]=j

# COnvert to binary for the binary classification problem
bin_label =np.zeros(label.shape[0])
for index,l in enumerate(a):
    if l == 0:
        bin_label[index] = l
    else:
        bin_label[index] = 1

unique, counts = np.unique(bin_label, return_counts=True)

print(np.asarray((unique, counts)).T)


# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(bin_label)
oh_labels = to_categorical(i_labels)
# Out:
# [[0.000e+00 3.642e+03]
#  [1.000e+00 3.256e+03]]

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(dataset, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %%
num_rows = 40
num_columns = 670
num_channels = 1

num_labels = 2
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(32, activation='relu')) 

model.add(Dense(num_labels, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()



# Load the trained model if required
#model_file = '/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/MFC_CNN_Binary_197.h5'
#model.load_weights(model_file)

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 669, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 334, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 334, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 333, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 166, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 166, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 165, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 82, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 82, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 81, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 40, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 40, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 47,506
# Trainable params: 47,506
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 0s 9ms/step - loss: 0.6952 - accuracy: 0.5283
# Pre-training accuracy: 52.8261%

# %%
# train model
num_epochs = 1000
num_batch_size = 128



callbacks = [
    ModelCheckpoint(
        filepath='/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
          validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.6909 - accuracy: 0.5448
# Epoch 00001: val_accuracy improved from -inf to 0.53116, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_01.h5
# 44/44 [==============================] - 3s 79ms/step - loss: 0.6909 - accuracy: 0.5448 - val_loss: 0.6906 - val_accuracy: 0.5312
# Epoch 2/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6799 - accuracy: 0.5663
# Epoch 00002: val_accuracy improved from 0.53116 to 0.56159, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_02.h5
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6807 - accuracy: 0.5661 - val_loss: 0.6805 - val_accuracy: 0.5616
# Epoch 3/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6814 - accuracy: 0.5578
# Epoch 00003: val_accuracy did not improve from 0.56159
# 44/44 [==============================] - 2s 54ms/step - loss: 0.6820 - accuracy: 0.5574 - val_loss: 0.6815 - val_accuracy: 0.5464
# Epoch 4/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6766 - accuracy: 0.5716
# Epoch 00004: val_accuracy improved from 0.56159 to 0.56957, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_04.h5
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6750 - accuracy: 0.5716 - val_loss: 0.6758 - val_accuracy: 0.5696
# Epoch 5/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.6739 - accuracy: 0.5828
# Epoch 00005: val_accuracy improved from 0.56957 to 0.59928, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_05.h5
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6739 - accuracy: 0.5828 - val_loss: 0.6733 - val_accuracy: 0.5993
# Epoch 6/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6733 - accuracy: 0.5861
# Epoch 00006: val_accuracy did not improve from 0.59928
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6713 - accuracy: 0.5870 - val_loss: 0.6746 - val_accuracy: 0.5819
# Epoch 7/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6680 - accuracy: 0.5996
# Epoch 00007: val_accuracy did not improve from 0.59928
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6685 - accuracy: 0.5993 - val_loss: 0.6706 - val_accuracy: 0.5978
# Epoch 8/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6642 - accuracy: 0.6096
# Epoch 00008: val_accuracy improved from 0.59928 to 0.60072, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_08.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6637 - accuracy: 0.6095 - val_loss: 0.6664 - val_accuracy: 0.6007
# Epoch 9/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6617 - accuracy: 0.6114
# Epoch 00009: val_accuracy did not improve from 0.60072
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6604 - accuracy: 0.6115 - val_loss: 0.6651 - val_accuracy: 0.5891
# Epoch 10/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6631 - accuracy: 0.6114
# Epoch 00010: val_accuracy did not improve from 0.60072
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6620 - accuracy: 0.6118 - val_loss: 0.6689 - val_accuracy: 0.5978
# Epoch 11/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.6596 - accuracy: 0.6156
# Epoch 00011: val_accuracy did not improve from 0.60072
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6596 - accuracy: 0.6156 - val_loss: 0.6642 - val_accuracy: 0.5928
# Epoch 12/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6556 - accuracy: 0.6215
# Epoch 00012: val_accuracy did not improve from 0.60072
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6558 - accuracy: 0.6212 - val_loss: 0.6656 - val_accuracy: 0.5942
# Epoch 13/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6553 - accuracy: 0.6283
# Epoch 00013: val_accuracy did not improve from 0.60072
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6546 - accuracy: 0.6287 - val_loss: 0.6610 - val_accuracy: 0.5971
# Epoch 14/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6480 - accuracy: 0.6315
# Epoch 00014: val_accuracy improved from 0.60072 to 0.61884, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_14.h5
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6500 - accuracy: 0.6310 - val_loss: 0.6477 - val_accuracy: 0.6188
# Epoch 15/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6478 - accuracy: 0.6268
# Epoch 00015: val_accuracy improved from 0.61884 to 0.62971, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_15.h5
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6472 - accuracy: 0.6269 - val_loss: 0.6488 - val_accuracy: 0.6297
# Epoch 16/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6436 - accuracy: 0.6423
# Epoch 00016: val_accuracy did not improve from 0.62971
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6485 - accuracy: 0.6417 - val_loss: 0.6599 - val_accuracy: 0.6065
# Epoch 17/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6435 - accuracy: 0.6410
# Epoch 00017: val_accuracy did not improve from 0.62971
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6447 - accuracy: 0.6408 - val_loss: 0.6464 - val_accuracy: 0.6261
# Epoch 18/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6422 - accuracy: 0.6361
# Epoch 00018: val_accuracy did not improve from 0.62971
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6417 - accuracy: 0.6363 - val_loss: 0.6468 - val_accuracy: 0.6290
# Epoch 19/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6441 - accuracy: 0.6337
# Epoch 00019: val_accuracy improved from 0.62971 to 0.63043, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_19.h5
# 44/44 [==============================] - 2s 57ms/step - loss: 0.6455 - accuracy: 0.6332 - val_loss: 0.6443 - val_accuracy: 0.6304
# Epoch 20/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6354 - accuracy: 0.6463
# Epoch 00020: val_accuracy improved from 0.63043 to 0.63913, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_20.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6378 - accuracy: 0.6462 - val_loss: 0.6386 - val_accuracy: 0.6391
# Epoch 21/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6441 - accuracy: 0.6277
# Epoch 00021: val_accuracy did not improve from 0.63913
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6422 - accuracy: 0.6281 - val_loss: 0.6428 - val_accuracy: 0.6377
# Epoch 22/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6347 - accuracy: 0.6452
# Epoch 00022: val_accuracy did not improve from 0.63913
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6320 - accuracy: 0.6453 - val_loss: 0.6429 - val_accuracy: 0.6362
# Epoch 23/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6424 - accuracy: 0.6324
# Epoch 00023: val_accuracy did not improve from 0.63913
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6438 - accuracy: 0.6321 - val_loss: 0.6442 - val_accuracy: 0.6261
# Epoch 24/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6346 - accuracy: 0.6430
# Epoch 00024: val_accuracy did not improve from 0.63913
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6326 - accuracy: 0.6437 - val_loss: 0.6359 - val_accuracy: 0.6355
# Epoch 25/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6288 - accuracy: 0.6501
# Epoch 00025: val_accuracy did not improve from 0.63913
# 44/44 [==============================] - 2s 55ms/step - loss: 0.6284 - accuracy: 0.6501 - val_loss: 0.6339 - val_accuracy: 0.6355
# Epoch 26/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6245 - accuracy: 0.6566
# Epoch 00026: val_accuracy improved from 0.63913 to 0.63986, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_26.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6229 - accuracy: 0.6568 - val_loss: 0.6316 - val_accuracy: 0.6399
# Epoch 27/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6212 - accuracy: 0.6541
# Epoch 00027: val_accuracy improved from 0.63986 to 0.64420, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_27.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6229 - accuracy: 0.6539 - val_loss: 0.6348 - val_accuracy: 0.6442
# Epoch 28/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6213 - accuracy: 0.6552
# Epoch 00028: val_accuracy improved from 0.64420 to 0.65145, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_28.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6233 - accuracy: 0.6544 - val_loss: 0.6207 - val_accuracy: 0.6514
# Epoch 29/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6159 - accuracy: 0.6626
# Epoch 00029: val_accuracy did not improve from 0.65145
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6152 - accuracy: 0.6624 - val_loss: 0.6286 - val_accuracy: 0.6370
# Epoch 30/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6179 - accuracy: 0.6559
# Epoch 00030: val_accuracy improved from 0.65145 to 0.66232, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_30.h5
# 44/44 [==============================] - 3s 58ms/step - loss: 0.6156 - accuracy: 0.6566 - val_loss: 0.6156 - val_accuracy: 0.6623
# Epoch 31/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6121 - accuracy: 0.6568
# Epoch 00031: val_accuracy did not improve from 0.66232
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6105 - accuracy: 0.6569 - val_loss: 0.6222 - val_accuracy: 0.6558
# Epoch 32/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6110 - accuracy: 0.6599
# Epoch 00032: val_accuracy did not improve from 0.66232
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6114 - accuracy: 0.6598 - val_loss: 0.6230 - val_accuracy: 0.6594
# Epoch 33/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6119 - accuracy: 0.6622
# Epoch 00033: val_accuracy improved from 0.66232 to 0.66812, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_33.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6140 - accuracy: 0.6624 - val_loss: 0.6151 - val_accuracy: 0.6681
# Epoch 34/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6072 - accuracy: 0.6635
# Epoch 00034: val_accuracy did not improve from 0.66812
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6081 - accuracy: 0.6635 - val_loss: 0.6210 - val_accuracy: 0.6565
# Epoch 35/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6044 - accuracy: 0.6768
# Epoch 00035: val_accuracy improved from 0.66812 to 0.67319, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_35.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6036 - accuracy: 0.6767 - val_loss: 0.6174 - val_accuracy: 0.6732
# Epoch 36/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6058 - accuracy: 0.6684
# Epoch 00036: val_accuracy did not improve from 0.67319
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6038 - accuracy: 0.6689 - val_loss: 0.6171 - val_accuracy: 0.6594
# Epoch 37/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5953 - accuracy: 0.6770
# Epoch 00037: val_accuracy did not improve from 0.67319
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5937 - accuracy: 0.6776 - val_loss: 0.6139 - val_accuracy: 0.6703
# Epoch 38/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.6018 - accuracy: 0.6661
# Epoch 00038: val_accuracy did not improve from 0.67319
# 44/44 [==============================] - 2s 56ms/step - loss: 0.6015 - accuracy: 0.6662 - val_loss: 0.6071 - val_accuracy: 0.6667
# Epoch 39/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5993 - accuracy: 0.6751
# Epoch 00039: val_accuracy did not improve from 0.67319
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5978 - accuracy: 0.6754 - val_loss: 0.6043 - val_accuracy: 0.6652
# Epoch 40/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5906 - accuracy: 0.6820
# Epoch 00040: val_accuracy did not improve from 0.67319
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5930 - accuracy: 0.6818 - val_loss: 0.6110 - val_accuracy: 0.6674
# Epoch 41/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5944 - accuracy: 0.6835
# Epoch 00041: val_accuracy improved from 0.67319 to 0.68043, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_41.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.6008 - accuracy: 0.6834 - val_loss: 0.6052 - val_accuracy: 0.6804
# Epoch 42/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5962 - accuracy: 0.6784
# Epoch 00042: val_accuracy did not improve from 0.68043
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5941 - accuracy: 0.6783 - val_loss: 0.6094 - val_accuracy: 0.6768
# Epoch 43/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5923 - accuracy: 0.6831
# Epoch 00043: val_accuracy did not improve from 0.68043
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5913 - accuracy: 0.6838 - val_loss: 0.6063 - val_accuracy: 0.6804
# Epoch 44/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5900 - accuracy: 0.6868
# Epoch 00044: val_accuracy did not improve from 0.68043
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5850 - accuracy: 0.6876 - val_loss: 0.5994 - val_accuracy: 0.6790
# Epoch 45/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5919 - accuracy: 0.6871
# Epoch 00045: val_accuracy did not improve from 0.68043
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5898 - accuracy: 0.6874 - val_loss: 0.5998 - val_accuracy: 0.6783
# Epoch 46/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5902 - accuracy: 0.6853
# Epoch 00046: val_accuracy did not improve from 0.68043
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5901 - accuracy: 0.6856 - val_loss: 0.6167 - val_accuracy: 0.6486
# Epoch 47/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5801 - accuracy: 0.6942
# Epoch 00047: val_accuracy did not improve from 0.68043
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5789 - accuracy: 0.6943 - val_loss: 0.6164 - val_accuracy: 0.6659
# Epoch 48/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5801 - accuracy: 0.7022
# Epoch 00048: val_accuracy improved from 0.68043 to 0.68406, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_48.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.5805 - accuracy: 0.7021 - val_loss: 0.5971 - val_accuracy: 0.6841
# Epoch 49/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5811 - accuracy: 0.6870
# Epoch 00049: val_accuracy did not improve from 0.68406
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5784 - accuracy: 0.6874 - val_loss: 0.5951 - val_accuracy: 0.6812
# Epoch 50/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5820 - accuracy: 0.6926
# Epoch 00050: val_accuracy did not improve from 0.68406
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5858 - accuracy: 0.6919 - val_loss: 0.5912 - val_accuracy: 0.6841
# Epoch 51/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5731 - accuracy: 0.7024
# Epoch 00051: val_accuracy improved from 0.68406 to 0.68696, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_51.h5
# 44/44 [==============================] - 2s 57ms/step - loss: 0.5717 - accuracy: 0.7024 - val_loss: 0.5908 - val_accuracy: 0.6870
# Epoch 52/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5746 - accuracy: 0.6979
# Epoch 00052: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5692 - accuracy: 0.6986 - val_loss: 0.6130 - val_accuracy: 0.6775
# Epoch 53/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5759 - accuracy: 0.7013
# Epoch 00053: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5776 - accuracy: 0.7013 - val_loss: 0.5994 - val_accuracy: 0.6688
# Epoch 54/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5767 - accuracy: 0.6955
# Epoch 00054: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5765 - accuracy: 0.6955 - val_loss: 0.5960 - val_accuracy: 0.6804
# Epoch 55/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5720 - accuracy: 0.7000
# Epoch 00055: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5722 - accuracy: 0.7001 - val_loss: 0.6066 - val_accuracy: 0.6674
# Epoch 56/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.5787 - accuracy: 0.6957
# Epoch 00056: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5787 - accuracy: 0.6957 - val_loss: 0.6019 - val_accuracy: 0.6797
# Epoch 57/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5701 - accuracy: 0.7078
# Epoch 00057: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5664 - accuracy: 0.7084 - val_loss: 0.5931 - val_accuracy: 0.6775
# Epoch 58/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5700 - accuracy: 0.6988
# Epoch 00058: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5713 - accuracy: 0.6986 - val_loss: 0.5985 - val_accuracy: 0.6833
# Epoch 59/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5665 - accuracy: 0.7086
# Epoch 00059: val_accuracy did not improve from 0.68696
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5657 - accuracy: 0.7088 - val_loss: 0.5890 - val_accuracy: 0.6681
# Epoch 60/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5645 - accuracy: 0.7060
# Epoch 00060: val_accuracy improved from 0.68696 to 0.69058, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_60.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.5652 - accuracy: 0.7057 - val_loss: 0.5841 - val_accuracy: 0.6906
# Epoch 61/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5605 - accuracy: 0.7051
# Epoch 00061: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5633 - accuracy: 0.7050 - val_loss: 0.5881 - val_accuracy: 0.6746
# Epoch 62/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5602 - accuracy: 0.7135
# Epoch 00062: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5631 - accuracy: 0.7133 - val_loss: 0.5955 - val_accuracy: 0.6761
# Epoch 63/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5590 - accuracy: 0.7080
# Epoch 00063: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5542 - accuracy: 0.7084 - val_loss: 0.6066 - val_accuracy: 0.6710
# Epoch 64/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5661 - accuracy: 0.7060
# Epoch 00064: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5650 - accuracy: 0.7062 - val_loss: 0.6026 - val_accuracy: 0.6681
# Epoch 65/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5579 - accuracy: 0.7131
# Epoch 00065: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5568 - accuracy: 0.7133 - val_loss: 0.5979 - val_accuracy: 0.6754
# Epoch 66/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5636 - accuracy: 0.7108
# Epoch 00066: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5645 - accuracy: 0.7106 - val_loss: 0.6094 - val_accuracy: 0.6754
# Epoch 67/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5698 - accuracy: 0.7046
# Epoch 00067: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5704 - accuracy: 0.7044 - val_loss: 0.5933 - val_accuracy: 0.6732
# Epoch 68/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5624 - accuracy: 0.7069
# Epoch 00068: val_accuracy did not improve from 0.69058
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5587 - accuracy: 0.7073 - val_loss: 0.5869 - val_accuracy: 0.6804
# Epoch 69/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5609 - accuracy: 0.7113
# Epoch 00069: val_accuracy improved from 0.69058 to 0.69928, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_69.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.5606 - accuracy: 0.7113 - val_loss: 0.5773 - val_accuracy: 0.6993
# Epoch 70/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5589 - accuracy: 0.7126
# Epoch 00070: val_accuracy did not improve from 0.69928
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5632 - accuracy: 0.7119 - val_loss: 0.5948 - val_accuracy: 0.6797
# Epoch 71/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5607 - accuracy: 0.7133
# Epoch 00071: val_accuracy did not improve from 0.69928
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5585 - accuracy: 0.7137 - val_loss: 0.6188 - val_accuracy: 0.6609
# Epoch 72/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5636 - accuracy: 0.7031
# Epoch 00072: val_accuracy improved from 0.69928 to 0.70362, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_72.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.5620 - accuracy: 0.7033 - val_loss: 0.5823 - val_accuracy: 0.7036
# Epoch 73/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5481 - accuracy: 0.7238
# Epoch 00073: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5469 - accuracy: 0.7238 - val_loss: 0.5806 - val_accuracy: 0.6841
# Epoch 74/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.5453 - accuracy: 0.7265
# Epoch 00074: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5453 - accuracy: 0.7265 - val_loss: 0.5739 - val_accuracy: 0.6899
# Epoch 75/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5456 - accuracy: 0.7197
# Epoch 00075: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5454 - accuracy: 0.7196 - val_loss: 0.5848 - val_accuracy: 0.6964
# Epoch 76/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5472 - accuracy: 0.7211
# Epoch 00076: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5464 - accuracy: 0.7211 - val_loss: 0.5853 - val_accuracy: 0.6848
# Epoch 77/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5434 - accuracy: 0.7233
# Epoch 00077: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5457 - accuracy: 0.7231 - val_loss: 0.5912 - val_accuracy: 0.6833
# Epoch 78/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5517 - accuracy: 0.7193
# Epoch 00078: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 57ms/step - loss: 0.5496 - accuracy: 0.7195 - val_loss: 0.5867 - val_accuracy: 0.6862
# Epoch 79/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5441 - accuracy: 0.7235
# Epoch 00079: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5409 - accuracy: 0.7238 - val_loss: 0.5956 - val_accuracy: 0.6870
# Epoch 80/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5447 - accuracy: 0.7242
# Epoch 00080: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5471 - accuracy: 0.7240 - val_loss: 0.6093 - val_accuracy: 0.6812
# Epoch 81/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5438 - accuracy: 0.7255
# Epoch 00081: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 3s 59ms/step - loss: 0.5434 - accuracy: 0.7254 - val_loss: 0.5843 - val_accuracy: 0.6957
# Epoch 82/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5449 - accuracy: 0.7235
# Epoch 00082: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5381 - accuracy: 0.7240 - val_loss: 0.5828 - val_accuracy: 0.6935
# Epoch 83/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5342 - accuracy: 0.7338
# Epoch 00083: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5326 - accuracy: 0.7341 - val_loss: 0.6133 - val_accuracy: 0.6768
# Epoch 84/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5353 - accuracy: 0.7277
# Epoch 00084: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5340 - accuracy: 0.7278 - val_loss: 0.5820 - val_accuracy: 0.6920
# Epoch 85/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5348 - accuracy: 0.7318
# Epoch 00085: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5321 - accuracy: 0.7320 - val_loss: 0.5802 - val_accuracy: 0.6812
# Epoch 86/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5310 - accuracy: 0.7351
# Epoch 00086: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5330 - accuracy: 0.7350 - val_loss: 0.6024 - val_accuracy: 0.6783
# Epoch 87/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5317 - accuracy: 0.7249
# Epoch 00087: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5338 - accuracy: 0.7247 - val_loss: 0.5714 - val_accuracy: 0.7007
# Epoch 88/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5303 - accuracy: 0.7336
# Epoch 00088: val_accuracy did not improve from 0.70362
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5295 - accuracy: 0.7336 - val_loss: 0.5805 - val_accuracy: 0.6913
# Epoch 89/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5376 - accuracy: 0.7284
# Epoch 00089: val_accuracy improved from 0.70362 to 0.70435, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_89.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.5367 - accuracy: 0.7285 - val_loss: 0.5698 - val_accuracy: 0.7043
# Epoch 90/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5289 - accuracy: 0.7380
# Epoch 00090: val_accuracy did not improve from 0.70435
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5272 - accuracy: 0.7383 - val_loss: 0.5826 - val_accuracy: 0.6949
# Epoch 91/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5332 - accuracy: 0.7307
# Epoch 00091: val_accuracy did not improve from 0.70435
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5314 - accuracy: 0.7309 - val_loss: 0.5770 - val_accuracy: 0.7022
# Epoch 92/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5294 - accuracy: 0.7329
# Epoch 00092: val_accuracy did not improve from 0.70435
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5278 - accuracy: 0.7329 - val_loss: 0.5875 - val_accuracy: 0.6957
# Epoch 93/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.5226 - accuracy: 0.7379
# Epoch 00093: val_accuracy did not improve from 0.70435
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5226 - accuracy: 0.7379 - val_loss: 0.5731 - val_accuracy: 0.6978
# Epoch 94/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5237 - accuracy: 0.7364
# Epoch 00094: val_accuracy improved from 0.70435 to 0.71014, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_94.h5
# 44/44 [==============================] - 2s 57ms/step - loss: 0.5260 - accuracy: 0.7360 - val_loss: 0.5724 - val_accuracy: 0.7101
# Epoch 95/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5240 - accuracy: 0.7378
# Epoch 00095: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5243 - accuracy: 0.7378 - val_loss: 0.5730 - val_accuracy: 0.7051
# Epoch 96/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5290 - accuracy: 0.7311
# Epoch 00096: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5330 - accuracy: 0.7305 - val_loss: 0.5766 - val_accuracy: 0.7058
# Epoch 97/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5293 - accuracy: 0.7375
# Epoch 00097: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5239 - accuracy: 0.7379 - val_loss: 0.5655 - val_accuracy: 0.7014
# Epoch 98/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5263 - accuracy: 0.7398
# Epoch 00098: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5261 - accuracy: 0.7399 - val_loss: 0.6043 - val_accuracy: 0.6884
# Epoch 99/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5216 - accuracy: 0.7367
# Epoch 00099: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 57ms/step - loss: 0.5261 - accuracy: 0.7363 - val_loss: 0.5921 - val_accuracy: 0.6804
# Epoch 100/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5204 - accuracy: 0.7406
# Epoch 00100: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5191 - accuracy: 0.7407 - val_loss: 0.5971 - val_accuracy: 0.6942
# Epoch 101/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5226 - accuracy: 0.7395
# Epoch 00101: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 57ms/step - loss: 0.5258 - accuracy: 0.7392 - val_loss: 0.5749 - val_accuracy: 0.7022
# Epoch 102/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5255 - accuracy: 0.7415
# Epoch 00102: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5231 - accuracy: 0.7416 - val_loss: 0.5782 - val_accuracy: 0.6971
# Epoch 103/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5209 - accuracy: 0.7367
# Epoch 00103: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5198 - accuracy: 0.7369 - val_loss: 0.5783 - val_accuracy: 0.7007
# Epoch 104/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5103 - accuracy: 0.7495
# Epoch 00104: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5097 - accuracy: 0.7494 - val_loss: 0.5724 - val_accuracy: 0.7029
# Epoch 105/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5115 - accuracy: 0.7495
# Epoch 00105: val_accuracy did not improve from 0.71014
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5142 - accuracy: 0.7492 - val_loss: 0.5723 - val_accuracy: 0.6971
# Epoch 106/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5094 - accuracy: 0.7456
# Epoch 00106: val_accuracy improved from 0.71014 to 0.71667, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_106.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.5105 - accuracy: 0.7456 - val_loss: 0.5663 - val_accuracy: 0.7167
# Epoch 107/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5227 - accuracy: 0.7440
# Epoch 00107: val_accuracy did not improve from 0.71667
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5237 - accuracy: 0.7437 - val_loss: 0.5873 - val_accuracy: 0.6993
# Epoch 108/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5202 - accuracy: 0.7442
# Epoch 00108: val_accuracy did not improve from 0.71667
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5198 - accuracy: 0.7441 - val_loss: 0.5649 - val_accuracy: 0.7101
# Epoch 109/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.5139 - accuracy: 0.7396
# Epoch 00109: val_accuracy did not improve from 0.71667
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5139 - accuracy: 0.7396 - val_loss: 0.5874 - val_accuracy: 0.6986
# Epoch 110/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5113 - accuracy: 0.7440
# Epoch 00110: val_accuracy did not improve from 0.71667
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5107 - accuracy: 0.7441 - val_loss: 0.5842 - val_accuracy: 0.7123
# Epoch 111/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5116 - accuracy: 0.7504
# Epoch 00111: val_accuracy did not improve from 0.71667
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5124 - accuracy: 0.7499 - val_loss: 0.5806 - val_accuracy: 0.7029
# Epoch 112/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5164 - accuracy: 0.7460
# Epoch 00112: val_accuracy improved from 0.71667 to 0.71739, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_112.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.5189 - accuracy: 0.7461 - val_loss: 0.5685 - val_accuracy: 0.7174
# Epoch 113/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5041 - accuracy: 0.7518
# Epoch 00113: val_accuracy did not improve from 0.71739
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5060 - accuracy: 0.7517 - val_loss: 0.5919 - val_accuracy: 0.7000
# Epoch 114/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5302 - accuracy: 0.7444
# Epoch 00114: val_accuracy did not improve from 0.71739
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5356 - accuracy: 0.7441 - val_loss: 0.5735 - val_accuracy: 0.7130
# Epoch 115/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5029 - accuracy: 0.7462
# Epoch 00115: val_accuracy did not improve from 0.71739
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5070 - accuracy: 0.7457 - val_loss: 0.6043 - val_accuracy: 0.7007
# Epoch 116/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5102 - accuracy: 0.7444
# Epoch 00116: val_accuracy did not improve from 0.71739
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5056 - accuracy: 0.7447 - val_loss: 0.5815 - val_accuracy: 0.7058
# Epoch 117/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5064 - accuracy: 0.7504
# Epoch 00117: val_accuracy did not improve from 0.71739
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5073 - accuracy: 0.7505 - val_loss: 0.5901 - val_accuracy: 0.7145
# Epoch 118/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4988 - accuracy: 0.7553
# Epoch 00118: val_accuracy improved from 0.71739 to 0.72246, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_118.h5
# 44/44 [==============================] - 2s 57ms/step - loss: 0.4997 - accuracy: 0.7553 - val_loss: 0.5715 - val_accuracy: 0.7225
# Epoch 119/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4946 - accuracy: 0.7613
# Epoch 00119: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4975 - accuracy: 0.7613 - val_loss: 0.5685 - val_accuracy: 0.7087
# Epoch 120/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4983 - accuracy: 0.7589
# Epoch 00120: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 57ms/step - loss: 0.5008 - accuracy: 0.7586 - val_loss: 0.5864 - val_accuracy: 0.6928
# Epoch 121/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5037 - accuracy: 0.7489
# Epoch 00121: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5021 - accuracy: 0.7488 - val_loss: 0.5782 - val_accuracy: 0.7007
# Epoch 122/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5010 - accuracy: 0.7520
# Epoch 00122: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5046 - accuracy: 0.7515 - val_loss: 0.5879 - val_accuracy: 0.7072
# Epoch 123/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4989 - accuracy: 0.7558
# Epoch 00123: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4988 - accuracy: 0.7557 - val_loss: 0.5573 - val_accuracy: 0.7138
# Epoch 124/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4852 - accuracy: 0.7620
# Epoch 00124: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4938 - accuracy: 0.7615 - val_loss: 0.5556 - val_accuracy: 0.7225
# Epoch 125/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4907 - accuracy: 0.7587
# Epoch 00125: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4906 - accuracy: 0.7588 - val_loss: 0.5602 - val_accuracy: 0.7217
# Epoch 126/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4929 - accuracy: 0.7636
# Epoch 00126: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4915 - accuracy: 0.7639 - val_loss: 0.5653 - val_accuracy: 0.7116
# Epoch 127/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4906 - accuracy: 0.7582
# Epoch 00127: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 55ms/step - loss: 0.4873 - accuracy: 0.7582 - val_loss: 0.5567 - val_accuracy: 0.7138
# Epoch 128/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4891 - accuracy: 0.7604
# Epoch 00128: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4874 - accuracy: 0.7604 - val_loss: 0.5973 - val_accuracy: 0.6986
# Epoch 129/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4881 - accuracy: 0.7627
# Epoch 00129: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4838 - accuracy: 0.7631 - val_loss: 0.5975 - val_accuracy: 0.7051
# Epoch 130/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4959 - accuracy: 0.7518
# Epoch 00130: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4972 - accuracy: 0.7515 - val_loss: 0.5911 - val_accuracy: 0.7043
# Epoch 131/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4911 - accuracy: 0.7591
# Epoch 00131: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 57ms/step - loss: 0.4915 - accuracy: 0.7592 - val_loss: 0.5675 - val_accuracy: 0.7196
# Epoch 132/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4929 - accuracy: 0.7567
# Epoch 00132: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4907 - accuracy: 0.7570 - val_loss: 0.6473 - val_accuracy: 0.6819
# Epoch 133/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.5025 - accuracy: 0.7520
# Epoch 00133: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.5040 - accuracy: 0.7521 - val_loss: 0.5634 - val_accuracy: 0.7196
# Epoch 134/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.4891 - accuracy: 0.7608
# Epoch 00134: val_accuracy did not improve from 0.72246
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4891 - accuracy: 0.7608 - val_loss: 0.5862 - val_accuracy: 0.7123
# Epoch 135/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4822 - accuracy: 0.7669
# Epoch 00135: val_accuracy improved from 0.72246 to 0.73261, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_CNN_Binary/STFT_CNN_Binary_135.h5
# 44/44 [==============================] - 3s 57ms/step - loss: 0.4818 - accuracy: 0.7669 - val_loss: 0.5586 - val_accuracy: 0.7326
# Epoch 136/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4895 - accuracy: 0.7613
# Epoch 00136: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4902 - accuracy: 0.7611 - val_loss: 0.5687 - val_accuracy: 0.7138
# Epoch 137/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4781 - accuracy: 0.7642
# Epoch 00137: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4790 - accuracy: 0.7640 - val_loss: 0.5751 - val_accuracy: 0.7297
# Epoch 138/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4777 - accuracy: 0.7713
# Epoch 00138: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4802 - accuracy: 0.7711 - val_loss: 0.5604 - val_accuracy: 0.7326
# Epoch 139/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4826 - accuracy: 0.7680
# Epoch 00139: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4861 - accuracy: 0.7679 - val_loss: 0.5702 - val_accuracy: 0.7188
# Epoch 140/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4781 - accuracy: 0.7718
# Epoch 00140: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4757 - accuracy: 0.7720 - val_loss: 0.5593 - val_accuracy: 0.7297
# Epoch 141/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4851 - accuracy: 0.7711
# Epoch 00141: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4845 - accuracy: 0.7711 - val_loss: 0.5840 - val_accuracy: 0.7167
# Epoch 142/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.7673
# Epoch 00142: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 57ms/step - loss: 0.4908 - accuracy: 0.7664 - val_loss: 0.5959 - val_accuracy: 0.7225
# Epoch 143/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4823 - accuracy: 0.7694
# Epoch 00143: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4865 - accuracy: 0.7691 - val_loss: 0.6130 - val_accuracy: 0.7080
# Epoch 144/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4721 - accuracy: 0.7711
# Epoch 00144: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4692 - accuracy: 0.7715 - val_loss: 0.5677 - val_accuracy: 0.7246
# Epoch 145/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4680 - accuracy: 0.7713
# Epoch 00145: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4656 - accuracy: 0.7715 - val_loss: 0.5688 - val_accuracy: 0.7225
# Epoch 146/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4695 - accuracy: 0.7743
# Epoch 00146: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4723 - accuracy: 0.7744 - val_loss: 0.6603 - val_accuracy: 0.6957
# Epoch 147/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4853 - accuracy: 0.7604
# Epoch 00147: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 57ms/step - loss: 0.4864 - accuracy: 0.7602 - val_loss: 0.6325 - val_accuracy: 0.7101
# Epoch 148/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4848 - accuracy: 0.7638
# Epoch 00148: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4868 - accuracy: 0.7633 - val_loss: 0.5509 - val_accuracy: 0.7254
# Epoch 149/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4881 - accuracy: 0.7620
# Epoch 00149: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 57ms/step - loss: 0.4859 - accuracy: 0.7621 - val_loss: 0.5916 - val_accuracy: 0.7246
# Epoch 150/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4668 - accuracy: 0.7729
# Epoch 00150: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4649 - accuracy: 0.7729 - val_loss: 0.6257 - val_accuracy: 0.7138
# Epoch 151/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4588 - accuracy: 0.7753
# Epoch 00151: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 57ms/step - loss: 0.4641 - accuracy: 0.7753 - val_loss: 0.5875 - val_accuracy: 0.7261
# Epoch 152/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4816 - accuracy: 0.7716
# Epoch 00152: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4814 - accuracy: 0.7717 - val_loss: 0.5880 - val_accuracy: 0.7232
# Epoch 153/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.4807 - accuracy: 0.7689
# Epoch 00153: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4807 - accuracy: 0.7689 - val_loss: 0.6246 - val_accuracy: 0.7080
# Epoch 154/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4790 - accuracy: 0.7707
# Epoch 00154: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4777 - accuracy: 0.7706 - val_loss: 0.6309 - val_accuracy: 0.7138
# Epoch 155/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4653 - accuracy: 0.7718
# Epoch 00155: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 2s 56ms/step - loss: 0.4628 - accuracy: 0.7720 - val_loss: 0.5834 - val_accuracy: 0.7254
# Epoch 156/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.4651 - accuracy: 0.7745
# Epoch 00156: val_accuracy did not improve from 0.73261
# ...
# Epoch 945/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9175
# Epoch 00945: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2058 - accuracy: 0.9170 - val_loss: 0.6562 - val_accuracy: 0.8123
# Epoch 946/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2178 - accuracy: 0.9104
# Epoch 00946: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2157 - accuracy: 0.9105 - val_loss: 0.6378 - val_accuracy: 0.8174
# Epoch 947/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1848 - accuracy: 0.9242
# Epoch 00947: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1820 - accuracy: 0.9244 - val_loss: 0.6446 - val_accuracy: 0.8203
# Epoch 948/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1860 - accuracy: 0.9199
# Epoch 00948: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1924 - accuracy: 0.9195 - val_loss: 0.7244 - val_accuracy: 0.8087
# Epoch 949/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2188 - accuracy: 0.9064
# Epoch 00949: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2183 - accuracy: 0.9065 - val_loss: 0.6628 - val_accuracy: 0.8181
# Epoch 950/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2071 - accuracy: 0.9139
# Epoch 00950: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2045 - accuracy: 0.9139 - val_loss: 0.6939 - val_accuracy: 0.8065
# Epoch 951/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1869 - accuracy: 0.9250
# Epoch 00951: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1910 - accuracy: 0.9248 - val_loss: 0.6582 - val_accuracy: 0.8232
# Epoch 952/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2081 - accuracy: 0.9112
# Epoch 00952: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2051 - accuracy: 0.9114 - val_loss: 0.6697 - val_accuracy: 0.8051
# Epoch 953/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1939 - accuracy: 0.9201
# Epoch 00953: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1916 - accuracy: 0.9203 - val_loss: 0.6939 - val_accuracy: 0.8058
# Epoch 954/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.1984 - accuracy: 0.9163
# Epoch 00954: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1984 - accuracy: 0.9163 - val_loss: 0.6904 - val_accuracy: 0.8167
# Epoch 955/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1916 - accuracy: 0.9233
# Epoch 00955: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1939 - accuracy: 0.9233 - val_loss: 0.7018 - val_accuracy: 0.8072
# Epoch 956/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2056 - accuracy: 0.9128
# Epoch 00956: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2049 - accuracy: 0.9128 - val_loss: 0.7333 - val_accuracy: 0.8087
# Epoch 957/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.9197
# Epoch 00957: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1937 - accuracy: 0.9197 - val_loss: 0.7239 - val_accuracy: 0.8051
# Epoch 958/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1949 - accuracy: 0.9226
# Epoch 00958: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1951 - accuracy: 0.9224 - val_loss: 0.6601 - val_accuracy: 0.8196
# Epoch 959/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1922 - accuracy: 0.9199
# Epoch 00959: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2007 - accuracy: 0.9194 - val_loss: 0.6831 - val_accuracy: 0.8072
# Epoch 960/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2064 - accuracy: 0.9135
# Epoch 00960: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2049 - accuracy: 0.9136 - val_loss: 0.6703 - val_accuracy: 0.8072
# Epoch 961/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1850 - accuracy: 0.9231
# Epoch 00961: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1829 - accuracy: 0.9233 - val_loss: 0.7151 - val_accuracy: 0.8000
# Epoch 962/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1791 - accuracy: 0.9286
# Epoch 00962: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1774 - accuracy: 0.9288 - val_loss: 0.7089 - val_accuracy: 0.8036
# Epoch 963/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1854 - accuracy: 0.9261
# Epoch 00963: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1820 - accuracy: 0.9262 - val_loss: 0.7228 - val_accuracy: 0.7957
# Epoch 964/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1867 - accuracy: 0.9166
# Epoch 00964: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1866 - accuracy: 0.9166 - val_loss: 0.7134 - val_accuracy: 0.8116
# Epoch 965/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2033 - accuracy: 0.9155
# Epoch 00965: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2002 - accuracy: 0.9157 - val_loss: 0.7017 - val_accuracy: 0.8072
# Epoch 966/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9141
# Epoch 00966: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2015 - accuracy: 0.9139 - val_loss: 0.7378 - val_accuracy: 0.8029
# Epoch 967/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9161
# Epoch 00967: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2012 - accuracy: 0.9161 - val_loss: 0.7259 - val_accuracy: 0.8109
# Epoch 968/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9181
# Epoch 00968: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1946 - accuracy: 0.9183 - val_loss: 0.6997 - val_accuracy: 0.8007
# Epoch 969/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1834 - accuracy: 0.9239
# Epoch 00969: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1822 - accuracy: 0.9239 - val_loss: 0.7353 - val_accuracy: 0.8174
# Epoch 970/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1873 - accuracy: 0.9255
# Epoch 00970: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1863 - accuracy: 0.9255 - val_loss: 0.7726 - val_accuracy: 0.8094
# Epoch 971/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1882 - accuracy: 0.9233
# Epoch 00971: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1857 - accuracy: 0.9235 - val_loss: 0.7302 - val_accuracy: 0.8109
# Epoch 972/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.2038 - accuracy: 0.9134
# Epoch 00972: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2038 - accuracy: 0.9134 - val_loss: 0.7706 - val_accuracy: 0.8065
# Epoch 973/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2026 - accuracy: 0.9184
# Epoch 00973: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2046 - accuracy: 0.9181 - val_loss: 0.7759 - val_accuracy: 0.8022
# Epoch 974/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9173
# Epoch 00974: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1974 - accuracy: 0.9174 - val_loss: 0.7094 - val_accuracy: 0.8116
# Epoch 975/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1881 - accuracy: 0.9248
# Epoch 00975: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1867 - accuracy: 0.9248 - val_loss: 0.7141 - val_accuracy: 0.8036
# Epoch 976/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1919 - accuracy: 0.9226
# Epoch 00976: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2014 - accuracy: 0.9221 - val_loss: 0.6948 - val_accuracy: 0.8181
# Epoch 977/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2345 - accuracy: 0.9028
# Epoch 00977: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2357 - accuracy: 0.9027 - val_loss: 0.6906 - val_accuracy: 0.8007
# Epoch 978/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1938 - accuracy: 0.9170
# Epoch 00978: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1921 - accuracy: 0.9170 - val_loss: 0.6968 - val_accuracy: 0.8058
# Epoch 979/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1977 - accuracy: 0.9221
# Epoch 00979: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1944 - accuracy: 0.9223 - val_loss: 0.7036 - val_accuracy: 0.8087
# Epoch 980/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1890 - accuracy: 0.9195
# Epoch 00980: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1922 - accuracy: 0.9192 - val_loss: 0.7314 - val_accuracy: 0.8145
# Epoch 981/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1959 - accuracy: 0.9150
# Epoch 00981: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2052 - accuracy: 0.9150 - val_loss: 0.6889 - val_accuracy: 0.8174
# Epoch 982/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1886 - accuracy: 0.9231
# Epoch 00982: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1879 - accuracy: 0.9232 - val_loss: 0.6831 - val_accuracy: 0.8051
# Epoch 983/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1848 - accuracy: 0.9215
# Epoch 00983: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1825 - accuracy: 0.9217 - val_loss: 0.7142 - val_accuracy: 0.7964
# Epoch 984/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2065 - accuracy: 0.9126
# Epoch 00984: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2172 - accuracy: 0.9125 - val_loss: 0.7045 - val_accuracy: 0.8145
# Epoch 985/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2029 - accuracy: 0.9146
# Epoch 00985: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2046 - accuracy: 0.9146 - val_loss: 0.7992 - val_accuracy: 0.7906
# Epoch 986/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1971 - accuracy: 0.9175
# Epoch 00986: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1948 - accuracy: 0.9177 - val_loss: 0.7024 - val_accuracy: 0.8043
# Epoch 987/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1825 - accuracy: 0.9246
# Epoch 00987: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1840 - accuracy: 0.9244 - val_loss: 0.6996 - val_accuracy: 0.8051
# Epoch 988/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1866 - accuracy: 0.9213
# Epoch 00988: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1895 - accuracy: 0.9212 - val_loss: 0.7267 - val_accuracy: 0.8094
# Epoch 989/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1842 - accuracy: 0.9244
# Epoch 00989: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1821 - accuracy: 0.9246 - val_loss: 0.6881 - val_accuracy: 0.8051
# Epoch 990/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1802 - accuracy: 0.9253
# Epoch 00990: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1807 - accuracy: 0.9253 - val_loss: 0.7014 - val_accuracy: 0.8036
# Epoch 991/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1945 - accuracy: 0.9197
# Epoch 00991: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1940 - accuracy: 0.9197 - val_loss: 0.7204 - val_accuracy: 0.8130
# Epoch 992/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1976 - accuracy: 0.9155
# Epoch 00992: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1951 - accuracy: 0.9157 - val_loss: 0.7495 - val_accuracy: 0.8022
# Epoch 993/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1837 - accuracy: 0.9246
# Epoch 00993: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1884 - accuracy: 0.9242 - val_loss: 0.7318 - val_accuracy: 0.8174
# Epoch 994/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2022 - accuracy: 0.9190
# Epoch 00994: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.2016 - accuracy: 0.9190 - val_loss: 0.7010 - val_accuracy: 0.8022
# Epoch 995/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2106 - accuracy: 0.9121
# Epoch 00995: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.2079 - accuracy: 0.9123 - val_loss: 0.7003 - val_accuracy: 0.8051
# Epoch 996/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9204
# Epoch 00996: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 55ms/step - loss: 0.1894 - accuracy: 0.9206 - val_loss: 0.7257 - val_accuracy: 0.8007
# Epoch 997/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.1761 - accuracy: 0.9213
# Epoch 00997: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1761 - accuracy: 0.9213 - val_loss: 0.7025 - val_accuracy: 0.7942
# Epoch 998/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1867 - accuracy: 0.9215
# Epoch 00998: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1845 - accuracy: 0.9217 - val_loss: 0.6414 - val_accuracy: 0.8116
# Epoch 999/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1925 - accuracy: 0.9186
# Epoch 00999: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1937 - accuracy: 0.9183 - val_loss: 0.6582 - val_accuracy: 0.8145
# Epoch 1000/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.1961 - accuracy: 0.9134
# Epoch 01000: val_accuracy did not improve from 0.82464
# 44/44 [==============================] - 2s 56ms/step - loss: 0.1961 - accuracy: 0.9134 - val_loss: 0.7060 - val_accuracy: 0.8022
# Training completed in time:  0:41:51.193318
