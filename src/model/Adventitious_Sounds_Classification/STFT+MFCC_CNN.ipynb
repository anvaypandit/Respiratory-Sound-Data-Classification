# %%
# Dummy code to get more RAM on google colab
#a = []
#while(1):
 #   a.append('1')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import pandas as pd
import wave
import sys
import os
import librosa
import librosa.display
import xgboost as xgb
from  sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import sklearn.naive_bayes as nb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier,GradientBoostingClassifier
from sklearn.neighbors import kd_tree
import seaborn as sn
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.kd_tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
# Load per cycle data frame
import pickle
folder = "/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/" 
filename = folder + 'w_c_dataset.pickle'
infile = open(filename,'rb')
[sound,sr,lengths,times,labels] = pickle.load(infile)
infile.close()

# %%
max_pad_len = 697
import librosa
from skimage.transform import resize
def extract_feature(X,sample_rate):
    n_fft=int(sample_rate*0.025)
    hop_length=int(sample_rate*0.01)

    stfts = librosa.core.stft(y=X,n_fft=n_fft)
    stfts = np.abs(stfts)
    stfts = resize(stfts, (40,697), mode = 'constant')
    mfccs = librosa.feature.mfcc(y=X, sr=sample_rate,n_mfcc=40)
    # Pad  mfcc till the end
    pad_width_mfcc = max_pad_len - mfccs.shape[1]
    pad_width_stfts = max_pad_len - stfts.shape[1]
    
    mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width_mfcc)), mode='constant')
    stfts = np.pad(stfts, pad_width=((0, 0), (0, pad_width_stfts)), mode='constant')

    
    return np.vstack((mfccs,stfts))

# %%
import sys

def split_sounds(sounds,times,labels):
    s=[]
    l=[]
    for i,sound in enumerate(sounds):
        for t,label in zip(times[i],labels[i]):
            s.append(sound[int(t[0]):int(t[1])])
            if label==0:
                a=np.array([1,0,0,0])
            if label==1:
                a=np.array([0,1,0,0])
            if label==2:
                a=np.array([0,0,1,0])    
            if label==3:
                a=np.array([0,0,0,1])
            l.append(a)
    return s,l

[data,label]=split_sounds(sound,times,labels)
dataset = []
for d in data:
    a = extract_feature(d,sr[0])
    dataset.append(a)

# %%
dataset = np.array(dataset)
dataset.shape
# Out:
# (6898, 80, 697)

# %%
# add channel dimension for CNN
dataset = np.reshape(dataset, (*dataset.shape,1))

label=np.asarray(label)
a=np.zeros(label.shape[0])
for i in range(label.shape[0]):
    for j in range(label.shape[1]):
        if label[i][j]==1:
            a[i]=j

# COnvert to binary for the binary classification problem
bin_label =np.zeros(label.shape[0])
for index,l in enumerate(a):
    if l == 0:
        bin_label[index] = l
    else:
        bin_label[index] = 1

unique, counts = np.unique(bin_label, return_counts=True)

print(np.asarray((unique, counts)).T)


# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(bin_label)
oh_labels = to_categorical(i_labels)
# Out:
# [[0.000e+00 3.642e+03]
#  [1.000e+00 3.256e+03]]

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(dataset, oh_labels, stratify=oh_labels, 
                                                    test_size=0.2, random_state = 42)

# %%
num_rows = 80
num_columns = 697
num_channels = 1

num_labels = 2
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(32, activation='relu')) 

model.add(Dense(num_labels, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()



# Load the trained model if required
#model_file = '/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/MFC_CNN_Binary_197.h5'
#model.load_weights(model_file)

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 79, 696, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 39, 348, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 39, 348, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 38, 347, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 19, 173, 32)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 19, 173, 32)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 18, 172, 64)       8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 86, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 86, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 85, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 42, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4, 42, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 47,506
# Trainable params: 47,506
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 0s 9ms/step - loss: 0.7609 - accuracy: 0.4717
# Pre-training accuracy: 47.1739%

# %%
# train model
num_epochs = 500
num_batch_size = 128



callbacks = [
    ModelCheckpoint(
        filepath='/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
          validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/500
# 44/44 [==============================] - ETA: 0s - loss: 0.6968 - accuracy: 0.5256
# Epoch 00001: val_accuracy improved from -inf to 0.53913, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_01.h5
# 44/44 [==============================] - 5s 116ms/step - loss: 0.6968 - accuracy: 0.5256 - val_loss: 0.6884 - val_accuracy: 0.5391
# Epoch 2/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6864 - accuracy: 0.5618
# Epoch 00002: val_accuracy improved from 0.53913 to 0.56739, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_02.h5
# 44/44 [==============================] - 4s 91ms/step - loss: 0.6856 - accuracy: 0.5618 - val_loss: 0.6841 - val_accuracy: 0.5674
# Epoch 3/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6817 - accuracy: 0.5741
# Epoch 00003: val_accuracy improved from 0.56739 to 0.57319, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_03.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.6789 - accuracy: 0.5748 - val_loss: 0.6791 - val_accuracy: 0.5732
# Epoch 4/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6720 - accuracy: 0.5932
# Epoch 00004: val_accuracy improved from 0.57319 to 0.60217, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_04.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.6706 - accuracy: 0.5935 - val_loss: 0.6713 - val_accuracy: 0.6022
# Epoch 5/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6656 - accuracy: 0.6065
# Epoch 00005: val_accuracy did not improve from 0.60217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6651 - accuracy: 0.6064 - val_loss: 0.6695 - val_accuracy: 0.5696
# Epoch 6/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6572 - accuracy: 0.6063
# Epoch 00006: val_accuracy improved from 0.60217 to 0.62464, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_06.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6565 - accuracy: 0.6067 - val_loss: 0.6609 - val_accuracy: 0.6246
# Epoch 7/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6485 - accuracy: 0.6261
# Epoch 00007: val_accuracy did not improve from 0.62464
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6491 - accuracy: 0.6261 - val_loss: 0.6588 - val_accuracy: 0.6123
# Epoch 8/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6429 - accuracy: 0.6348
# Epoch 00008: val_accuracy improved from 0.62464 to 0.64203, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_08.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.6442 - accuracy: 0.6347 - val_loss: 0.6521 - val_accuracy: 0.6420
# Epoch 9/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6415 - accuracy: 0.6374
# Epoch 00009: val_accuracy did not improve from 0.64203
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6403 - accuracy: 0.6375 - val_loss: 0.6613 - val_accuracy: 0.6029
# Epoch 10/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6377 - accuracy: 0.6428
# Epoch 00010: val_accuracy did not improve from 0.64203
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6372 - accuracy: 0.6430 - val_loss: 0.6547 - val_accuracy: 0.6152
# Epoch 11/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6337 - accuracy: 0.6366
# Epoch 00011: val_accuracy did not improve from 0.64203
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6393 - accuracy: 0.6361 - val_loss: 0.6436 - val_accuracy: 0.6420
# Epoch 12/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6350 - accuracy: 0.6463
# Epoch 00012: val_accuracy improved from 0.64203 to 0.64638, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_12.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.6363 - accuracy: 0.6459 - val_loss: 0.6465 - val_accuracy: 0.6464
# Epoch 13/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6294 - accuracy: 0.6506
# Epoch 00013: val_accuracy did not improve from 0.64638
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6297 - accuracy: 0.6502 - val_loss: 0.6420 - val_accuracy: 0.6464
# Epoch 14/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6328 - accuracy: 0.6473
# Epoch 00014: val_accuracy did not improve from 0.64638
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6305 - accuracy: 0.6477 - val_loss: 0.6416 - val_accuracy: 0.6464
# Epoch 15/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6249 - accuracy: 0.6581
# Epoch 00015: val_accuracy did not improve from 0.64638
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6259 - accuracy: 0.6578 - val_loss: 0.6451 - val_accuracy: 0.6413
# Epoch 16/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6280 - accuracy: 0.6544
# Epoch 00016: val_accuracy did not improve from 0.64638
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6286 - accuracy: 0.6544 - val_loss: 0.6439 - val_accuracy: 0.6391
# Epoch 17/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6260 - accuracy: 0.6528
# Epoch 00017: val_accuracy did not improve from 0.64638
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6256 - accuracy: 0.6528 - val_loss: 0.6393 - val_accuracy: 0.6449
# Epoch 18/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6239 - accuracy: 0.6584
# Epoch 00018: val_accuracy improved from 0.64638 to 0.65362, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_18.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6253 - accuracy: 0.6580 - val_loss: 0.6372 - val_accuracy: 0.6536
# Epoch 19/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6232 - accuracy: 0.6601
# Epoch 00019: val_accuracy did not improve from 0.65362
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6244 - accuracy: 0.6600 - val_loss: 0.6356 - val_accuracy: 0.6514
# Epoch 20/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6187 - accuracy: 0.6572
# Epoch 00020: val_accuracy did not improve from 0.65362
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6198 - accuracy: 0.6571 - val_loss: 0.6379 - val_accuracy: 0.6449
# Epoch 21/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6189 - accuracy: 0.6615
# Epoch 00021: val_accuracy did not improve from 0.65362
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6197 - accuracy: 0.6609 - val_loss: 0.6341 - val_accuracy: 0.6529
# Epoch 22/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6244 - accuracy: 0.6526
# Epoch 00022: val_accuracy did not improve from 0.65362
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6241 - accuracy: 0.6526 - val_loss: 0.6379 - val_accuracy: 0.6435
# Epoch 23/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6177 - accuracy: 0.6624
# Epoch 00023: val_accuracy did not improve from 0.65362
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6196 - accuracy: 0.6622 - val_loss: 0.6294 - val_accuracy: 0.6464
# Epoch 24/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6120 - accuracy: 0.6731
# Epoch 00024: val_accuracy did not improve from 0.65362
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6118 - accuracy: 0.6733 - val_loss: 0.6320 - val_accuracy: 0.6471
# Epoch 25/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6142 - accuracy: 0.6686
# Epoch 00025: val_accuracy did not improve from 0.65362
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6122 - accuracy: 0.6687 - val_loss: 0.6320 - val_accuracy: 0.6457
# Epoch 26/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6098 - accuracy: 0.6686
# Epoch 00026: val_accuracy improved from 0.65362 to 0.65870, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_26.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6112 - accuracy: 0.6684 - val_loss: 0.6242 - val_accuracy: 0.6587
# Epoch 27/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6045 - accuracy: 0.6721
# Epoch 00027: val_accuracy did not improve from 0.65870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6031 - accuracy: 0.6723 - val_loss: 0.6254 - val_accuracy: 0.6442
# Epoch 28/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6111 - accuracy: 0.6690
# Epoch 00028: val_accuracy improved from 0.65870 to 0.66232, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_28.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.6119 - accuracy: 0.6687 - val_loss: 0.6190 - val_accuracy: 0.6623
# Epoch 29/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6068 - accuracy: 0.6766
# Epoch 00029: val_accuracy did not improve from 0.66232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6064 - accuracy: 0.6765 - val_loss: 0.6209 - val_accuracy: 0.6529
# Epoch 30/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6081 - accuracy: 0.6713
# Epoch 00030: val_accuracy improved from 0.66232 to 0.66449, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_30.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.6093 - accuracy: 0.6713 - val_loss: 0.6184 - val_accuracy: 0.6645
# Epoch 31/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5989 - accuracy: 0.6846
# Epoch 00031: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5992 - accuracy: 0.6847 - val_loss: 0.6163 - val_accuracy: 0.6572
# Epoch 32/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5991 - accuracy: 0.6791
# Epoch 00032: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5979 - accuracy: 0.6794 - val_loss: 0.6268 - val_accuracy: 0.6457
# Epoch 33/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5969 - accuracy: 0.6880
# Epoch 00033: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5999 - accuracy: 0.6876 - val_loss: 0.6213 - val_accuracy: 0.6609
# Epoch 34/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.6139 - accuracy: 0.6552
# Epoch 00034: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.6173 - accuracy: 0.6549 - val_loss: 0.6211 - val_accuracy: 0.6543
# Epoch 35/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5977 - accuracy: 0.6782
# Epoch 00035: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5974 - accuracy: 0.6783 - val_loss: 0.6160 - val_accuracy: 0.6558
# Epoch 36/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5919 - accuracy: 0.6775
# Epoch 00036: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5909 - accuracy: 0.6776 - val_loss: 0.6179 - val_accuracy: 0.6420
# Epoch 37/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5912 - accuracy: 0.6848
# Epoch 00037: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5887 - accuracy: 0.6848 - val_loss: 0.6126 - val_accuracy: 0.6630
# Epoch 38/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5884 - accuracy: 0.6853
# Epoch 00038: val_accuracy did not improve from 0.66449
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5938 - accuracy: 0.6843 - val_loss: 0.6127 - val_accuracy: 0.6616
# Epoch 39/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5895 - accuracy: 0.6882
# Epoch 00039: val_accuracy improved from 0.66449 to 0.66522, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_39.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.5880 - accuracy: 0.6887 - val_loss: 0.6150 - val_accuracy: 0.6652
# Epoch 40/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5952 - accuracy: 0.6802
# Epoch 00040: val_accuracy did not improve from 0.66522
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5941 - accuracy: 0.6805 - val_loss: 0.6141 - val_accuracy: 0.6529
# Epoch 41/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5937 - accuracy: 0.6819
# Epoch 00041: val_accuracy did not improve from 0.66522
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5963 - accuracy: 0.6814 - val_loss: 0.6052 - val_accuracy: 0.6623
# Epoch 42/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5864 - accuracy: 0.6922
# Epoch 00042: val_accuracy did not improve from 0.66522
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5868 - accuracy: 0.6921 - val_loss: 0.6185 - val_accuracy: 0.6551
# Epoch 43/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5834 - accuracy: 0.6926
# Epoch 00043: val_accuracy did not improve from 0.66522
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5859 - accuracy: 0.6921 - val_loss: 0.6128 - val_accuracy: 0.6580
# Epoch 44/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5850 - accuracy: 0.6846
# Epoch 00044: val_accuracy improved from 0.66522 to 0.66957, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_44.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5837 - accuracy: 0.6847 - val_loss: 0.6004 - val_accuracy: 0.6696
# Epoch 45/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5737 - accuracy: 0.6966
# Epoch 00045: val_accuracy did not improve from 0.66957
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5711 - accuracy: 0.6968 - val_loss: 0.6001 - val_accuracy: 0.6688
# Epoch 46/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5737 - accuracy: 0.7019
# Epoch 00046: val_accuracy did not improve from 0.66957
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5715 - accuracy: 0.7021 - val_loss: 0.6133 - val_accuracy: 0.6638
# Epoch 47/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5760 - accuracy: 0.6913
# Epoch 00047: val_accuracy improved from 0.66957 to 0.68623, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_47.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5756 - accuracy: 0.6914 - val_loss: 0.5963 - val_accuracy: 0.6862
# Epoch 48/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5784 - accuracy: 0.6899
# Epoch 00048: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5757 - accuracy: 0.6903 - val_loss: 0.6064 - val_accuracy: 0.6594
# Epoch 49/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5693 - accuracy: 0.7077
# Epoch 00049: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5672 - accuracy: 0.7079 - val_loss: 0.5952 - val_accuracy: 0.6681
# Epoch 50/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5680 - accuracy: 0.7019
# Epoch 00050: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5644 - accuracy: 0.7021 - val_loss: 0.6058 - val_accuracy: 0.6601
# Epoch 51/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5659 - accuracy: 0.7039
# Epoch 00051: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5623 - accuracy: 0.7042 - val_loss: 0.6131 - val_accuracy: 0.6558
# Epoch 52/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5734 - accuracy: 0.6924
# Epoch 00052: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5712 - accuracy: 0.6926 - val_loss: 0.6390 - val_accuracy: 0.6275
# Epoch 53/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5647 - accuracy: 0.7013
# Epoch 00053: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5653 - accuracy: 0.7017 - val_loss: 0.5996 - val_accuracy: 0.6696
# Epoch 54/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5619 - accuracy: 0.7049
# Epoch 00054: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5608 - accuracy: 0.7050 - val_loss: 0.5906 - val_accuracy: 0.6725
# Epoch 55/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5597 - accuracy: 0.7073
# Epoch 00055: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5611 - accuracy: 0.7070 - val_loss: 0.5902 - val_accuracy: 0.6804
# Epoch 56/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5568 - accuracy: 0.7089
# Epoch 00056: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5571 - accuracy: 0.7088 - val_loss: 0.5938 - val_accuracy: 0.6790
# Epoch 57/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5610 - accuracy: 0.7019
# Epoch 00057: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5620 - accuracy: 0.7017 - val_loss: 0.5982 - val_accuracy: 0.6688
# Epoch 58/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5554 - accuracy: 0.7082
# Epoch 00058: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5577 - accuracy: 0.7080 - val_loss: 0.5966 - val_accuracy: 0.6674
# Epoch 59/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5595 - accuracy: 0.7040
# Epoch 00059: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5596 - accuracy: 0.7044 - val_loss: 0.5866 - val_accuracy: 0.6710
# Epoch 60/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5576 - accuracy: 0.7093
# Epoch 00060: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5564 - accuracy: 0.7093 - val_loss: 0.5865 - val_accuracy: 0.6725
# Epoch 61/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5505 - accuracy: 0.7148
# Epoch 00061: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5514 - accuracy: 0.7148 - val_loss: 0.5926 - val_accuracy: 0.6710
# Epoch 62/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5526 - accuracy: 0.7093
# Epoch 00062: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5592 - accuracy: 0.7086 - val_loss: 0.5870 - val_accuracy: 0.6681
# Epoch 63/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5454 - accuracy: 0.7164
# Epoch 00063: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5447 - accuracy: 0.7164 - val_loss: 0.5799 - val_accuracy: 0.6783
# Epoch 64/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5402 - accuracy: 0.7189
# Epoch 00064: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5358 - accuracy: 0.7193 - val_loss: 0.5818 - val_accuracy: 0.6841
# Epoch 65/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5446 - accuracy: 0.7218
# Epoch 00065: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5458 - accuracy: 0.7216 - val_loss: 0.5854 - val_accuracy: 0.6725
# Epoch 66/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5491 - accuracy: 0.7182
# Epoch 00066: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5475 - accuracy: 0.7182 - val_loss: 0.5857 - val_accuracy: 0.6775
# Epoch 67/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5410 - accuracy: 0.7193
# Epoch 00067: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5414 - accuracy: 0.7193 - val_loss: 0.5837 - val_accuracy: 0.6783
# Epoch 68/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5448 - accuracy: 0.7182
# Epoch 00068: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5413 - accuracy: 0.7186 - val_loss: 0.5758 - val_accuracy: 0.6855
# Epoch 69/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5479 - accuracy: 0.7153
# Epoch 00069: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5469 - accuracy: 0.7153 - val_loss: 0.5791 - val_accuracy: 0.6819
# Epoch 70/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5357 - accuracy: 0.7298
# Epoch 00070: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5353 - accuracy: 0.7298 - val_loss: 0.5833 - val_accuracy: 0.6725
# Epoch 71/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5384 - accuracy: 0.7282
# Epoch 00071: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5381 - accuracy: 0.7283 - val_loss: 0.5700 - val_accuracy: 0.6862
# Epoch 72/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5445 - accuracy: 0.7206
# Epoch 00072: val_accuracy did not improve from 0.68623
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5477 - accuracy: 0.7200 - val_loss: 0.5793 - val_accuracy: 0.6841
# Epoch 73/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5467 - accuracy: 0.7149
# Epoch 00073: val_accuracy improved from 0.68623 to 0.68986, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_73.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5435 - accuracy: 0.7151 - val_loss: 0.5685 - val_accuracy: 0.6899
# Epoch 74/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5338 - accuracy: 0.7253
# Epoch 00074: val_accuracy did not improve from 0.68986
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5318 - accuracy: 0.7256 - val_loss: 0.5696 - val_accuracy: 0.6899
# Epoch 75/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5280 - accuracy: 0.7284
# Epoch 00075: val_accuracy improved from 0.68986 to 0.69420, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_75.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.5261 - accuracy: 0.7283 - val_loss: 0.5716 - val_accuracy: 0.6942
# Epoch 76/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5230 - accuracy: 0.7382
# Epoch 00076: val_accuracy did not improve from 0.69420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5212 - accuracy: 0.7383 - val_loss: 0.5737 - val_accuracy: 0.6855
# Epoch 77/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5303 - accuracy: 0.7264
# Epoch 00077: val_accuracy did not improve from 0.69420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5297 - accuracy: 0.7262 - val_loss: 0.5821 - val_accuracy: 0.6899
# Epoch 78/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5235 - accuracy: 0.7329
# Epoch 00078: val_accuracy did not improve from 0.69420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5244 - accuracy: 0.7331 - val_loss: 0.5806 - val_accuracy: 0.6812
# Epoch 79/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5214 - accuracy: 0.7375
# Epoch 00079: val_accuracy did not improve from 0.69420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5175 - accuracy: 0.7379 - val_loss: 0.5760 - val_accuracy: 0.6906
# Epoch 80/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5326 - accuracy: 0.7247
# Epoch 00080: val_accuracy did not improve from 0.69420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5320 - accuracy: 0.7249 - val_loss: 0.5790 - val_accuracy: 0.6804
# Epoch 81/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5280 - accuracy: 0.7346
# Epoch 00081: val_accuracy did not improve from 0.69420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5265 - accuracy: 0.7343 - val_loss: 0.5713 - val_accuracy: 0.6862
# Epoch 82/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5200 - accuracy: 0.7333
# Epoch 00082: val_accuracy did not improve from 0.69420
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5194 - accuracy: 0.7334 - val_loss: 0.5776 - val_accuracy: 0.6877
# Epoch 83/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5250 - accuracy: 0.7340
# Epoch 00083: val_accuracy improved from 0.69420 to 0.69855, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_83.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5251 - accuracy: 0.7340 - val_loss: 0.5617 - val_accuracy: 0.6986
# Epoch 84/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5190 - accuracy: 0.7389
# Epoch 00084: val_accuracy improved from 0.69855 to 0.70290, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_84.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.5162 - accuracy: 0.7387 - val_loss: 0.5553 - val_accuracy: 0.7029
# Epoch 85/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5090 - accuracy: 0.7473
# Epoch 00085: val_accuracy did not improve from 0.70290
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5095 - accuracy: 0.7470 - val_loss: 0.5591 - val_accuracy: 0.7029
# Epoch 86/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5149 - accuracy: 0.7376
# Epoch 00086: val_accuracy did not improve from 0.70290
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5184 - accuracy: 0.7374 - val_loss: 0.5625 - val_accuracy: 0.6957
# Epoch 87/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5018 - accuracy: 0.7507
# Epoch 00087: val_accuracy did not improve from 0.70290
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5014 - accuracy: 0.7508 - val_loss: 0.5665 - val_accuracy: 0.6928
# Epoch 88/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5134 - accuracy: 0.7447
# Epoch 00088: val_accuracy did not improve from 0.70290
# 44/44 [==============================] - 3s 70ms/step - loss: 0.5121 - accuracy: 0.7447 - val_loss: 0.5725 - val_accuracy: 0.6833
# Epoch 89/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5131 - accuracy: 0.7406
# Epoch 00089: val_accuracy improved from 0.70290 to 0.71594, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_89.h5
# 44/44 [==============================] - 3s 73ms/step - loss: 0.5111 - accuracy: 0.7403 - val_loss: 0.5529 - val_accuracy: 0.7159
# Epoch 90/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5006 - accuracy: 0.7562
# Epoch 00090: val_accuracy did not improve from 0.71594
# 44/44 [==============================] - 3s 72ms/step - loss: 0.5014 - accuracy: 0.7561 - val_loss: 0.5508 - val_accuracy: 0.7130
# Epoch 91/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5087 - accuracy: 0.7409
# Epoch 00091: val_accuracy did not improve from 0.71594
# 44/44 [==============================] - 3s 72ms/step - loss: 0.5079 - accuracy: 0.7410 - val_loss: 0.5662 - val_accuracy: 0.6928
# Epoch 92/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4977 - accuracy: 0.7518
# Epoch 00092: val_accuracy did not improve from 0.71594
# 44/44 [==============================] - 3s 72ms/step - loss: 0.5070 - accuracy: 0.7512 - val_loss: 0.5577 - val_accuracy: 0.7138
# Epoch 93/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5048 - accuracy: 0.7485
# Epoch 00093: val_accuracy improved from 0.71594 to 0.71667, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_93.h5
# 44/44 [==============================] - 3s 74ms/step - loss: 0.5042 - accuracy: 0.7486 - val_loss: 0.5535 - val_accuracy: 0.7167
# Epoch 94/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5056 - accuracy: 0.7469
# Epoch 00094: val_accuracy improved from 0.71667 to 0.71957, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_94.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.5031 - accuracy: 0.7470 - val_loss: 0.5513 - val_accuracy: 0.7196
# Epoch 95/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.5032 - accuracy: 0.7447
# Epoch 00095: val_accuracy improved from 0.71957 to 0.72174, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_95.h5
# 44/44 [==============================] - 3s 72ms/step - loss: 0.5006 - accuracy: 0.7450 - val_loss: 0.5435 - val_accuracy: 0.7217
# Epoch 96/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4911 - accuracy: 0.7600
# Epoch 00096: val_accuracy did not improve from 0.72174
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4879 - accuracy: 0.7602 - val_loss: 0.5458 - val_accuracy: 0.7188
# Epoch 97/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4944 - accuracy: 0.7587
# Epoch 00097: val_accuracy improved from 0.72174 to 0.72536, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_97.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4929 - accuracy: 0.7590 - val_loss: 0.5470 - val_accuracy: 0.7254
# Epoch 98/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4879 - accuracy: 0.7564
# Epoch 00098: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4893 - accuracy: 0.7564 - val_loss: 0.5496 - val_accuracy: 0.7174
# Epoch 99/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4821 - accuracy: 0.7667
# Epoch 00099: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4832 - accuracy: 0.7666 - val_loss: 0.5605 - val_accuracy: 0.7080
# Epoch 100/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4929 - accuracy: 0.7616
# Epoch 00100: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4895 - accuracy: 0.7621 - val_loss: 0.5570 - val_accuracy: 0.7116
# Epoch 101/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4961 - accuracy: 0.7531
# Epoch 00101: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4978 - accuracy: 0.7528 - val_loss: 0.5400 - val_accuracy: 0.7152
# Epoch 102/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4899 - accuracy: 0.7594
# Epoch 00102: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 75ms/step - loss: 0.4976 - accuracy: 0.7592 - val_loss: 0.5582 - val_accuracy: 0.7087
# Epoch 103/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4976 - accuracy: 0.7549
# Epoch 00103: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4956 - accuracy: 0.7550 - val_loss: 0.5418 - val_accuracy: 0.7239
# Epoch 104/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4793 - accuracy: 0.7682
# Epoch 00104: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4781 - accuracy: 0.7684 - val_loss: 0.5583 - val_accuracy: 0.7123
# Epoch 105/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4708 - accuracy: 0.7742
# Epoch 00105: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4746 - accuracy: 0.7738 - val_loss: 0.5412 - val_accuracy: 0.7239
# Epoch 106/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.7618
# Epoch 00106: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4828 - accuracy: 0.7617 - val_loss: 0.5356 - val_accuracy: 0.7196
# Epoch 107/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4762 - accuracy: 0.7680
# Epoch 00107: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4742 - accuracy: 0.7680 - val_loss: 0.5700 - val_accuracy: 0.7094
# Epoch 108/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4849 - accuracy: 0.7631
# Epoch 00108: val_accuracy did not improve from 0.72536
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4849 - accuracy: 0.7631 - val_loss: 0.5450 - val_accuracy: 0.7159
# Epoch 109/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4752 - accuracy: 0.7687
# Epoch 00109: val_accuracy improved from 0.72536 to 0.73116, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_109.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4720 - accuracy: 0.7689 - val_loss: 0.5319 - val_accuracy: 0.7312
# Epoch 110/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4724 - accuracy: 0.7709
# Epoch 00110: val_accuracy did not improve from 0.73116
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4731 - accuracy: 0.7708 - val_loss: 0.5345 - val_accuracy: 0.7290
# Epoch 111/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4658 - accuracy: 0.7760
# Epoch 00111: val_accuracy did not improve from 0.73116
# 44/44 [==============================] - 3s 76ms/step - loss: 0.4648 - accuracy: 0.7762 - val_loss: 0.5497 - val_accuracy: 0.7159
# Epoch 112/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4675 - accuracy: 0.7747
# Epoch 00112: val_accuracy did not improve from 0.73116
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4698 - accuracy: 0.7744 - val_loss: 0.5475 - val_accuracy: 0.7167
# Epoch 113/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4629 - accuracy: 0.7849
# Epoch 00113: val_accuracy did not improve from 0.73116
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4638 - accuracy: 0.7849 - val_loss: 0.5429 - val_accuracy: 0.7174
# Epoch 114/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4639 - accuracy: 0.7740
# Epoch 00114: val_accuracy did not improve from 0.73116
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4704 - accuracy: 0.7735 - val_loss: 0.5265 - val_accuracy: 0.7246
# Epoch 115/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4618 - accuracy: 0.7762
# Epoch 00115: val_accuracy improved from 0.73116 to 0.73261, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_115.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4613 - accuracy: 0.7760 - val_loss: 0.5371 - val_accuracy: 0.7326
# Epoch 116/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4565 - accuracy: 0.7800
# Epoch 00116: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4570 - accuracy: 0.7800 - val_loss: 0.5373 - val_accuracy: 0.7254
# Epoch 117/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4611 - accuracy: 0.7818
# Epoch 00117: val_accuracy did not improve from 0.73261
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4606 - accuracy: 0.7816 - val_loss: 0.5327 - val_accuracy: 0.7239
# Epoch 118/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4608 - accuracy: 0.7691
# Epoch 00118: val_accuracy improved from 0.73261 to 0.73551, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_118.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4609 - accuracy: 0.7689 - val_loss: 0.5252 - val_accuracy: 0.7355
# Epoch 119/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4612 - accuracy: 0.7787
# Epoch 00119: val_accuracy did not improve from 0.73551
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4590 - accuracy: 0.7787 - val_loss: 0.5351 - val_accuracy: 0.7268
# Epoch 120/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4607 - accuracy: 0.7754
# Epoch 00120: val_accuracy did not improve from 0.73551
# 44/44 [==============================] - 3s 74ms/step - loss: 0.4582 - accuracy: 0.7755 - val_loss: 0.5329 - val_accuracy: 0.7297
# Epoch 121/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4456 - accuracy: 0.7836
# Epoch 00121: val_accuracy improved from 0.73551 to 0.73696, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_121.h5
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4437 - accuracy: 0.7836 - val_loss: 0.5169 - val_accuracy: 0.7370
# Epoch 122/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4417 - accuracy: 0.7941
# Epoch 00122: val_accuracy did not improve from 0.73696
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4390 - accuracy: 0.7943 - val_loss: 0.5248 - val_accuracy: 0.7312
# Epoch 123/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4551 - accuracy: 0.7825
# Epoch 00123: val_accuracy did not improve from 0.73696
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4551 - accuracy: 0.7825 - val_loss: 0.5256 - val_accuracy: 0.7217
# Epoch 124/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4553 - accuracy: 0.7812
# Epoch 00124: val_accuracy did not improve from 0.73696
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4510 - accuracy: 0.7816 - val_loss: 0.5199 - val_accuracy: 0.7283
# Epoch 125/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4373 - accuracy: 0.7952
# Epoch 00125: val_accuracy did not improve from 0.73696
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4402 - accuracy: 0.7949 - val_loss: 0.5380 - val_accuracy: 0.7326
# Epoch 126/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4437 - accuracy: 0.7847
# Epoch 00126: val_accuracy improved from 0.73696 to 0.74638, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_126.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4476 - accuracy: 0.7843 - val_loss: 0.5250 - val_accuracy: 0.7464
# Epoch 127/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4558 - accuracy: 0.7794
# Epoch 00127: val_accuracy did not improve from 0.74638
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4523 - accuracy: 0.7798 - val_loss: 0.5197 - val_accuracy: 0.7370
# Epoch 128/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4435 - accuracy: 0.7903
# Epoch 00128: val_accuracy did not improve from 0.74638
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4428 - accuracy: 0.7905 - val_loss: 0.5221 - val_accuracy: 0.7442
# Epoch 129/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4383 - accuracy: 0.7902
# Epoch 00129: val_accuracy did not improve from 0.74638
# 44/44 [==============================] - 3s 78ms/step - loss: 0.4411 - accuracy: 0.7901 - val_loss: 0.5175 - val_accuracy: 0.7370
# Epoch 130/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4346 - accuracy: 0.7943
# Epoch 00130: val_accuracy improved from 0.74638 to 0.75870, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_130.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4396 - accuracy: 0.7939 - val_loss: 0.5126 - val_accuracy: 0.7587
# Epoch 131/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4494 - accuracy: 0.7876
# Epoch 00131: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 69ms/step - loss: 0.4554 - accuracy: 0.7871 - val_loss: 0.5217 - val_accuracy: 0.7333
# Epoch 132/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4552 - accuracy: 0.7791
# Epoch 00132: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4512 - accuracy: 0.7794 - val_loss: 0.5112 - val_accuracy: 0.7435
# Epoch 133/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4272 - accuracy: 0.7941
# Epoch 00133: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4275 - accuracy: 0.7941 - val_loss: 0.5082 - val_accuracy: 0.7500
# Epoch 134/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4295 - accuracy: 0.7965
# Epoch 00134: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4317 - accuracy: 0.7965 - val_loss: 0.5125 - val_accuracy: 0.7391
# Epoch 135/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4297 - accuracy: 0.7978
# Epoch 00135: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4313 - accuracy: 0.7976 - val_loss: 0.5195 - val_accuracy: 0.7384
# Epoch 136/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4327 - accuracy: 0.7902
# Epoch 00136: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4281 - accuracy: 0.7905 - val_loss: 0.5217 - val_accuracy: 0.7254
# Epoch 137/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4368 - accuracy: 0.7891
# Epoch 00137: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4327 - accuracy: 0.7894 - val_loss: 0.5165 - val_accuracy: 0.7457
# Epoch 138/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4307 - accuracy: 0.7941
# Epoch 00138: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 75ms/step - loss: 0.4303 - accuracy: 0.7939 - val_loss: 0.5299 - val_accuracy: 0.7406
# Epoch 139/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4288 - accuracy: 0.7976
# Epoch 00139: val_accuracy did not improve from 0.75870
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4241 - accuracy: 0.7979 - val_loss: 0.5141 - val_accuracy: 0.7457
# Epoch 140/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4225 - accuracy: 0.8038
# Epoch 00140: val_accuracy improved from 0.75870 to 0.76232, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_140.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4192 - accuracy: 0.8037 - val_loss: 0.5007 - val_accuracy: 0.7623
# Epoch 141/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4188 - accuracy: 0.8020
# Epoch 00141: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4214 - accuracy: 0.8017 - val_loss: 0.5105 - val_accuracy: 0.7507
# Epoch 142/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4149 - accuracy: 0.8087
# Epoch 00142: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4152 - accuracy: 0.8088 - val_loss: 0.5113 - val_accuracy: 0.7514
# Epoch 143/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4190 - accuracy: 0.8058
# Epoch 00143: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4192 - accuracy: 0.8059 - val_loss: 0.5062 - val_accuracy: 0.7536
# Epoch 144/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4129 - accuracy: 0.8058
# Epoch 00144: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4126 - accuracy: 0.8057 - val_loss: 0.5072 - val_accuracy: 0.7536
# Epoch 145/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4101 - accuracy: 0.8041
# Epoch 00145: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4117 - accuracy: 0.8039 - val_loss: 0.5134 - val_accuracy: 0.7514
# Epoch 146/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4185 - accuracy: 0.8027
# Epoch 00146: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4161 - accuracy: 0.8028 - val_loss: 0.5034 - val_accuracy: 0.7507
# Epoch 147/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4191 - accuracy: 0.7994
# Epoch 00147: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 78ms/step - loss: 0.4208 - accuracy: 0.7994 - val_loss: 0.5231 - val_accuracy: 0.7428
# Epoch 148/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4082 - accuracy: 0.8090
# Epoch 00148: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4065 - accuracy: 0.8090 - val_loss: 0.5009 - val_accuracy: 0.7551
# Epoch 149/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4051 - accuracy: 0.8105
# Epoch 00149: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4045 - accuracy: 0.8106 - val_loss: 0.5028 - val_accuracy: 0.7565
# Epoch 150/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4133 - accuracy: 0.8063
# Epoch 00150: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 71ms/step - loss: 0.4098 - accuracy: 0.8065 - val_loss: 0.5762 - val_accuracy: 0.7058
# Epoch 151/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4167 - accuracy: 0.8027
# Epoch 00151: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4108 - accuracy: 0.8030 - val_loss: 0.4957 - val_accuracy: 0.7572
# Epoch 152/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4100 - accuracy: 0.8061
# Epoch 00152: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4058 - accuracy: 0.8065 - val_loss: 0.5085 - val_accuracy: 0.7435
# Epoch 153/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4076 - accuracy: 0.8109
# Epoch 00153: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.4043 - accuracy: 0.8110 - val_loss: 0.4934 - val_accuracy: 0.7565
# Epoch 154/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.4013 - accuracy: 0.8118
# Epoch 00154: val_accuracy did not improve from 0.76232
# 44/44 [==============================] - 3s 70ms/step - loss: 0.3986 - accuracy: 0.8121 - val_loss: 0.5071 - val_accuracy: 0.7543
# Epoch 155/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.3988 - accuracy: 0.8219
# ...
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2054 - accuracy: 0.9148 - val_loss: 0.5321 - val_accuracy: 0.7819
# Epoch 446/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2171 - accuracy: 0.9092
# Epoch 00446: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2125 - accuracy: 0.9094 - val_loss: 0.5111 - val_accuracy: 0.7877
# Epoch 447/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1932 - accuracy: 0.9255
# Epoch 00447: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1899 - accuracy: 0.9257 - val_loss: 0.5321 - val_accuracy: 0.7783
# Epoch 448/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9219
# Epoch 00448: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1902 - accuracy: 0.9221 - val_loss: 0.5314 - val_accuracy: 0.7971
# Epoch 449/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2052 - accuracy: 0.9191
# Epoch 00449: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2038 - accuracy: 0.9192 - val_loss: 0.5321 - val_accuracy: 0.7978
# Epoch 450/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1978 - accuracy: 0.9155
# Epoch 00450: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2010 - accuracy: 0.9155 - val_loss: 0.5371 - val_accuracy: 0.7884
# Epoch 451/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2421 - accuracy: 0.9028
# Epoch 00451: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2452 - accuracy: 0.9027 - val_loss: 0.5634 - val_accuracy: 0.7667
# Epoch 452/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2440 - accuracy: 0.8959
# Epoch 00452: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2432 - accuracy: 0.8960 - val_loss: 0.5271 - val_accuracy: 0.7899
# Epoch 453/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2157 - accuracy: 0.9066
# Epoch 00453: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2179 - accuracy: 0.9063 - val_loss: 0.5204 - val_accuracy: 0.7848
# Epoch 454/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2079 - accuracy: 0.9135
# Epoch 00454: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2064 - accuracy: 0.9136 - val_loss: 0.5286 - val_accuracy: 0.7804
# Epoch 455/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2056 - accuracy: 0.9155
# Epoch 00455: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2073 - accuracy: 0.9155 - val_loss: 0.5206 - val_accuracy: 0.7841
# Epoch 456/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2095 - accuracy: 0.9112
# Epoch 00456: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2062 - accuracy: 0.9114 - val_loss: 0.5221 - val_accuracy: 0.7899
# Epoch 457/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1987 - accuracy: 0.9221
# Epoch 00457: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1999 - accuracy: 0.9219 - val_loss: 0.5238 - val_accuracy: 0.7891
# Epoch 458/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1990 - accuracy: 0.9202
# Epoch 00458: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1977 - accuracy: 0.9203 - val_loss: 0.5301 - val_accuracy: 0.7783
# Epoch 459/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2081 - accuracy: 0.9142
# Epoch 00459: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2038 - accuracy: 0.9145 - val_loss: 0.5413 - val_accuracy: 0.7804
# Epoch 460/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2026 - accuracy: 0.9193
# Epoch 00460: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2028 - accuracy: 0.9194 - val_loss: 0.5019 - val_accuracy: 0.7906
# Epoch 461/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1966 - accuracy: 0.9222
# Epoch 00461: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1949 - accuracy: 0.9223 - val_loss: 0.5355 - val_accuracy: 0.7855
# Epoch 462/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2050 - accuracy: 0.9132
# Epoch 00462: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2079 - accuracy: 0.9130 - val_loss: 0.5238 - val_accuracy: 0.7891
# Epoch 463/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2004 - accuracy: 0.9152
# Epoch 00463: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1978 - accuracy: 0.9154 - val_loss: 0.5270 - val_accuracy: 0.7920
# Epoch 464/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1906 - accuracy: 0.9190
# Epoch 00464: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1896 - accuracy: 0.9190 - val_loss: 0.5183 - val_accuracy: 0.7928
# Epoch 465/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2032 - accuracy: 0.9175
# Epoch 00465: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 71ms/step - loss: 0.2012 - accuracy: 0.9175 - val_loss: 0.5431 - val_accuracy: 0.7790
# Epoch 466/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.9208
# Epoch 00466: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1899 - accuracy: 0.9208 - val_loss: 0.5424 - val_accuracy: 0.7877
# Epoch 467/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1911 - accuracy: 0.9208
# Epoch 00467: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1892 - accuracy: 0.9210 - val_loss: 0.5440 - val_accuracy: 0.7862
# Epoch 468/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1941 - accuracy: 0.9206
# Epoch 00468: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1905 - accuracy: 0.9208 - val_loss: 0.5513 - val_accuracy: 0.7899
# Epoch 469/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2017 - accuracy: 0.9150
# Epoch 00469: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2016 - accuracy: 0.9150 - val_loss: 0.5164 - val_accuracy: 0.7877
# Epoch 470/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1910 - accuracy: 0.9261
# Epoch 00470: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1913 - accuracy: 0.9261 - val_loss: 0.5531 - val_accuracy: 0.7754
# Epoch 471/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2053 - accuracy: 0.9144
# Epoch 00471: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2029 - accuracy: 0.9145 - val_loss: 0.5455 - val_accuracy: 0.7855
# Epoch 472/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2129 - accuracy: 0.9092
# Epoch 00472: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2140 - accuracy: 0.9088 - val_loss: 0.5397 - val_accuracy: 0.7833
# Epoch 473/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2096 - accuracy: 0.9119
# Epoch 00473: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2108 - accuracy: 0.9119 - val_loss: 0.5612 - val_accuracy: 0.7833
# Epoch 474/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2090 - accuracy: 0.9146
# Epoch 00474: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2077 - accuracy: 0.9146 - val_loss: 0.5501 - val_accuracy: 0.7913
# Epoch 475/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1945 - accuracy: 0.9197
# Epoch 00475: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2004 - accuracy: 0.9194 - val_loss: 0.5488 - val_accuracy: 0.7862
# Epoch 476/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2181 - accuracy: 0.9110
# Epoch 00476: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2207 - accuracy: 0.9110 - val_loss: 0.5272 - val_accuracy: 0.7848
# Epoch 477/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1852 - accuracy: 0.9262
# Epoch 00477: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1856 - accuracy: 0.9262 - val_loss: 0.5207 - val_accuracy: 0.7884
# Epoch 478/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1940 - accuracy: 0.9201
# Epoch 00478: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1984 - accuracy: 0.9197 - val_loss: 0.5301 - val_accuracy: 0.7848
# Epoch 479/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1940 - accuracy: 0.9202
# Epoch 00479: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2069 - accuracy: 0.9199 - val_loss: 0.5185 - val_accuracy: 0.7819
# Epoch 480/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2109 - accuracy: 0.9124
# Epoch 00480: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2072 - accuracy: 0.9126 - val_loss: 0.5145 - val_accuracy: 0.7870
# Epoch 481/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1802 - accuracy: 0.9295
# Epoch 00481: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1781 - accuracy: 0.9297 - val_loss: 0.5406 - val_accuracy: 0.7841
# Epoch 482/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2052 - accuracy: 0.9191
# Epoch 00482: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2033 - accuracy: 0.9194 - val_loss: 0.5228 - val_accuracy: 0.7855
# Epoch 483/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1893 - accuracy: 0.9199
# Epoch 00483: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1912 - accuracy: 0.9199 - val_loss: 0.5507 - val_accuracy: 0.7920
# Epoch 484/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1937 - accuracy: 0.9253
# Epoch 00484: val_accuracy did not improve from 0.79783
# 44/44 [==============================] - 3s 69ms/step - loss: 0.1917 - accuracy: 0.9255 - val_loss: 0.5067 - val_accuracy: 0.7928
# Epoch 485/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1969 - accuracy: 0.9172
# Epoch 00485: val_accuracy improved from 0.79783 to 0.80072, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_485.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.1944 - accuracy: 0.9172 - val_loss: 0.5280 - val_accuracy: 0.8007
# Epoch 486/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9202
# Epoch 00486: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 71ms/step - loss: 0.2030 - accuracy: 0.9203 - val_loss: 0.5327 - val_accuracy: 0.7841
# Epoch 487/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1915 - accuracy: 0.9195
# Epoch 00487: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1880 - accuracy: 0.9197 - val_loss: 0.5266 - val_accuracy: 0.7884
# Epoch 488/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1883 - accuracy: 0.9248
# Epoch 00488: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1922 - accuracy: 0.9246 - val_loss: 0.5383 - val_accuracy: 0.7877
# Epoch 489/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9215
# Epoch 00489: val_accuracy did not improve from 0.80072
# 44/44 [==============================] - 3s 71ms/step - loss: 0.1978 - accuracy: 0.9213 - val_loss: 0.5716 - val_accuracy: 0.7841
# Epoch 490/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2044 - accuracy: 0.9191
# Epoch 00490: val_accuracy improved from 0.80072 to 0.80217, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/STFT_MFCC_CNN/STFT_MFCC_CNN_Binary_490.h5
# 44/44 [==============================] - 3s 71ms/step - loss: 0.2038 - accuracy: 0.9192 - val_loss: 0.5307 - val_accuracy: 0.8022
# Epoch 491/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1901 - accuracy: 0.9186
# Epoch 00491: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1903 - accuracy: 0.9186 - val_loss: 0.5195 - val_accuracy: 0.7848
# Epoch 492/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2023 - accuracy: 0.9164
# Epoch 00492: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2054 - accuracy: 0.9165 - val_loss: 0.6208 - val_accuracy: 0.7717
# Epoch 493/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2073 - accuracy: 0.9170
# Epoch 00493: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2058 - accuracy: 0.9170 - val_loss: 0.5616 - val_accuracy: 0.7884
# Epoch 494/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1894 - accuracy: 0.9242
# Epoch 00494: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1867 - accuracy: 0.9244 - val_loss: 0.5193 - val_accuracy: 0.7964
# Epoch 495/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1805 - accuracy: 0.9304
# Epoch 00495: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1793 - accuracy: 0.9304 - val_loss: 0.5541 - val_accuracy: 0.7949
# Epoch 496/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1845 - accuracy: 0.9257
# Epoch 00496: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1808 - accuracy: 0.9259 - val_loss: 0.5386 - val_accuracy: 0.7899
# Epoch 497/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1795 - accuracy: 0.9261
# Epoch 00497: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1846 - accuracy: 0.9259 - val_loss: 0.5249 - val_accuracy: 0.7920
# Epoch 498/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1857 - accuracy: 0.9237
# Epoch 00498: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 71ms/step - loss: 0.1897 - accuracy: 0.9233 - val_loss: 0.5404 - val_accuracy: 0.7957
# Epoch 499/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.2065 - accuracy: 0.9190
# Epoch 00499: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.2061 - accuracy: 0.9190 - val_loss: 0.5193 - val_accuracy: 0.7964
# Epoch 500/500
# 43/44 [============================>.] - ETA: 0s - loss: 0.1857 - accuracy: 0.9255
# Epoch 00500: val_accuracy did not improve from 0.80217
# 44/44 [==============================] - 3s 70ms/step - loss: 0.1860 - accuracy: 0.9255 - val_loss: 0.5335 - val_accuracy: 0.8007
# Training completed in time:  0:26:31.909396
