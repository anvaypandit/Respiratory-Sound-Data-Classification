# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import pandas as pd
import wave
import sys
import os
import librosa
import librosa.display
import xgboost as xgb
from  sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.model_selection import GridSearchCV 
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import sklearn.naive_bayes as nb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier,GradientBoostingClassifier
from sklearn.neighbors import kd_tree
import seaborn as sn
from sklearn.metrics import confusion_matrix
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.kd_tree module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/deprecation.py:144: FutureWarning: The sklearn.neighbors.base module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.neighbors. Anything that cannot be imported from sklearn.neighbors is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.utils import to_categorical
from tensorflow.keras.callbacks import ModelCheckpoint


from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc, accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
# Out:
# Using TensorFlow backend.

# %%
# Load per cycle data frame
import pickle
folder = "/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/" 
filename = folder + 'w_c_dataset.pickle'
infile = open(filename,'rb')
[sound,sr,lengths,times,labels] = pickle.load(infile)
infile.close()

# %%
def split_sounds(sounds,times,labels):
    s=[]
    l=[]
    for i,sound in enumerate(sounds):
        for t,label in zip(times[i],labels[i]):
            s.append(sound[int(t[0]):int(t[1])])
            if label==0:
                a=np.array([1,0,0,0])
            if label==1:
                a=np.array([0,1,0,0])
            if label==2:
                a=np.array([0,0,1,0])    
            if label==3:
                a=np.array([0,0,0,1])
            l.append(a)
    return s,l

# %%
[data,label]=split_sounds(sound,times,labels)

# %%
max_pad_len = 697
import librosa
def extract_feature(X,sample_rate):
    n_fft=int(sample_rate*0.025)
    hop_length=int(sample_rate*0.01)


    mfccs = librosa.feature.mfcc(y=X, sr=sample_rate,n_mfcc=40)
    # Pad  mfcc till the end
    pad_width_mfcc = max_pad_len - mfccs.shape[1]
    
    mfccs = np.pad(mfccs, pad_width=((0, 0), (0, pad_width_mfcc)), mode='constant')
   
    return mfccs

# %%
import sys
dataset = []
for d in data:
    a = extract_feature(d,sr[0])
    dataset.append(a)

# %%
dataset = np.array(dataset)
dataset.shape
# Out:
# (6898, 40, 697)

# %%
# add channel dimension for CNN
dataset = np.reshape(dataset, (*dataset.shape,1))

label=np.asarray(label)
a=np.zeros(label.shape[0])
for i in range(label.shape[0]):
    for j in range(label.shape[1]):
        if label[i][j]==1:
            a[i]=j

# COnvert to binary for the binary classification problem
bin_label =np.zeros(label.shape[0])
for index,l in enumerate(a):
    if l == 0:
        bin_label[index] = l
    else:
        bin_label[index] = 1

unique, counts = np.unique(bin_label, return_counts=True)

print(np.asarray((unique, counts)).T)


# One-hot encode labels
le = LabelEncoder()
i_labels = le.fit_transform(bin_label)
oh_labels = to_categorical(i_labels)
# Out:
# [[0.000e+00 3.642e+03]
#  [1.000e+00 3.256e+03]]

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(dataset, oh_labels, stratify=label, 
                                                    test_size=0.2, random_state = 42)

# %%
num_rows = 40
num_columns = 697
num_channels = 1

num_labels = 2
filter_size = 2

# Construct model 
model = Sequential()
model.add(Conv2D(filters=16, kernel_size=filter_size,
                 input_shape=(num_rows, num_columns, num_channels), activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=32, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=64, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(Conv2D(filters=128, kernel_size=filter_size, activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.2))

model.add(GlobalAveragePooling2D())

model.add(Dense(32, activation='relu')) 

model.add(Dense(num_labels, activation='sigmoid'))

# %%
# Compile the model
model.compile(loss='binary_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
# Display model architecture summary 
model.summary()



# Load the trained model if required
model_file = '/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/MFC_CNN_Binary_197.h5'
model.load_weights(model_file)

# Calculate pre-training accuracy 
score = model.evaluate(x_test, y_test, verbose=1)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 39, 696, 16)       80
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 19, 348, 16)       0
# _________________________________________________________________
# dropout (Dropout)            (None, 19, 348, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 18, 347, 32)       2080
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 9, 173, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 9, 173, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 8, 172, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 86, 64)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 86, 64)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 85, 128)        32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 42, 128)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1, 42, 128)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 32)                4128
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 47,506
# Trainable params: 47,506
# Non-trainable params: 0
# _________________________________________________________________
# 44/44 [==============================] - 0s 6ms/step - loss: 0.5084 - accuracy: 0.8101
# Pre-training accuracy: 81.0145%

# %%
# train model
num_epochs = 1000
num_batch_size = 128



callbacks = [
    ModelCheckpoint(
        filepath='/content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/Try2/MFC_CNN_Binary_{epoch:02d}.h5',
        # Path where to save the model
        # The two parameters below mean that we will overwrite
        # the current checkpoint if and only if
        # the `val_accuracy` score has improved.
        save_best_only=True,
        monitor='val_accuracy',
        verbose=1)
]
start = datetime.now()

model.fit(x_train, y_train, batch_size=num_batch_size, epochs=num_epochs,
          validation_data=(x_test, y_test), callbacks=callbacks, verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/1000
# 44/44 [==============================] - ETA: 0s - loss: 0.2613 - accuracy: 0.8842
# Epoch 00001: val_accuracy improved from -inf to 0.80435, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/Try2/MFC_CNN_Binary_01.h5
# 44/44 [==============================] - 2s 49ms/step - loss: 0.2613 - accuracy: 0.8842 - val_loss: 0.5201 - val_accuracy: 0.8043
# Epoch 2/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2545 - accuracy: 0.8908
# Epoch 00002: val_accuracy did not improve from 0.80435
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2541 - accuracy: 0.8907 - val_loss: 0.5321 - val_accuracy: 0.7913
# Epoch 3/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2593 - accuracy: 0.8904
# Epoch 00003: val_accuracy did not improve from 0.80435
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2633 - accuracy: 0.8900 - val_loss: 0.4897 - val_accuracy: 0.8036
# Epoch 4/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2499 - accuracy: 0.8937
# Epoch 00004: val_accuracy did not improve from 0.80435
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2491 - accuracy: 0.8936 - val_loss: 0.5034 - val_accuracy: 0.8014
# Epoch 5/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2417 - accuracy: 0.8943
# Epoch 00005: val_accuracy improved from 0.80435 to 0.80725, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/Try2/MFC_CNN_Binary_05.h5
# 44/44 [==============================] - 2s 38ms/step - loss: 0.2418 - accuracy: 0.8943 - val_loss: 0.4867 - val_accuracy: 0.8072
# Epoch 6/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2391 - accuracy: 0.9010
# Epoch 00006: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2370 - accuracy: 0.9012 - val_loss: 0.5409 - val_accuracy: 0.7812
# Epoch 7/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2412 - accuracy: 0.8977
# Epoch 00007: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2407 - accuracy: 0.8976 - val_loss: 0.5090 - val_accuracy: 0.7942
# Epoch 8/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2449 - accuracy: 0.8912
# Epoch 00008: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2464 - accuracy: 0.8911 - val_loss: 0.5183 - val_accuracy: 0.7855
# Epoch 9/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2409 - accuracy: 0.8977
# Epoch 00009: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2410 - accuracy: 0.8976 - val_loss: 0.4955 - val_accuracy: 0.8043
# Epoch 10/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2395 - accuracy: 0.8990
# Epoch 00010: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2387 - accuracy: 0.8991 - val_loss: 0.5384 - val_accuracy: 0.8022
# Epoch 11/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2476 - accuracy: 0.8935
# Epoch 00011: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2496 - accuracy: 0.8933 - val_loss: 0.5003 - val_accuracy: 0.8058
# Epoch 12/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2451 - accuracy: 0.8961
# Epoch 00012: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2445 - accuracy: 0.8960 - val_loss: 0.5138 - val_accuracy: 0.7913
# Epoch 13/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2363 - accuracy: 0.8988
# Epoch 00013: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2347 - accuracy: 0.8989 - val_loss: 0.5275 - val_accuracy: 0.7964
# Epoch 14/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2302 - accuracy: 0.9039
# Epoch 00014: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2305 - accuracy: 0.9040 - val_loss: 0.5491 - val_accuracy: 0.8051
# Epoch 15/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2451 - accuracy: 0.8892
# Epoch 00015: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2490 - accuracy: 0.8889 - val_loss: 0.5190 - val_accuracy: 0.7899
# Epoch 16/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2414 - accuracy: 0.8968
# Epoch 00016: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2413 - accuracy: 0.8969 - val_loss: 0.5174 - val_accuracy: 0.7957
# Epoch 17/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2429 - accuracy: 0.8995
# Epoch 00017: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2422 - accuracy: 0.8996 - val_loss: 0.5234 - val_accuracy: 0.8000
# Epoch 18/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2314 - accuracy: 0.9017
# Epoch 00018: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2299 - accuracy: 0.9020 - val_loss: 0.5189 - val_accuracy: 0.7899
# Epoch 19/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2419 - accuracy: 0.8959
# Epoch 00019: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2398 - accuracy: 0.8960 - val_loss: 0.5110 - val_accuracy: 0.7986
# Epoch 20/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2361 - accuracy: 0.9012
# Epoch 00020: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2357 - accuracy: 0.9011 - val_loss: 0.5120 - val_accuracy: 0.7957
# Epoch 21/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2649 - accuracy: 0.8877
# Epoch 00021: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2635 - accuracy: 0.8876 - val_loss: 0.5340 - val_accuracy: 0.7848
# Epoch 22/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2362 - accuracy: 0.8975
# Epoch 00022: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2353 - accuracy: 0.8976 - val_loss: 0.5108 - val_accuracy: 0.7935
# Epoch 23/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2400 - accuracy: 0.8943
# Epoch 00023: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2400 - accuracy: 0.8940 - val_loss: 0.5539 - val_accuracy: 0.7935
# Epoch 24/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2524 - accuracy: 0.8923
# Epoch 00024: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2496 - accuracy: 0.8924 - val_loss: 0.5107 - val_accuracy: 0.7913
# Epoch 25/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2259 - accuracy: 0.9004
# Epoch 00025: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2241 - accuracy: 0.9005 - val_loss: 0.5194 - val_accuracy: 0.7855
# Epoch 26/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2312 - accuracy: 0.8992
# Epoch 00026: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2319 - accuracy: 0.8992 - val_loss: 0.5130 - val_accuracy: 0.7920
# Epoch 27/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2351 - accuracy: 0.8983
# Epoch 00027: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2322 - accuracy: 0.8983 - val_loss: 0.5079 - val_accuracy: 0.7942
# Epoch 28/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2334 - accuracy: 0.9012
# Epoch 00028: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2349 - accuracy: 0.9012 - val_loss: 0.5242 - val_accuracy: 0.7986
# Epoch 29/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2373 - accuracy: 0.8992
# Epoch 00029: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2347 - accuracy: 0.8994 - val_loss: 0.5099 - val_accuracy: 0.8007
# Epoch 30/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2292 - accuracy: 0.9064
# Epoch 00030: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2283 - accuracy: 0.9067 - val_loss: 0.5208 - val_accuracy: 0.7848
# Epoch 31/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2356 - accuracy: 0.9013
# Epoch 00031: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2384 - accuracy: 0.9014 - val_loss: 0.5121 - val_accuracy: 0.8014
# Epoch 32/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2344 - accuracy: 0.9017
# Epoch 00032: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2337 - accuracy: 0.9018 - val_loss: 0.5421 - val_accuracy: 0.7906
# Epoch 33/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2279 - accuracy: 0.9055
# Epoch 00033: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2299 - accuracy: 0.9054 - val_loss: 0.5309 - val_accuracy: 0.7971
# Epoch 34/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2438 - accuracy: 0.8963
# Epoch 00034: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2483 - accuracy: 0.8962 - val_loss: 0.4981 - val_accuracy: 0.7993
# Epoch 35/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2243 - accuracy: 0.9068
# Epoch 00035: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2271 - accuracy: 0.9065 - val_loss: 0.5278 - val_accuracy: 0.8000
# Epoch 36/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2346 - accuracy: 0.9044
# Epoch 00036: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2325 - accuracy: 0.9043 - val_loss: 0.5238 - val_accuracy: 0.7993
# Epoch 37/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2103 - accuracy: 0.9122
# Epoch 00037: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2090 - accuracy: 0.9123 - val_loss: 0.5276 - val_accuracy: 0.7935
# Epoch 38/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2317 - accuracy: 0.9017
# Epoch 00038: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2333 - accuracy: 0.9016 - val_loss: 0.5426 - val_accuracy: 0.7899
# Epoch 39/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2228 - accuracy: 0.9048
# Epoch 00039: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2188 - accuracy: 0.9050 - val_loss: 0.5385 - val_accuracy: 0.7913
# Epoch 40/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2142 - accuracy: 0.9124
# Epoch 00040: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2159 - accuracy: 0.9121 - val_loss: 0.5435 - val_accuracy: 0.7935
# Epoch 41/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2369 - accuracy: 0.8997
# Epoch 00041: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 38ms/step - loss: 0.2328 - accuracy: 0.9000 - val_loss: 0.5674 - val_accuracy: 0.7754
# Epoch 42/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2122 - accuracy: 0.9093
# Epoch 00042: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2104 - accuracy: 0.9094 - val_loss: 0.5169 - val_accuracy: 0.7957
# Epoch 43/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2109 - accuracy: 0.9126
# Epoch 00043: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2136 - accuracy: 0.9126 - val_loss: 0.5330 - val_accuracy: 0.7971
# Epoch 44/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2355 - accuracy: 0.8983
# Epoch 00044: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2330 - accuracy: 0.8985 - val_loss: 0.5584 - val_accuracy: 0.7797
# Epoch 45/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2155 - accuracy: 0.9113
# Epoch 00045: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2160 - accuracy: 0.9114 - val_loss: 0.5480 - val_accuracy: 0.7942
# Epoch 46/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2211 - accuracy: 0.9077
# Epoch 00046: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2204 - accuracy: 0.9076 - val_loss: 0.5487 - val_accuracy: 0.8029
# Epoch 47/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2164 - accuracy: 0.9104
# Epoch 00047: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2158 - accuracy: 0.9103 - val_loss: 0.5443 - val_accuracy: 0.7935
# Epoch 48/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2175 - accuracy: 0.9081
# Epoch 00048: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2150 - accuracy: 0.9083 - val_loss: 0.5355 - val_accuracy: 0.7942
# Epoch 49/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2158 - accuracy: 0.9059
# Epoch 00049: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2196 - accuracy: 0.9058 - val_loss: 0.5204 - val_accuracy: 0.8007
# Epoch 50/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2161 - accuracy: 0.9104
# Epoch 00050: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2139 - accuracy: 0.9105 - val_loss: 0.5184 - val_accuracy: 0.7949
# Epoch 51/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2216 - accuracy: 0.9064
# Epoch 00051: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2180 - accuracy: 0.9067 - val_loss: 0.5812 - val_accuracy: 0.7696
# Epoch 52/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2093 - accuracy: 0.9141
# Epoch 00052: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2135 - accuracy: 0.9139 - val_loss: 0.5323 - val_accuracy: 0.7928
# Epoch 53/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2135 - accuracy: 0.9124
# Epoch 00053: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2123 - accuracy: 0.9125 - val_loss: 0.5435 - val_accuracy: 0.7928
# Epoch 54/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2179 - accuracy: 0.9075
# Epoch 00054: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2199 - accuracy: 0.9074 - val_loss: 0.5281 - val_accuracy: 0.8007
# Epoch 55/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2220 - accuracy: 0.9108
# Epoch 00055: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2191 - accuracy: 0.9110 - val_loss: 0.4994 - val_accuracy: 0.7993
# Epoch 56/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2109 - accuracy: 0.9112
# Epoch 00056: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2124 - accuracy: 0.9110 - val_loss: 0.5121 - val_accuracy: 0.7986
# Epoch 57/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2146 - accuracy: 0.9139
# Epoch 00057: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2119 - accuracy: 0.9141 - val_loss: 0.5549 - val_accuracy: 0.7928
# Epoch 58/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2078 - accuracy: 0.9139
# Epoch 00058: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2073 - accuracy: 0.9139 - val_loss: 0.5571 - val_accuracy: 0.7971
# Epoch 59/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2143 - accuracy: 0.9073
# Epoch 00059: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2135 - accuracy: 0.9074 - val_loss: 0.5957 - val_accuracy: 0.7913
# Epoch 60/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2202 - accuracy: 0.9062
# Epoch 00060: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2176 - accuracy: 0.9065 - val_loss: 0.5580 - val_accuracy: 0.7841
# Epoch 61/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2013 - accuracy: 0.9190
# Epoch 00061: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2051 - accuracy: 0.9188 - val_loss: 0.5594 - val_accuracy: 0.7841
# Epoch 62/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2442 - accuracy: 0.8966
# Epoch 00062: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2422 - accuracy: 0.8969 - val_loss: 0.5022 - val_accuracy: 0.7920
# Epoch 63/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2109 - accuracy: 0.9104
# Epoch 00063: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2082 - accuracy: 0.9107 - val_loss: 0.5361 - val_accuracy: 0.7993
# Epoch 64/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2069 - accuracy: 0.9141
# Epoch 00064: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2076 - accuracy: 0.9141 - val_loss: 0.5395 - val_accuracy: 0.7913
# Epoch 65/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2279 - accuracy: 0.9073
# Epoch 00065: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2279 - accuracy: 0.9074 - val_loss: 0.5476 - val_accuracy: 0.7986
# Epoch 66/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2127 - accuracy: 0.9166
# Epoch 00066: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2183 - accuracy: 0.9163 - val_loss: 0.5452 - val_accuracy: 0.7993
# Epoch 67/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2123 - accuracy: 0.9082
# Epoch 00067: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2112 - accuracy: 0.9083 - val_loss: 0.5313 - val_accuracy: 0.7891
# Epoch 68/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1950 - accuracy: 0.9168
# Epoch 00068: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1964 - accuracy: 0.9168 - val_loss: 0.5629 - val_accuracy: 0.7804
# Epoch 69/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2033 - accuracy: 0.9141
# Epoch 00069: val_accuracy did not improve from 0.80725
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2037 - accuracy: 0.9141 - val_loss: 0.5526 - val_accuracy: 0.7819
# Epoch 70/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2125 - accuracy: 0.9162
# Epoch 00070: val_accuracy improved from 0.80725 to 0.81014, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/Try2/MFC_CNN_Binary_70.h5
# 44/44 [==============================] - 2s 38ms/step - loss: 0.2093 - accuracy: 0.9165 - val_loss: 0.5407 - val_accuracy: 0.8101
# Epoch 71/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1965 - accuracy: 0.9182
# Epoch 00071: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1972 - accuracy: 0.9179 - val_loss: 0.5452 - val_accuracy: 0.7986
# Epoch 72/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2004 - accuracy: 0.9144
# Epoch 00072: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2066 - accuracy: 0.9139 - val_loss: 0.5431 - val_accuracy: 0.7862
# Epoch 73/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2227 - accuracy: 0.9104
# Epoch 00073: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2196 - accuracy: 0.9107 - val_loss: 0.5330 - val_accuracy: 0.7993
# Epoch 74/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1975 - accuracy: 0.9184
# Epoch 00074: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1969 - accuracy: 0.9184 - val_loss: 0.5458 - val_accuracy: 0.7957
# Epoch 75/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2041 - accuracy: 0.9157
# Epoch 00075: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2079 - accuracy: 0.9155 - val_loss: 0.5531 - val_accuracy: 0.7949
# Epoch 76/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2156 - accuracy: 0.9122
# Epoch 00076: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2146 - accuracy: 0.9123 - val_loss: 0.5563 - val_accuracy: 0.7942
# Epoch 77/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2013 - accuracy: 0.9177
# Epoch 00077: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1980 - accuracy: 0.9179 - val_loss: 0.5291 - val_accuracy: 0.7993
# Epoch 78/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9215
# Epoch 00078: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1985 - accuracy: 0.9213 - val_loss: 0.5528 - val_accuracy: 0.7928
# Epoch 79/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1931 - accuracy: 0.9215
# Epoch 00079: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1904 - accuracy: 0.9217 - val_loss: 0.5424 - val_accuracy: 0.7949
# Epoch 80/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1926 - accuracy: 0.9221
# Epoch 00080: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1910 - accuracy: 0.9223 - val_loss: 0.5498 - val_accuracy: 0.7920
# Epoch 81/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2044 - accuracy: 0.9119
# Epoch 00081: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2029 - accuracy: 0.9119 - val_loss: 0.5744 - val_accuracy: 0.7978
# Epoch 82/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1956 - accuracy: 0.9195
# Epoch 00082: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1944 - accuracy: 0.9195 - val_loss: 0.5396 - val_accuracy: 0.7964
# Epoch 83/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2052 - accuracy: 0.9161
# Epoch 00083: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2105 - accuracy: 0.9157 - val_loss: 0.5894 - val_accuracy: 0.7804
# Epoch 84/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2090 - accuracy: 0.9099
# Epoch 00084: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2129 - accuracy: 0.9097 - val_loss: 0.5714 - val_accuracy: 0.7928
# Epoch 85/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2119 - accuracy: 0.9132
# Epoch 00085: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2115 - accuracy: 0.9130 - val_loss: 0.5612 - val_accuracy: 0.7855
# Epoch 86/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2049 - accuracy: 0.9142
# Epoch 00086: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2035 - accuracy: 0.9143 - val_loss: 0.5666 - val_accuracy: 0.7891
# Epoch 87/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2024 - accuracy: 0.9168
# Epoch 00087: val_accuracy did not improve from 0.81014
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2037 - accuracy: 0.9166 - val_loss: 0.5586 - val_accuracy: 0.8000
# Epoch 88/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2009 - accuracy: 0.9170
# Epoch 00088: val_accuracy improved from 0.81014 to 0.81232, saving model to /content/drive/My Drive/Respiratory_Sound_Database/Respiratory_Sound_Database/FinalModels/MFCC_CNN_Binary/Try2/MFC_CNN_Binary_88.h5
# 44/44 [==============================] - 2s 38ms/step - loss: 0.1984 - accuracy: 0.9172 - val_loss: 0.5673 - val_accuracy: 0.8123
# Epoch 89/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1889 - accuracy: 0.9239
# Epoch 00089: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1899 - accuracy: 0.9237 - val_loss: 0.5763 - val_accuracy: 0.7935
# Epoch 90/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2054 - accuracy: 0.9155
# Epoch 00090: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2059 - accuracy: 0.9154 - val_loss: 0.5747 - val_accuracy: 0.7877
# Epoch 91/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1947 - accuracy: 0.9170
# Epoch 00091: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1922 - accuracy: 0.9172 - val_loss: 0.5186 - val_accuracy: 0.8109
# Epoch 92/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1881 - accuracy: 0.9230
# Epoch 00092: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1855 - accuracy: 0.9232 - val_loss: 0.5736 - val_accuracy: 0.7862
# Epoch 93/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1982 - accuracy: 0.9139
# Epoch 00093: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.2010 - accuracy: 0.9139 - val_loss: 0.5307 - val_accuracy: 0.7906
# Epoch 94/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2010 - accuracy: 0.9190
# Epoch 00094: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2005 - accuracy: 0.9190 - val_loss: 0.5385 - val_accuracy: 0.7986
# Epoch 95/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1845 - accuracy: 0.9217
# Epoch 00095: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1892 - accuracy: 0.9213 - val_loss: 0.5546 - val_accuracy: 0.7964
# Epoch 96/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1946 - accuracy: 0.9195
# Epoch 00096: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1915 - accuracy: 0.9197 - val_loss: 0.5579 - val_accuracy: 0.7870
# Epoch 97/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9172
# Epoch 00097: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1900 - accuracy: 0.9174 - val_loss: 0.5646 - val_accuracy: 0.8036
# Epoch 98/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.2051 - accuracy: 0.9191
# Epoch 00098: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2030 - accuracy: 0.9194 - val_loss: 0.5521 - val_accuracy: 0.8072
# Epoch 99/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1974 - accuracy: 0.9201
# Epoch 00099: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1957 - accuracy: 0.9201 - val_loss: 0.6050 - val_accuracy: 0.7906
# Epoch 100/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1988 - accuracy: 0.9193
# Epoch 00100: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.2002 - accuracy: 0.9192 - val_loss: 0.5757 - val_accuracy: 0.7978
# Epoch 101/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1911 - accuracy: 0.9222
# Epoch 00101: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1894 - accuracy: 0.9223 - val_loss: 0.5840 - val_accuracy: 0.7971
# Epoch 102/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1803 - accuracy: 0.9288
# Epoch 00102: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1769 - accuracy: 0.9290 - val_loss: 0.5851 - val_accuracy: 0.7877
# Epoch 103/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1868 - accuracy: 0.9231
# Epoch 00103: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1862 - accuracy: 0.9232 - val_loss: 0.5540 - val_accuracy: 0.8029
# Epoch 104/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1811 - accuracy: 0.9257
# Epoch 00104: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1823 - accuracy: 0.9257 - val_loss: 0.5878 - val_accuracy: 0.7935
# Epoch 105/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1855 - accuracy: 0.9239
# Epoch 00105: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1818 - accuracy: 0.9241 - val_loss: 0.5791 - val_accuracy: 0.7993
# Epoch 106/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1840 - accuracy: 0.9268
# Epoch 00106: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1818 - accuracy: 0.9270 - val_loss: 0.6051 - val_accuracy: 0.8007
# Epoch 107/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1951 - accuracy: 0.9199
# Epoch 00107: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1959 - accuracy: 0.9197 - val_loss: 0.5846 - val_accuracy: 0.7949
# Epoch 108/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1889 - accuracy: 0.9219
# Epoch 00108: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1876 - accuracy: 0.9219 - val_loss: 0.5726 - val_accuracy: 0.7928
# Epoch 109/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1858 - accuracy: 0.9241
# Epoch 00109: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1861 - accuracy: 0.9241 - val_loss: 0.5684 - val_accuracy: 0.7928
# Epoch 110/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1760 - accuracy: 0.9251
# Epoch 00110: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1788 - accuracy: 0.9248 - val_loss: 0.5829 - val_accuracy: 0.7877
# Epoch 111/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1902 - accuracy: 0.9208
# Epoch 00111: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1873 - accuracy: 0.9210 - val_loss: 0.6103 - val_accuracy: 0.7775
# Epoch 112/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1959 - accuracy: 0.9233
# Epoch 00112: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1950 - accuracy: 0.9233 - val_loss: 0.5620 - val_accuracy: 0.8043
# Epoch 113/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1893 - accuracy: 0.9239
# Epoch 00113: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1933 - accuracy: 0.9237 - val_loss: 0.5975 - val_accuracy: 0.7797
# Epoch 114/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1917 - accuracy: 0.9237
# Epoch 00114: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1915 - accuracy: 0.9237 - val_loss: 0.5449 - val_accuracy: 0.8065
# Epoch 115/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1959 - accuracy: 0.9168
# Epoch 00115: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1976 - accuracy: 0.9166 - val_loss: 0.5460 - val_accuracy: 0.7978
# Epoch 116/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1843 - accuracy: 0.9237
# Epoch 00116: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1856 - accuracy: 0.9235 - val_loss: 0.5517 - val_accuracy: 0.8000
# Epoch 117/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1878 - accuracy: 0.9215
# Epoch 00117: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1861 - accuracy: 0.9215 - val_loss: 0.5527 - val_accuracy: 0.7957
# Epoch 118/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1928 - accuracy: 0.9248
# Epoch 00118: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1894 - accuracy: 0.9250 - val_loss: 0.5573 - val_accuracy: 0.7877
# Epoch 119/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1707 - accuracy: 0.9299
# Epoch 00119: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1694 - accuracy: 0.9299 - val_loss: 0.5692 - val_accuracy: 0.8022
# Epoch 120/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1726 - accuracy: 0.9261
# Epoch 00120: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1704 - accuracy: 0.9262 - val_loss: 0.5760 - val_accuracy: 0.7862
# Epoch 121/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1811 - accuracy: 0.9271
# Epoch 00121: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1832 - accuracy: 0.9268 - val_loss: 0.5526 - val_accuracy: 0.8043
# Epoch 122/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1892 - accuracy: 0.9235
# Epoch 00122: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 38ms/step - loss: 0.1881 - accuracy: 0.9235 - val_loss: 0.5828 - val_accuracy: 0.7986
# Epoch 123/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1930 - accuracy: 0.9195
# Epoch 00123: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1898 - accuracy: 0.9197 - val_loss: 0.5474 - val_accuracy: 0.8022
# Epoch 124/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1901 - accuracy: 0.9221
# Epoch 00124: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1864 - accuracy: 0.9223 - val_loss: 0.5495 - val_accuracy: 0.7870
# Epoch 125/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1911 - accuracy: 0.9241
# Epoch 00125: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1890 - accuracy: 0.9242 - val_loss: 0.5694 - val_accuracy: 0.7920
# Epoch 126/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1617 - accuracy: 0.9330
# Epoch 00126: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1658 - accuracy: 0.9326 - val_loss: 0.5875 - val_accuracy: 0.7819
# Epoch 127/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1807 - accuracy: 0.9270
# Epoch 00127: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1816 - accuracy: 0.9270 - val_loss: 0.5449 - val_accuracy: 0.7964
# Epoch 128/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1813 - accuracy: 0.9193
# Epoch 00128: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1845 - accuracy: 0.9192 - val_loss: 0.5914 - val_accuracy: 0.7899
# Epoch 129/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1846 - accuracy: 0.9222
# Epoch 00129: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1875 - accuracy: 0.9221 - val_loss: 0.5717 - val_accuracy: 0.7971
# Epoch 130/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1818 - accuracy: 0.9230
# Epoch 00130: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1790 - accuracy: 0.9232 - val_loss: 0.5524 - val_accuracy: 0.7935
# Epoch 131/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1780 - accuracy: 0.9279
# Epoch 00131: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 38ms/step - loss: 0.1840 - accuracy: 0.9279 - val_loss: 0.5485 - val_accuracy: 0.7942
# Epoch 132/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1817 - accuracy: 0.9262
# Epoch 00132: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1822 - accuracy: 0.9262 - val_loss: 0.5489 - val_accuracy: 0.8123
# Epoch 133/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1778 - accuracy: 0.9286
# Epoch 00133: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1750 - accuracy: 0.9288 - val_loss: 0.5657 - val_accuracy: 0.8065
# Epoch 134/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1800 - accuracy: 0.9257
# Epoch 00134: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1777 - accuracy: 0.9259 - val_loss: 0.5632 - val_accuracy: 0.7978
# Epoch 135/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1815 - accuracy: 0.9262
# Epoch 00135: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1803 - accuracy: 0.9262 - val_loss: 0.5524 - val_accuracy: 0.8007
# Epoch 136/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1725 - accuracy: 0.9297
# Epoch 00136: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1706 - accuracy: 0.9299 - val_loss: 0.6460 - val_accuracy: 0.7819
# Epoch 137/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1820 - accuracy: 0.9246
# Epoch 00137: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1803 - accuracy: 0.9248 - val_loss: 0.5728 - val_accuracy: 0.7942
# Epoch 138/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1720 - accuracy: 0.9335
# Epoch 00138: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1711 - accuracy: 0.9335 - val_loss: 0.5522 - val_accuracy: 0.8036
# Epoch 139/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.9359
# Epoch 00139: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1623 - accuracy: 0.9360 - val_loss: 0.5719 - val_accuracy: 0.8000
# Epoch 140/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1755 - accuracy: 0.9266
# Epoch 00140: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 38ms/step - loss: 0.1733 - accuracy: 0.9268 - val_loss: 0.5822 - val_accuracy: 0.7891
# Epoch 141/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1744 - accuracy: 0.9306
# Epoch 00141: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1771 - accuracy: 0.9304 - val_loss: 0.5666 - val_accuracy: 0.8058
# Epoch 142/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1744 - accuracy: 0.9301
# Epoch 00142: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1723 - accuracy: 0.9302 - val_loss: 0.5938 - val_accuracy: 0.7942
# Epoch 143/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9286
# Epoch 00143: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1765 - accuracy: 0.9284 - val_loss: 0.5741 - val_accuracy: 0.8058
# Epoch 144/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1731 - accuracy: 0.9288
# Epoch 00144: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1717 - accuracy: 0.9288 - val_loss: 0.5656 - val_accuracy: 0.8000
# Epoch 145/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1752 - accuracy: 0.9290
# Epoch 00145: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1756 - accuracy: 0.9290 - val_loss: 0.5715 - val_accuracy: 0.7957
# Epoch 146/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1733 - accuracy: 0.9322
# Epoch 00146: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1739 - accuracy: 0.9320 - val_loss: 0.5733 - val_accuracy: 0.8014
# Epoch 147/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1751 - accuracy: 0.9301
# Epoch 00147: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1725 - accuracy: 0.9300 - val_loss: 0.5756 - val_accuracy: 0.7993
# Epoch 148/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1611 - accuracy: 0.9368
# Epoch 00148: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1658 - accuracy: 0.9368 - val_loss: 0.5640 - val_accuracy: 0.8058
# Epoch 149/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1832 - accuracy: 0.9261
# Epoch 00149: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1820 - accuracy: 0.9261 - val_loss: 0.6212 - val_accuracy: 0.7949
# Epoch 150/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1732 - accuracy: 0.9271
# Epoch 00150: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1856 - accuracy: 0.9271 - val_loss: 0.5815 - val_accuracy: 0.7935
# Epoch 151/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1842 - accuracy: 0.9248
# Epoch 00151: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1816 - accuracy: 0.9250 - val_loss: 0.5830 - val_accuracy: 0.7862
# Epoch 152/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1619 - accuracy: 0.9322
# Epoch 00152: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1596 - accuracy: 0.9324 - val_loss: 0.5859 - val_accuracy: 0.8000
# Epoch 153/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1741 - accuracy: 0.9281
# Epoch 00153: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1729 - accuracy: 0.9281 - val_loss: 0.5846 - val_accuracy: 0.8043
# Epoch 154/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1715 - accuracy: 0.9311
# Epoch 00154: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1723 - accuracy: 0.9310 - val_loss: 0.5753 - val_accuracy: 0.7949
# Epoch 155/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1804 - accuracy: 0.9275
# Epoch 00155: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1776 - accuracy: 0.9277 - val_loss: 0.5655 - val_accuracy: 0.7870
# Epoch 156/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1692 - accuracy: 0.9279
# Epoch 00156: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1681 - accuracy: 0.9281 - val_loss: 0.5730 - val_accuracy: 0.7986
# Epoch 157/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1712 - accuracy: 0.9273
# Epoch 00157: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1681 - accuracy: 0.9275 - val_loss: 0.5905 - val_accuracy: 0.7957
# Epoch 158/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1612 - accuracy: 0.9364
# Epoch 00158: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1652 - accuracy: 0.9360 - val_loss: 0.6038 - val_accuracy: 0.7978
# Epoch 159/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1659 - accuracy: 0.9324
# Epoch 00159: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1674 - accuracy: 0.9324 - val_loss: 0.5902 - val_accuracy: 0.8014
# Epoch 160/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1597 - accuracy: 0.9377
# Epoch 00160: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1585 - accuracy: 0.9378 - val_loss: 0.6022 - val_accuracy: 0.8007
# Epoch 161/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1648 - accuracy: 0.9333
# Epoch 00161: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1620 - accuracy: 0.9335 - val_loss: 0.6272 - val_accuracy: 0.7971
# Epoch 162/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1608 - accuracy: 0.9346
# Epoch 00162: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1635 - accuracy: 0.9344 - val_loss: 0.5933 - val_accuracy: 0.7949
# Epoch 163/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1650 - accuracy: 0.9331
# Epoch 00163: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1640 - accuracy: 0.9333 - val_loss: 0.5849 - val_accuracy: 0.7928
# Epoch 164/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1595 - accuracy: 0.9359
# Epoch 00164: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1630 - accuracy: 0.9357 - val_loss: 0.6276 - val_accuracy: 0.7913
# Epoch 165/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1726 - accuracy: 0.9299
# Epoch 00165: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1776 - accuracy: 0.9297 - val_loss: 0.5640 - val_accuracy: 0.8036
# Epoch 166/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1794 - accuracy: 0.9253
# Epoch 00166: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1802 - accuracy: 0.9253 - val_loss: 0.6374 - val_accuracy: 0.7746
# Epoch 167/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1829 - accuracy: 0.9277
# Epoch 00167: val_accuracy did not improve from 0.81232
# 44/44 [==============================] - 2s 38ms/step - loss: 0.1809 - accuracy: 0.9279 - val_loss: 0.6244 - val_accuracy: 0.8029
# Epoch 168/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1677 - accuracy: 0.9320
# Epoch 00168: val_accuracy did not improve from 0.81232
# ...
# Epoch 945/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9693
# Epoch 00945: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0821 - accuracy: 0.9694 - val_loss: 0.7920 - val_accuracy: 0.8043
# Epoch 946/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0826 - accuracy: 0.9700
# Epoch 00946: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0816 - accuracy: 0.9701 - val_loss: 0.7491 - val_accuracy: 0.8123
# Epoch 947/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0825 - accuracy: 0.9704
# Epoch 00947: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0828 - accuracy: 0.9703 - val_loss: 0.7422 - val_accuracy: 0.8087
# Epoch 948/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0828 - accuracy: 0.9695
# Epoch 00948: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0846 - accuracy: 0.9694 - val_loss: 0.8012 - val_accuracy: 0.8080
# Epoch 949/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1061 - accuracy: 0.9593
# Epoch 00949: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1050 - accuracy: 0.9594 - val_loss: 0.7712 - val_accuracy: 0.8036
# Epoch 950/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0787 - accuracy: 0.9709
# Epoch 00950: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0786 - accuracy: 0.9710 - val_loss: 0.7743 - val_accuracy: 0.8101
# Epoch 951/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0835 - accuracy: 0.9649
# Epoch 00951: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0869 - accuracy: 0.9648 - val_loss: 0.7956 - val_accuracy: 0.8029
# Epoch 952/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1045 - accuracy: 0.9608
# Epoch 00952: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1037 - accuracy: 0.9609 - val_loss: 0.7696 - val_accuracy: 0.8058
# Epoch 953/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0956 - accuracy: 0.9649
# Epoch 00953: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0942 - accuracy: 0.9650 - val_loss: 0.7749 - val_accuracy: 0.8072
# Epoch 954/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0882 - accuracy: 0.9693
# Epoch 00954: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0865 - accuracy: 0.9694 - val_loss: 0.7728 - val_accuracy: 0.8109
# Epoch 955/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0989 - accuracy: 0.9653
# Epoch 00955: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1002 - accuracy: 0.9652 - val_loss: 0.7544 - val_accuracy: 0.8094
# Epoch 956/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0889 - accuracy: 0.9682
# Epoch 00956: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0879 - accuracy: 0.9683 - val_loss: 0.7607 - val_accuracy: 0.7986
# Epoch 957/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0849 - accuracy: 0.9682
# Epoch 00957: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0868 - accuracy: 0.9679 - val_loss: 0.7439 - val_accuracy: 0.8036
# Epoch 958/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0881 - accuracy: 0.9684
# Epoch 00958: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0901 - accuracy: 0.9683 - val_loss: 0.7586 - val_accuracy: 0.8094
# Epoch 959/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1023 - accuracy: 0.9633
# Epoch 00959: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1063 - accuracy: 0.9630 - val_loss: 0.7639 - val_accuracy: 0.8000
# Epoch 960/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0999 - accuracy: 0.9611
# Epoch 00960: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.1044 - accuracy: 0.9609 - val_loss: 0.7754 - val_accuracy: 0.8000
# Epoch 961/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1009 - accuracy: 0.9615
# Epoch 00961: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0998 - accuracy: 0.9614 - val_loss: 0.7387 - val_accuracy: 0.8101
# Epoch 962/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0852 - accuracy: 0.9700
# Epoch 00962: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0847 - accuracy: 0.9701 - val_loss: 0.7626 - val_accuracy: 0.8051
# Epoch 963/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0898 - accuracy: 0.9664
# Epoch 00963: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0902 - accuracy: 0.9663 - val_loss: 0.7293 - val_accuracy: 0.8109
# Epoch 964/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9713
# Epoch 00964: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0812 - accuracy: 0.9714 - val_loss: 0.7281 - val_accuracy: 0.8109
# Epoch 965/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0785 - accuracy: 0.9673
# Epoch 00965: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0842 - accuracy: 0.9670 - val_loss: 0.7509 - val_accuracy: 0.8022
# Epoch 966/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0879 - accuracy: 0.9657
# Epoch 00966: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0865 - accuracy: 0.9657 - val_loss: 0.7974 - val_accuracy: 0.8051
# Epoch 967/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0891 - accuracy: 0.9675
# Epoch 00967: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0875 - accuracy: 0.9676 - val_loss: 0.7459 - val_accuracy: 0.8014
# Epoch 968/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1004 - accuracy: 0.9631
# Epoch 00968: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1003 - accuracy: 0.9630 - val_loss: 0.8118 - val_accuracy: 0.7949
# Epoch 969/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0962 - accuracy: 0.9620
# Epoch 00969: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0943 - accuracy: 0.9621 - val_loss: 0.8109 - val_accuracy: 0.8072
# Epoch 970/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0810 - accuracy: 0.9704
# Epoch 00970: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0792 - accuracy: 0.9705 - val_loss: 0.7505 - val_accuracy: 0.8072
# Epoch 971/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0758 - accuracy: 0.9715
# Epoch 00971: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0759 - accuracy: 0.9715 - val_loss: 0.7756 - val_accuracy: 0.8043
# Epoch 972/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0790 - accuracy: 0.9709
# Epoch 00972: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0795 - accuracy: 0.9708 - val_loss: 0.7822 - val_accuracy: 0.8051
# Epoch 973/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0760 - accuracy: 0.9717
# Epoch 00973: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0756 - accuracy: 0.9715 - val_loss: 0.7790 - val_accuracy: 0.8065
# Epoch 974/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0913 - accuracy: 0.9664
# Epoch 00974: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0897 - accuracy: 0.9665 - val_loss: 0.7960 - val_accuracy: 0.8058
# Epoch 975/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0838 - accuracy: 0.9677
# Epoch 00975: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0821 - accuracy: 0.9677 - val_loss: 0.7895 - val_accuracy: 0.8043
# Epoch 976/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0727 - accuracy: 0.9713
# Epoch 00976: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0715 - accuracy: 0.9714 - val_loss: 0.7951 - val_accuracy: 0.8022
# Epoch 977/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9648
# Epoch 00977: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0915 - accuracy: 0.9648 - val_loss: 0.7726 - val_accuracy: 0.7964
# Epoch 978/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0921 - accuracy: 0.9689
# Epoch 00978: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0924 - accuracy: 0.9690 - val_loss: 0.7995 - val_accuracy: 0.8022
# Epoch 979/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0851 - accuracy: 0.9671
# Epoch 00979: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0842 - accuracy: 0.9672 - val_loss: 0.8137 - val_accuracy: 0.8094
# Epoch 980/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0822 - accuracy: 0.9720
# Epoch 00980: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0911 - accuracy: 0.9717 - val_loss: 0.7545 - val_accuracy: 0.8116
# Epoch 981/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.1156 - accuracy: 0.9573
# Epoch 00981: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.1137 - accuracy: 0.9574 - val_loss: 0.7199 - val_accuracy: 0.7993
# Epoch 982/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0897 - accuracy: 0.9644
# Epoch 00982: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0879 - accuracy: 0.9645 - val_loss: 0.7337 - val_accuracy: 0.8152
# Epoch 983/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0824 - accuracy: 0.9691
# Epoch 00983: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0806 - accuracy: 0.9692 - val_loss: 0.7697 - val_accuracy: 0.8014
# Epoch 984/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0829 - accuracy: 0.9684
# Epoch 00984: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0814 - accuracy: 0.9685 - val_loss: 0.8122 - val_accuracy: 0.7870
# Epoch 985/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0789 - accuracy: 0.9724
# Epoch 00985: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0786 - accuracy: 0.9723 - val_loss: 0.7759 - val_accuracy: 0.8036
# Epoch 986/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0912 - accuracy: 0.9651
# Epoch 00986: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0894 - accuracy: 0.9652 - val_loss: 0.8073 - val_accuracy: 0.7928
# Epoch 987/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9662
# Epoch 00987: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0827 - accuracy: 0.9663 - val_loss: 0.7779 - val_accuracy: 0.7949
# Epoch 988/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0790 - accuracy: 0.9700
# Epoch 00988: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0803 - accuracy: 0.9699 - val_loss: 0.8208 - val_accuracy: 0.8029
# Epoch 989/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0894 - accuracy: 0.9671
# Epoch 00989: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0878 - accuracy: 0.9672 - val_loss: 0.7725 - val_accuracy: 0.8043
# Epoch 990/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0914 - accuracy: 0.9655
# Epoch 00990: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0899 - accuracy: 0.9656 - val_loss: 0.8224 - val_accuracy: 0.8029
# Epoch 991/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0845 - accuracy: 0.9684
# Epoch 00991: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0836 - accuracy: 0.9685 - val_loss: 0.7640 - val_accuracy: 0.8058
# Epoch 992/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0817 - accuracy: 0.9673
# Epoch 00992: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0804 - accuracy: 0.9674 - val_loss: 0.7498 - val_accuracy: 0.8087
# Epoch 993/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0811 - accuracy: 0.9695
# Epoch 00993: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0798 - accuracy: 0.9696 - val_loss: 0.7835 - val_accuracy: 0.8029
# Epoch 994/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0796 - accuracy: 0.9709
# Epoch 00994: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0820 - accuracy: 0.9708 - val_loss: 0.8146 - val_accuracy: 0.7935
# Epoch 995/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0952 - accuracy: 0.9688
# Epoch 00995: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0932 - accuracy: 0.9688 - val_loss: 0.8392 - val_accuracy: 0.8036
# Epoch 996/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0987 - accuracy: 0.9640
# Epoch 00996: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0968 - accuracy: 0.9641 - val_loss: 0.7669 - val_accuracy: 0.7986
# Epoch 997/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0949 - accuracy: 0.9651
# Epoch 00997: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 37ms/step - loss: 0.0960 - accuracy: 0.9650 - val_loss: 0.7814 - val_accuracy: 0.8029
# Epoch 998/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0929 - accuracy: 0.9655
# Epoch 00998: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0918 - accuracy: 0.9656 - val_loss: 0.7770 - val_accuracy: 0.8065
# Epoch 999/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0923 - accuracy: 0.9644
# Epoch 00999: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0914 - accuracy: 0.9645 - val_loss: 0.7753 - val_accuracy: 0.8116
# Epoch 1000/1000
# 43/44 [============================>.] - ETA: 0s - loss: 0.0791 - accuracy: 0.9706
# Epoch 01000: val_accuracy did not improve from 0.82391
# 44/44 [==============================] - 2s 36ms/step - loss: 0.0775 - accuracy: 0.9706 - val_loss: 0.7803 - val_accuracy: 0.8123
# Training completed in time:  0:27:27.087698
